# %%
import pyterrier as pt
if not pt.started():
    pt.init(version='5.7', helper_version='0.0.7')
import ir_datasets as irds
# Out:
# /tmp/ipykernel_595506/3295562699.py:2: DeprecationWarning: Call to deprecated function (or staticmethod) started. (use pt.java.started() instead) -- Deprecated since version 0.11.0.
#   if not pt.started():
# No etc/terrier.properties, using terrier.default.properties for bootstrap configuration.
# Java started and loaded: pyterrier.java, pyterrier.terrier.java [version=5.7 (build: craigm 2022-11-10 18:30), helper_version=0.0.7]
# /tmp/ipykernel_595506/3295562699.py:3: DeprecationWarning: Call to deprecated method pt.init(). Deprecated since version 0.11.0.
# The following code will have the same effect:
# pt.terrier.set_version('5.7')
# pt.terrier.set_helper_version('0.0.7')
# pt.java.init() # optional, forces java initialisation
#   pt.init(version='5.7', helper_version='0.0.7')

# %%
ds_list = pt.list_datasets()['dataset'].to_list()

# find dataset name containing "scifact"
ds_name = [ds for ds in ds_list if 'trec-covid' in ds]
ds_name
# Out:
# ['trec-covid',
#  'irds:beir/trec-covid',
#  'irds:cord19/fulltext/trec-covid',
#  'irds:cord19/trec-covid',
#  'irds:cord19/trec-covid/round1',
#  'irds:cord19/trec-covid/round2',
#  'irds:cord19/trec-covid/round3',
#  'irds:cord19/trec-covid/round4',
#  'irds:cord19/trec-covid/round5']

# %%
trec_covid = pt.get_dataset('irds:beir/trec-covid')
trec_covid
# Out:
# IRDSDataset('beir/trec-covid')

# %%
trec_covid.get_topics()
# Out:
# There are multiple query fields available: ('text', 'query', 'narrative'). To use with pyterrier, provide variant or modify dataframe to add query column.
#    qid                                               text  \
# 0    1                     what is the origin of COVID-19
# 1    2  how does the coronavirus respond to changes in...
# 2    3  will SARS-CoV2 infected people develop immunit...
# 3    4                   what causes death from Covid-19?
# 4    5  what drugs have been active against SARS-CoV o...
# 5    6  what types of rapid testing for Covid-19 have ...
# 6    7  are there serological tests that detect antibo...
# 7    8  how has lack of testing availability led to un...
# 8    9                   how has COVID-19 affected Canada
# 9   10  has social distancing had an impact on slowing...
# 10  11  what are the guidelines for triaging patients ...
# 11  12  what are best practices in hospitals and at ho...
# 12  13   what are the transmission routes of coronavirus?
# 13  14  what evidence is there related to COVID-19 sup...
# 14  15  how long can the coronavirus live outside the ...
# 15  16  how long does coronavirus remain stable  on su...
# 16  17  are there any clinical trials available for th...
# 17  18  what are the best masks for preventing infecti...
# 18  19  what type of hand sanitizer is needed to destr...
# 19  20  are patients taking Angiotensin-converting enz...
# 20  21  what are the mortality rates overall and in sp...
# 21  22  are cardiac complications likely in patients w...
# 22  23  what kinds of complications related to COVID-1...
# 23  24  what kinds of complications related to COVID-1...
# 24  25  which biomarkers predict the severe clinical c...
# 25  26         what are the initial symptoms of Covid-19?
# 26  27  what is known about those infected with Covid-...
# 27  28  what evidence is there for the value of hydrox...
# 28  29  which SARS-CoV-2 proteins-human proteins inter...
# 29  30  is remdesivir an effective treatment for COVID-19
# 30  31  How does the coronavirus differ from seasonal ...
# 31  32  Does SARS-CoV-2 have any subtypes, and if so w...
# 32  33  What vaccine candidates are being tested for C...
# 33  34  What are the longer-term complications of thos...
# 34  35  What new public datasets are available related...
# 35  36  What is the protein structure of the SARS-CoV-...
# 36  37  What is the result of phylogenetic analysis of...
# 37  38  What is the mechanism of inflammatory response...
# 38  39  What is the mechanism of cytokine storm syndro...
# 39  40  What are the observed mutations in the SARS-Co...
# 40  41  What are the impacts of COVID-19 among African...
# 41  42  Does Vitamin D impact COVID-19 prevention and ...
# 42  43  How has the COVID-19 pandemic impacted violenc...
# 43  44  How much impact do masks have on preventing th...
# 44  45  How has the COVID-19 pandemic impacted mental ...
# 45  46  what evidence is there for dexamethasone as a ...
# 46  47  what are the health outcomes for children who ...
# 47  48  what are the benefits and risks of re-opening ...
# 48  49  do individuals who recover from COVID-19 show ...
# 49  50  what is known about an mRNA vaccine for the SA...
#
#                                             query  \
# 0                              coronavirus origin
# 1         coronavirus response to weather changes
# 2                            coronavirus immunity
# 3          how do people die from the coronavirus
# 4                       animal models of covid 19
# 5                  coronavirus test rapid testing
# 6               serological tests for coronavirus
# 7                     coronavirus under reporting
# 8                           coronavirus in canada
# 9            coronavirus social distancing impact
# 10                 coronavirus hospital rationing
# 11                         coronavirus quarantine
# 12                    how does coronavirus spread
# 13                    coronavirus super spreaders
# 14                       coronavirus outside body
# 15  how long does coronavirus survive on surfaces
# 16                    coronavirus clinical trials
# 17                      masks prevent coronavirus
# 18       what alcohol sanitizer kills coronavirus
# 19                 coronavirus and ace inhibitors
# 20                          coronavirus mortality
# 21                      coronavirus heart impacts
# 22                       coronavirus hypertension
# 23                           coronavirus diabetes
# 24                         coronavirus biomarkers
# 25                     coronavirus early symptoms
# 26                       coronavirus asymptomatic
# 27                 coronavirus hydroxychloroquine
# 28                   coronavirus drug repurposing
# 29                         coronavirus remdesivir
# 30         difference between coronavirus and flu
# 31                           coronavirus subtypes
# 32                 coronavirus vaccine candidates
# 33                           coronavirus recovery
# 34                    coronavirus public datasets
# 35                     sars cov 2 spike structure
# 36               sars cov 2 phylogenetic analysis
# 37                    covid inflammatory response
# 38                        covid 19 cytokine storm
# 39                          coronavirus mutations
# 40                  covid 19 in african americans
# 41                         vitamin d and covid 19
# 42                       violence during pandemic
# 43    impact of masks on coronavirus transmission
# 44               coronavirus mental health impact
# 45                      dexamethasone coronavirus
# 46                  covid 19 outcomes in children
# 47                   school reopening coronavirus
# 48               post infection covid 19 immunity
# 49                       mrna vaccine coronavirus
#
#                                             narrative
# 0   seeking range of information about the SARS-Co...
# 1   seeking range of information about the SARS-Co...
# 2   seeking studies of immunity developed due to i...
# 3   Studies looking at mechanisms of death from Co...
# 4   Papers that describe the results  of testing d...
# 5   Looking for studies identifying ways to diagno...
# 6   Looking for assays that measure immune respons...
# 7   Looking for studies answering questions of imp...
# 8   seeking data related to infections (confirm, s...
# 9   seeking specific information on studies that h...
# 10  Seeking information on any guidelines for prio...
# 11  Seeking information on best practices for acti...
# 12  Looking for information on all possible ways t...
# 13  seeking range of information related to the nu...
# 14  seeking range of information on the SARS-CoV-2...
# 15  Studies of time SARS-CoV-2 remains stable afte...
# 16  seeking specific COVID-19 clinical trials rang...
# 17  What types of masks should or should not be us...
# 18  Studies assessing chemicals and their concentr...
# 19  Looking for information on interactions betwee...
# 20  Seeking  information on COVID-19 fatality rate...
# 21  Seeking information on the types, frequency an...
# 22  seeking specific outcomes that hypertensive  (...
# 23  seeking specific outcomes that diabetic (any t...
# 24  Looking for information on biomarkers that pre...
# 25  Studies of patients and the first clinical man...
# 26  Studies of people who are known to be infected...
# 27  Basic science or clinical studies assessing th...
# 28  Seeking information about protein-protein inte...
# 29  seeking specific information on clinical outco...
# 30  Includes studies ranging from those focusing o...
# 31  Papers that discuss subtypes of the virus, fro...
# 32  Seeking studies that discuss possible, but spe...
# 33  Seeking information on the health outcomes for...
# 34  Seeking articles that specifically release new...
# 35  Looking for studies of the structure of the sp...
# 36  Looking for a range of studies which provide t...
# 37  Looking for a range of studies which describes...
# 38  Looking for studies that describes mechanism o...
# 39  Looking for studies that describes the emergen...
# 40  Looking for studies that analyze burden of ill...
# 41  This includes studies describing possible role...
# 42  Looking for analyses and data on how the pande...
# 43  Looking for studies of how masks slow SARS-CoV...
# 44  Includes increasing/decreasing rates of depres...
# 45  Looking for studies on the impact of dexametha...
# 46  Looking for studies on health outcomes in chil...
# 47  With the possibility of schools re-opening whi...
# 48  There is concern about re-infection for COVID-...
# 49  Looking for studies specifically focusing on m...

# %%
corpus_iter = trec_covid.get_corpus_iter()
# Out:
# [INFO] [starting] building docstore
# [INFO] [starting] opening zip file
# [INFO] [finished] opening zip file s]
# docs_iter: 100%|████████████████████| 171332/171332 [00:05<00:00, 32885.78doc/s]
# [INFO] [finished] docs_iter: [00:05] [171332doc] [32879.93doc/s]
# [INFO] [finished] building docstore [5.27s]
# beir/trec-covid documents:   0%|          | 0/171332 [00:00<?, ?it/s]

# %%
i = 0
for doc in corpus_iter:
    i += 1
    if i > 5:
        print(doc.keys())
        break
    print(doc)
# Out:
# beir/trec-covid documents:   0%|          | 7/171332 [00:40<234:59:28,  4.94s/it]
# {'text': "The 21st International Symposium on Intensive Care and Emergency Medicine was dominated by the results of recent clinical trials in sepsis and acute respiratory distress syndrome (ARDS). The promise of extracorporeal liver replacement therapy and noninvasive ventilation were other areas of interest. Ethical issues also received attention. Overall, the 'state of the art' lectures, pro/con debates, seminars and tutorials were of a high standard. The meeting was marked by a sense of renewed enthusiasm that positive progress is occurring in intensive care medicine.", 'title': 'The 21st International Symposium on Intensive Care and Emergency Medicine, Brussels, Belgium, 20-23 March 2001', 'url': 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC137274/', 'pubmed_id': '11353930', 'docno': '8zchiykl'}
# {'text': 'Heme oxygenase-1 (HO-1), an inducible stress protein, confers cytoprotection against oxidative stress in vitro and in vivo. In addition to its physiological role in heme degradation, HO-1 may influence a number of cellular processes, including growth, inflammation, and apoptosis. By virtue of anti-inflammatory effects, HO-1 limits tissue damage in response to proinflammatory stimuli and prevents allograft rejection after transplantation. The transcriptional upregulation of HO-1 responds to many agents, such as hypoxia, bacterial lipopolysaccharide, and reactive oxygen/nitrogen species. HO-1 and its constitutively expressed isozyme, heme oxygenase-2, catalyze the rate-limiting step in the conversion of heme to its metabolites, bilirubin IXα, ferrous iron, and carbon monoxide (CO). The mechanisms by which HO-1 provides protection most likely involve its enzymatic reaction products. Remarkably, administration of CO at low concentrations can substitute for HO-1 with respect to anti-inflammatory and anti-apoptotic effects, suggesting a role for CO as a key mediator of HO-1 function. Chronic, low-level, exogenous exposure to CO from cigarette smoking contributes to the importance of CO in pulmonary medicine. The implications of the HO-1/CO system in pulmonary diseases will be discussed in this review, with an emphasis on inflammatory states.', 'title': 'Heme oxygenase-1 and carbon monoxide in pulmonary medicine', 'url': 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC193681/', 'pubmed_id': '12964953', 'docno': '8qnrcgnk'}
# {'text': 'This report describes the design and implementation of the Real-time Outbreak and Disease Surveillance (RODS) system, a computer-based public health surveillance system for early detection of disease outbreaks. Hospitals send RODS data from clinical encounters over virtual private networks and leased lines using the Health Level 7 (HL7) message protocol. The data are sent in real time. RODS automatically classifies the registration chief complaint from the visit into one of seven syndrome categories using Bayesian classifiers. It stores the data in a relational database, aggregates the data for analysis using data warehousing techniques, applies univariate and multivariate statistical detection algorithms to the data, and alerts users of when the algorithms identify anomalous patterns in the syndrome counts. RODS also has a Web-based user interface that supports temporal and spatial analyses. RODS processes sales of over-the-counter health care products in a similar manner but receives such data in batch mode on a daily basis. RODS was used during the 2002 Winter Olympics and currently operates in two states—Pennsylvania and Utah. It has been and continues to be a resource for implementing, evaluating, and applying new methods of public health surveillance.', 'title': 'Technical Description of RODS: A Real-time Public Health Surveillance System', 'url': 'https://academic.oup.com/jamia/article-pdf/10/5/399/2352016/10-5-399.pdf', 'pubmed_id': '12807803', 'docno': 'jg13scgo'}
# {'text': 'Regulation of ornithine decarboxylase in vertebrates involves a negative feedback mechanism requiring the protein antizyme. Here we show that a similar mechanism exists in the fission yeast Schizosaccharomyces pombe. The expression of mammalian antizyme genes requires a specific +1 translational frameshift. The efficiency of the frameshift event reflects cellular polyamine levels creating the autoregulatory feedback loop. As shown here, the yeast antizyme gene and several newly identified antizyme genes from different nematodes also require a ribosomal frameshift event for their expression. Twelve nucleotides around the frameshift site are identical between S.pombe and the mammalian counterparts. The core element for this frameshifting is likely to have been present in the last common ancestor of yeast, nematodes and mammals.', 'title': 'Conservation of polyamine regulation by translational frameshifting from yeast to mammals', 'url': 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC302018/', 'pubmed_id': '10775274', 'docno': '5tkvsudh'}
# {'text': 'Heterogeneous nuclear ribonucleoprotein (hnRNP A1) is involved in pre-mRNA splicing in the nucleus and translational regulation in the cytoplasm. In the present study, we demonstrate that hnRNP A1 also participates in the transcription and replication of a cytoplasmic RNA virus, mouse hepatitis virus (MHV). Overexpression of hnRNP A1 accelerated the kinetics of viral RNA synthesis, whereas the expression in the cytoplasm of a dominant-negative hnRNP A1 mutant that lacks the nuclear transport domain significantly delayed it. The hnRNP A1 mutant caused a global inhibition of viral mRNA transcription and genomic replication, and also a preferential inhibition of the replication of defective-interfering RNAs. Similar to the wild-type hnRNP A1, the hnRNP A1 mutant complexed with an MHV polymerase gene product, the nucleocapsid protein and the viral RNA. However, in contrast to the wild-type hnRNP A1, the mutant protein failed to bind a 250 kDa cellular protein, suggesting that the recruitment of cellular proteins by hnRNP A1 is important for MHV RNA synthesis. Our findings establish the importance of cellular factors in viral RNA-dependent RNA synthesis.', 'title': 'Heterogeneous nuclear ribonucleoprotein A1 regulates RNA synthesis of a cytoplasmic virus', 'url': 'http://europepmc.org/articles/pmc302072?pdf=render', 'pubmed_id': '10970862', 'docno': '6lvn10f4'}
# dict_keys(['text', 'title', 'url', 'pubmed_id', 'docno'])

# %%
nf = pt.get_dataset('irds:beir/nfcorpus')

# %%
nf.get_topics("text")
# Out:
#              qid                                              query
# 0        PLAIN-3            breast cancer cells feed on cholesterol
# 1        PLAIN-4              using diet to treat asthma and eczema
# 2        PLAIN-5               treating asthma with plants vs pills
# 3        PLAIN-6         how fruits and vegetables can treat asthma
# 4        PLAIN-7       how fruits and vegetables can prevent asthma
# ...          ...                                                ...
# 3232  PLAIN-3432                       healthy chocolate milkshakes
# 3233  PLAIN-3442                          the healthiest vegetables
# 3234  PLAIN-3452                           bowel movement frequency
# 3235  PLAIN-3462                      olive oil and artery function
# 3236  PLAIN-3472  how doctors responded to being named a leading...
#
# [3237 rows x 2 columns]

# %%
nf_topic_df = nf.get_topics("text")
nf_topic_df.to_csv("/home/guest/r12922050/GitHub/d2qplus/data/nfcorpus.tsv", sep="\t", header=False, index=False)

# %%
dataset = pt.get_dataset("irds:beir/trec-covid")
topics = dataset.get_topics()  # Queries
qrels = dataset.get_qrels()    # Relevance judgments
# Out:
# There are multiple query fields available: ('text', 'query', 'narrative'). To use with pyterrier, provide variant or modify dataframe to add query column.

# %% [markdown]
# ## nfcorpus eval and rerank

# %%
dataset = pt.get_dataset("irds:beir/nfcorpus")
topics = dataset.get_topics("text")  # Queries
it = dataset.get_corpus_iter()

# %%
import json

with open("/home/guest/r12922050/GitHub/d2qplus/gen/scifact_llm_gen20.jsonl", "r") as f:
    lines = f.readlines()
    for line in lines:
        data = json.loads(line)
        print(data.keys())
        print(data["id"])
        break
# Out:
# dict_keys(['id', 'text', 'predicted_queries'])
# 4983

# %%
pt.get_dataset("irds:beir/scifact").get_topics()
# Out:
#        qid                                              query
# 0        0  0 dimensional biomaterials lack inductive prop...
# 1        2  1 in 5 million in uk have abnormal prp positivity
# 2        4  1 1 of colorectal cancer patients are diagnose...
# 3        6  10 of sudden infant death syndrome sids deaths...
# 4        9  32 of liver transplantation programs required ...
# ...    ...                                                ...
# 1104  1379  women with a higher birth weight are more like...
# 1105  1382  apkcz causes tumour enhancement by affecting g...
# 1106  1385    csmac formation enhances weak ligand signalling
# 1107  1389  mtorc2 regulates intracellular cysteine levels...
# 1108  1395  p16ink4a accumulation is linked to an abnormal...
#
# [1109 rows x 2 columns]

# %%
import pandas as pd
corpus_df = pd.read_json("/home/guest/r12922050/GitHub/d2qplus/gen/scifact_llm_gen20.jsonl", lines=True)
corpus_df = corpus_df.rename(columns={"id": "docno"})
corpus_df
# Out:
#           docno                                               text  \
# 0          4983  Alterations of the architecture of cerebral wh...
# 1          5836  Myelodysplastic syndromes (MDS) are age-depend...
# 2          7912  ID elements are short interspersed elements (S...
# 3         18670  DNA methylation plays an important role in bio...
# 4         19238  Two human Golli (for gene expressed in the oli...
# ...         ...                                                ...
# 5178  195689316  BACKGROUND The main associations of body-mass ...
# 5179  195689757  A key aberrant biological difference between t...
# 5180  196664003  A signaling pathway transmits information from...
# 5181  198133135  AIMS Trabecular bone score (TBS) is a surrogat...
# 5182  198309074  Introduction: Among the inflammatory mediators...
#
#                                       predicted_queries
# 0     ["Preterm infants show differences in cerebral...
# 1     [Myeloid-derived suppressor cells (MDSCs) in t...
# 2     [The presence of ID elements in high copy numb...
# 3     [Inositol lipid 3-phosphatase PTEN converts Pt...
# 4     ["The expression of the MBP gene, encoding mye...
# ...                                                 ...
# 5178  [Vitamin E and C supplements have been shown t...
# 5179  [Glioblastoma cells exploit metabolic aberrati...
# 5180  ["A signaling pathway that regulates cell divi...
# 5181  [Type 2 diabetes increases trabecular bone sco...
# 5182  [P-selectin, E-selectin, and VCAM-1 are cell a...
#
# [5183 rows x 3 columns]

# %%
import json
corpus = []
with open("/home/guest/r12922050/GitHub/d2qplus/gen/nfcorpus_gen_10q_text_only.jsonl", "r") as f:
    lines = f.readlines()
    for line in lines:
        data = json.loads(line)
        corpus.append(data)

# %%
# for each corpus entry, change queries key to "predicted_queries"
for entry in corpus:
    entry['id'] = entry.pop('doc_id')
    # entry["predicted_queries"] = entry.pop("queries")

# %%
with open("/home/guest/r12922050/GitHub/d2qplus/gen/nfcorpus_gen_10q_text_only.jsonl", "w") as f:
    for entry in corpus:
        json.dump(entry, f)
        f.write("\n")

# %% [markdown]
# ## Split the corpus into smaller set

# %%
CORPUS_PATH = "/home/guest/r12922050/GitHub/d2qplus/data/fiqa/corpus_all.jsonl"
import json
with open(CORPUS_PATH, "r") as f:
    all_corpus =[json.loads(line) for line in f.readlines()]
    
did22doc = {doc['_id']: doc for doc in all_corpus}
print(len(all_corpus))

CORPUS_CUT_PATH = "/home/guest/r12922050/GitHub/d2qplus/data/fiqa/corpus.jsonl"
with open(CORPUS_CUT_PATH, "r") as f:
    corpus_cut = [json.loads(line) for line in f.readlines()]
print(len(corpus_cut))

all_doc_ids = set(doc['_id'] for doc in all_corpus)
corpus_cut_ids = set(doc['_id'] for doc in corpus_cut)
missing_ids = all_doc_ids - corpus_cut_ids
print(f"Missing IDs: {len(missing_ids)}")

GOAL_CORPUS_NUM = 10000
# from missing ids, randomly pick GOAL_CORPUS_NUM - len(corpus_cut) ids
import random
missing_ids = list(missing_ids)
random.shuffle(missing_ids)
selected_ids = missing_ids[:GOAL_CORPUS_NUM - len(corpus_cut)]
selected_docs = [did22doc[doc_id] for doc_id in selected_ids if doc_id in did22doc]
# append selected_docs to corpus_cut
corpus_cut.extend(selected_docs)
# write corpus_cut to file
with open("/home/guest/r12922050/GitHub/d2qplus/data/fiqa/corpus_1w.jsonl", "w") as f:
    for doc in corpus_cut:
        json.dump(doc, f)
        f.write("\n")
# Out:
# 57638
# 4000
# Missing IDs: 53638

# %%
import pandas as pd
import json
import random
import numpy as np
import os
from collections import defaultdict
from typing import Set, List, Dict, Tuple
import pyterrier as pt
from pyterrier_pisa import PisaIndex
from tqdm import tqdm

def get_hard_negatives_with_bm25(
    corpus_docs: Dict, 
    relevant_docs: Set[str], 
    query_ids: List[str],
    queries_path: str,
    count: int,
    temp_index_dir: str = "./temp_bm25_index"
) -> Set[str]:
    """
    使用BM25檢索獲取真正的hard negative documents
    
    Args:
        corpus_docs: 所有文檔的字典
        relevant_docs: 已知相關文檔的集合
        query_ids: 選中的query IDs
        queries_path: queries文件路徑
        count: 需要的hard negative數量
        temp_index_dir: 臨時index目錄
    
    Returns:
        Set[str]: hard negative文檔ID集合
    """
    try:
        # 載入queries
        if not queries_path or not os.path.exists(queries_path):
            print("No queries file available, using random selection for hard negatives")
            return get_hard_negatives(corpus_docs, relevant_docs, query_ids, queries_path, count)
        
        with open(queries_path, 'r', encoding='utf-8') as f:
            all_queries = [json.loads(line) for line in f]
        
        query_dict = {str(q.get('_id', q.get('qid'))): q.get('text', q.get('query', '')) for q in all_queries}
        selected_queries = [(qid, query_dict.get(qid, '')) for qid in query_ids if qid in query_dict]
        
        if not selected_queries:
            print("No matching queries found, using random selection for hard negatives")
            return get_hard_negatives(corpus_docs, relevant_docs, query_ids, queries_path, count)
        
        print(f"Building temporary BM25 index for hard negative mining...")
        
        # 準備文檔數據供索引
        docs_for_index = []
        for doc_id, doc in corpus_docs.items():
            if doc_id not in relevant_docs:  # 只索引非相關文檔
                text = doc.get('text', '') + ' ' + doc.get('title', '')
                docs_for_index.append({
                    'docno': str(doc_id),
                    'text': text.strip()
                })
        
        if len(docs_for_index) < count:
            print(f"Not enough non-relevant documents ({len(docs_for_index)}) for hard negatives")
            return set([doc['docno'] for doc in docs_for_index])
        
        # 使用PISA建立臨時索引
        os.makedirs(temp_index_dir, exist_ok=True)
        pisa_index = PisaIndex(temp_index_dir, overwrite=True)
        pisa_index.index(docs_for_index)
        
        # 用BM25檢索器
        bm25 = pisa_index.bm25(b=0.4, k1=0.9, num_results=min(1000, len(docs_for_index)))
        
        # 收集hard negatives
        hard_negatives = set()
        candidates_per_query = max(1, count // len(selected_queries))
        
        for qid, query_text in selected_queries:
            if not query_text.strip():
                continue
                
            # 檢索
            query_df = pd.DataFrame([{'qid': qid, 'query': query_text}])
            try:
                results = bm25.transform(query_df)
                
                # 取top-K作為hard negatives (這些是BM25認為相關但實際不相關的)
                top_docs = results.head(candidates_per_query)['docno'].tolist()
                hard_negatives.update(top_docs)
                
                if len(hard_negatives) >= count:
                    break
                    
            except Exception as e:
                print(f"Error retrieving for query {qid}: {e}")
                continue
        
        # 如果還不夠，補充隨機文檔
        if len(hard_negatives) < count:
            remaining = count - len(hard_negatives)
            available_docs = set([doc['docno'] for doc in docs_for_index]) - hard_negatives
            additional = set(random.sample(list(available_docs), min(remaining, len(available_docs))))
            hard_negatives.update(additional)
        
        # 清理臨時索引
        try:
            import shutil
            shutil.rmtree(temp_index_dir)
        except:
            pass
        
        print(f"Found {len(hard_negatives)} hard negatives using BM25")
        return hard_negatives
        
    except Exception as e:
        print(f"Error in BM25 hard negative mining: {e}")
        print("Falling back to random selection")
        return get_hard_negatives(corpus_docs, relevant_docs, query_ids, queries_path, count)

def create_small_corpus_with_bm25_hard_negatives(
    corpus_path: str,
    qrels_path: str,
    queries_path: str = None,
    target_corpus_size: int = 10000,
    num_queries: int = 100,
    hard_negative_ratio: float = 0.3,
    random_seed: int = 42
) -> Dict:
    """
    創建固定大小的小corpus，使用真正的BM25檢索來獲取hard negatives
    """
    random.seed(random_seed)
    np.random.seed(random_seed)
    
    print(f"Loading corpus from {corpus_path}...")
    # 載入corpus
    corpus_docs = {}
    with open(corpus_path, 'r', encoding='utf-8') as f:
        for line in f:
            doc = json.loads(line)
            doc_id = doc.get('_id') or doc.get('id')
            corpus_docs[doc_id] = doc
    
    print(f"Loaded {len(corpus_docs)} documents")
    
    # 載入qrels
    print(f"Loading qrels from {qrels_path}...")
    qrels_df = pd.read_csv(qrels_path, sep='\t')
    if 'qid' not in qrels_df.columns:
        qrels_df.columns = ['qid', 'docno', 'label'] if len(qrels_df.columns) == 3 else ['qid', 'Q0', 'docno', 'label']
    
    # 只保留正相關的qrels
    positive_qrels = qrels_df[qrels_df['label'] > 0]
    
    # 構建query -> relevant_docs mapping
    query_to_docs = defaultdict(set)
    for _, row in positive_qrels.iterrows():
        query_to_docs[str(row['qid'])].add(str(row['docno']))
    
    # 選擇有足夠相關文檔的queries
    valid_queries = [qid for qid, docs in query_to_docs.items() if len(docs) >= 2]
    
    if len(valid_queries) < num_queries:
        print(f"Warning: Only {len(valid_queries)} valid queries found, using all of them")
        num_queries = len(valid_queries)
    
    # 隨機選擇queries
    selected_query_ids = random.sample(valid_queries, num_queries)
    print(f"Selected {len(selected_query_ids)} queries")
    
    # 收集所有相關文檔
    relevant_docs = set()
    for qid in selected_query_ids:
        relevant_docs.update(query_to_docs[qid])
    
    relevant_docs = {doc_id for doc_id in relevant_docs if doc_id in corpus_docs}
    print(f"Found {len(relevant_docs)} relevant documents")
    
    # 計算需要的hard negative和random文檔數量
    remaining_slots = target_corpus_size - len(relevant_docs)
    if remaining_slots <= 0:
        print(f"Relevant documents ({len(relevant_docs)}) already exceed target size ({target_corpus_size})")
        corpus_small = {doc_id: corpus_docs[doc_id] for doc_id in list(relevant_docs)[:target_corpus_size]}
        hard_negatives = set()
        random_docs = set()
    else:
        # 添加hard negatives (使用真正的BM25檢索)
        hard_negative_count = int(remaining_slots * hard_negative_ratio)
        random_count = remaining_slots - hard_negative_count
        
        print(f"Adding {hard_negative_count} BM25 hard negatives and {random_count} random documents")
        
        # 獲取hard negatives (使用BM25)
        hard_negatives = get_hard_negatives_with_bm25(
            corpus_docs, 
            relevant_docs, 
            selected_query_ids, 
            queries_path,
            hard_negative_count
        )
        
        # 獲取random documents
        available_docs = set(corpus_docs.keys()) - relevant_docs - hard_negatives
        random_docs = set(random.sample(list(available_docs), min(random_count, len(available_docs))))
        
        # 組合最終的corpus
        final_doc_ids = relevant_docs | hard_negatives | random_docs
        corpus_small = {doc_id: corpus_docs[doc_id] for doc_id in final_doc_ids}
    
    # 創建filtered qrels
    qrels_small = qrels_df[
        (qrels_df['qid'].astype(str).isin(selected_query_ids)) & 
        (qrels_df['docno'].astype(str).isin(corpus_small.keys()))
    ]
    
    # 載入selected queries (如果有queries文件)
    selected_queries = None
    if queries_path and os.path.exists(queries_path):
        with open(queries_path, 'r', encoding='utf-8') as f:
            all_queries = [json.loads(line) for line in f]
        selected_queries = [q for q in all_queries if str(q.get('_id', q.get('qid'))) in selected_query_ids]
    
    result = {
        'corpus_small': corpus_small,
        'qrels_small': qrels_small,
        'selected_queries': selected_queries,
        'selected_query_ids': selected_query_ids,
        'stats': {
            'total_docs': len(corpus_small),
            'relevant_docs': len(relevant_docs),
            'hard_negatives': len(hard_negatives),
            'random_docs': len(random_docs),
            'num_queries': len(selected_query_ids),
            'num_qrels': len(qrels_small)
        }
    }
    
    print("\n=== Corpus Splitting Statistics (with BM25 Hard Negatives) ===")
    for key, value in result['stats'].items():
        print(f"{key}: {value}")
    
    return result

def save_small_corpus(result: Dict, output_dir: str, dataset_name: str):
    """
    保存切分後的小corpus到文件
    
    Args:
        result: create_small_corpus_*函數的返回結果
        output_dir: 輸出目錄
        dataset_name: 數據集名稱
    """
    os.makedirs(output_dir, exist_ok=True)
    
    # 保存corpus
    corpus_path = os.path.join(output_dir, f"{dataset_name}_corpus_small.jsonl")
    with open(corpus_path, 'w', encoding='utf-8') as f:
        for doc_id, doc in result['corpus_small'].items():
            # 確保doc有正確的id字段
            if '_id' not in doc and 'id' not in doc:
                doc['_id'] = doc_id
            f.write(json.dumps(doc, ensure_ascii=False) + '\n')
    
    # 保存qrels
    qrels_path = os.path.join(output_dir, f"{dataset_name}_qrels_small.tsv")
    result['qrels_small'].to_csv(qrels_path, sep='\t', index=False)
    
    # 保存queries (如果有)
    if result['selected_queries']:
        queries_path = os.path.join(output_dir, f"{dataset_name}_queries_small.jsonl")
        with open(queries_path, 'w', encoding='utf-8') as f:
            for query in result['selected_queries']:
                f.write(json.dumps(query, ensure_ascii=False) + '\n')
    
    # 保存統計信息
    stats_path = os.path.join(output_dir, f"{dataset_name}_split_stats.json")
    with open(stats_path, 'w', encoding='utf-8') as f:
        json.dump(result['stats'], f, indent=2, ensure_ascii=False)
    
    print(f"\nSaved small corpus to {output_dir}:")
    print(f"- Corpus: {corpus_path}")
    print(f"- Qrels: {qrels_path}")
    if result['selected_queries']:
        print(f"- Queries: {queries_path}")
    print(f"- Stats: {stats_path}")

print("Dataset splitting functions loaded successfully!")
# Out:
# Dataset splitting functions loaded successfully!

# %% [markdown]
# ## Create Small Corpus with BM25 Hard Negatives - FiQA Example

# %%
# Example usage: Create small FiQA corpus with BM25 hard negatives
corpus_path = "/home/guest/r12922050/GitHub/d2qplus/data/fiqa/corpus_all.jsonl"
qrels_path = "/home/guest/r12922050/GitHub/d2qplus/data/fiqa/qrels/test_all.tsv"
queries_path = "/home/guest/r12922050/GitHub/d2qplus/data/fiqa/queries_all.jsonl"  # Update this path if needed
output_dir = "/home/guest/r12922050/GitHub/d2qplus/data/fiqa-bm25-5000"

# Create small corpus with BM25 hard negatives
result = create_small_corpus_with_bm25_hard_negatives(
    corpus_path=corpus_path,
    qrels_path=qrels_path,
    queries_path=queries_path,
    target_corpus_size=5000,  # Smaller size for demonstration
    num_queries=500,           # Select 50 queries
    hard_negative_ratio=0.6,  # 40% hard negatives, 60% random
    random_seed=42
)

# Save the results
save_small_corpus(result, output_dir, "fiqa")

# Display detailed statistics
print("\n=== Detailed Statistics ===")
print(f"Original corpus size: {len(all_corpus)}")
print(f"Small corpus size: {result['stats']['total_docs']}")
print(f"Relevant documents: {result['stats']['relevant_docs']}")
print(f"BM25 hard negatives: {result['stats']['hard_negatives']}")
print(f"Random documents: {result['stats']['random_docs']}")
print(f"Selected queries: {result['stats']['num_queries']}")
print(f"Filtered qrels: {result['stats']['num_qrels']}")

# Show some examples of selected queries (if available)
if result['selected_queries']:
    print(f"\n=== Sample Selected Queries ===")
    for i, query in enumerate(result['selected_queries'][:3]):
        qid = query.get('_id') or query.get('qid')
        text = query.get('text') or query.get('query', '')
        print(f"Query {i+1} (ID: {qid}): {text[:100]}...")
# Out:
# Loading corpus from /home/guest/r12922050/GitHub/d2qplus/data/fiqa/corpus_all.jsonl...
# Loaded 57638 documents
# Loading qrels from /home/guest/r12922050/GitHub/d2qplus/data/fiqa/qrels/test_all.tsv...
# Warning: Only 428 valid queries found, using all of them
# Selected 428 queries
# Found 1486 relevant documents
# Adding 2108 BM25 hard negatives and 1406 random documents
# Building temporary BM25 index for hard negative mining...
# /home/guest/r12922050/miniconda3/envs/d2qplus/lib/python3.9/site-packages/pyterrier_pisa/__init__.py:144: UserWarning: text_field not specified; indexing all str fields: ['text']
#   warn(f'text_field not specified; indexing all str fields: {text_field}')
# [2025-06-12 17:52:24.013] [info] [Batch 0] Processed documents [0, 56152)
# [2025-06-12 17:52:24.041] [info] Merging titles
# [2025-06-12 17:52:24.046] [info] Creating document lexicon
# [2025-06-12 17:52:24.060] [info] Merging URLs
# [2025-06-12 17:52:24.062] [info] Collecting terms
# [2025-06-12 17:52:24.080] [info] Writing terms
# [2025-06-12 17:52:24.102] [info] Mapping terms
# [2025-06-12 17:52:24.109] [info] Remapping IDs
# [2025-06-12 17:52:24.529] [info] Concatenating batches
# [2025-06-12 17:52:24.556] [info] Success.
# [2025-06-12 17:52:24.821] [info] Inverting [0, 56152)
# [2025-06-12 17:52:25.902] [info] Number of terms: 55336
# [2025-06-12 17:52:25.902] [info] Number of documents: 56152
# [2025-06-12 17:52:25.902] [info] Number of postings: 4432907
# Storing terms statistics: 100% [0s]
# Storing score upper bounds: 100% [0s]
# Create index: 100% [0s]
# [2025-06-12 17:52:26.235] [info] Dropping 0 terms
# Error retrieving for query 7747: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# [2025-06-12 17:52:26.235] [info] Reading sizes...
# [2025-06-12 17:52:26.235] [info] Storing max weight for each list and for each block...
# [2025-06-12 17:52:26.282] [info] number of elements / number of blocks: 37.2085
# [2025-06-12 17:52:26.307] [info] Processing 56152 documents (streaming)
# ./temp_bm25_index/bm25.k1-0.9.b-0.4.q0.bmw.64.block_simdbp
# [2025-06-12 17:52:26.396] [info] Index compressed in 0.089224 seconds
# Error retrieving for query 1994: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 620: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 9291: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 3612: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 3254: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 3051: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 2330: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 9188: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 1812: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 8247: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 10979: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 6562: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 1393: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 7098: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 5083: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 687: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 672: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 1530: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 3014: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 3148: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 6041: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 7279: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 622: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 6713: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 2856: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 8934: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 7880: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 8632: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 10639: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 4999: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 3033: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 5356: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 7080: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 3625: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 89: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 9633: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 2423: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 8544: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 10526: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 4205: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 9737: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 2407: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 3008: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 4125: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 10734: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 10447: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 4523: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 1676: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 4394: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 4265: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 7329: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 3503: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 766: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 9108: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 5460: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 6467: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 2108: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 4514: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 1309: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 6635: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 3771: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 7633: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 7529: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 4411: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 6890: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 2749: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 8635: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 1085: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 776: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 8002: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 3085: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 3759: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 8970: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 10267: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 1748: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 9296: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 9565: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 5410: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 7705: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 4414: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 2465: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 4465: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 4335: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 2968: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 3512: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 7879: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 1090: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 7345: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 8296: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 2551: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 6420: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 10812: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 10674: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 5464: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 8378: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 3566: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 11054: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 6679: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 9871: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 4037: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 859: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 3091: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 10497: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 3934: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 4823: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 3530: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 957: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 2994: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 6803: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 7700: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 7590: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 5993: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 4714: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 5427: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 2348: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 9164: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 10808: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 3264: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 10136: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 6468: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 3500: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 7068: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 5172: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 6959: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 4804: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 8789: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 7801: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 2316: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 6110: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 5951: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 1441: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 813: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 1915: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 2400: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 9668: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 9701: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 932: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 4605: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 4539: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 5534: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 6252: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 3394: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 6647: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 104: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 2010: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 9060: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 8102: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 9617: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 11039: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 10109: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 5196: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 2416: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 8332: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 26: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 7145: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 6002: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 2589: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 6080: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 1826: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 3789: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 6221: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 10122: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 6835: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 4500: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 2460: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 8: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 4019: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 5906: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 588: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 6554: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 9771: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 3875: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 2076: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 659: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 5981: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 5241: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 3694: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 5646: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 750: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 753: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 4415: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 3189: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 4845: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 701: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 10034: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 6611: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 4571: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 7534: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 10213: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 4084: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 3177: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 10827: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 1322: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 2264: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 8013: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 5206: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 3822: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 8834: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 6219: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 8079: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 8974: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 8271: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 10792: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 8456: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 4339: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 9481: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 2857: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 4116: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 7823: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 2685: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 7071: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 3453: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 3067: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 885: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 8982: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 6005: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 7702: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 2549: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 6668: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 6525: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 3615: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 8947: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 4844: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 6867: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 7936: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 715: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 8202: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 7533: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 10462: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 7674: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 5683: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 585: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 2472: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 4681: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 3451: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 2075: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 7344: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 7124: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 5763: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 5271: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 5264: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 7622: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 3724: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 3735: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 7911: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 2088: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 6479: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 2895: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 1670: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 8779: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 4286: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 5503: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 9403: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 2580: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 9808: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 2923: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 8475: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 10183: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 4047: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 7109: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 852: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 4615: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 2885: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 4846: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 858: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 4962: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 10645: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 4289: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 8855: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 10809: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 9979: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 9391: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 6891: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 4499: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 3115: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 4640: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 744: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 3049: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 9088: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 5134: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 10994: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 5254: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 9733: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 8592: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 6131: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 7445: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 4306: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 4433: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 3186: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 5782: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 5178: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 4233: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 4837: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 2724: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 6121: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 2790: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 5422: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 8539: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 7441: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 5369: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 2579: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 3179: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 2593: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 2801: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 3791: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 5888: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 6683: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 4641: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 10558: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 5940: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 1150: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 3995: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 547: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 2376: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 2598: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 2306: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 7513: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 5090: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 8507: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 9929: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 504: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 3767: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 6901: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 2181: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 3446: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 5862: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 8116: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 2183: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 594: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 3682: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 6715: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 2385: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 2713: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 4007: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 4981: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 5402: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 6612: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 2334: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 928: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 8230: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 3006: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 5741: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 5185: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 8702: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 1819: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 7992: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 9174: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 2204: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 3369: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 6262: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 853: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 6133: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 2590: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 2398: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 1736: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 4863: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 1157: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 6746: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 2383: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 10246: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 7463: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 10414: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 4409: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 5620: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 988: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 4102: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 5511: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 7928: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 6814: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 9115: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 4767: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 98: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 4142: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 3480: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 5255: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 7925: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 7734: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 4105: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 1415: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 6199: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 1306: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 1321: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 7803: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 5064: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 6278: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 3829: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 9329: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 2964: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 4504: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 2070: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 6146: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 3801: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 3781: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 5549: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 9381: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 8532: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 4920: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 3149: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 3909: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 5853: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 6142: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 7141: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 3404: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 3888: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 9275: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 4312: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 42: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 2568: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 6832: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 9925: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 1391: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 864: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 4011: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 3594: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 6122: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 1871: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 2296: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 8072: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 8351: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 7206: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 604: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 9646: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 2516: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 3932: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 5970: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 3683: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Error retrieving for query 10596: You need to call pt.java.init() required before you can call <function autoclass at 0x7f274a287820>
# Found 2108 hard negatives using BM25
#
# === Corpus Splitting Statistics (with BM25 Hard Negatives) ===
# total_docs: 5000
# relevant_docs: 1486
# hard_negatives: 2108
# random_docs: 1406
# num_queries: 428
# num_qrels: 1486
#
# Saved small corpus to /home/guest/r12922050/GitHub/d2qplus/data/fiqa-bm25-5000:
# - Corpus: /home/guest/r12922050/GitHub/d2qplus/data/fiqa-bm25-5000/fiqa_corpus_small.jsonl
# - Qrels: /home/guest/r12922050/GitHub/d2qplus/data/fiqa-bm25-5000/fiqa_qrels_small.tsv
# - Queries: /home/guest/r12922050/GitHub/d2qplus/data/fiqa-bm25-5000/fiqa_queries_small.jsonl
# - Stats: /home/guest/r12922050/GitHub/d2qplus/data/fiqa-bm25-5000/fiqa_split_stats.json
#
# === Detailed Statistics ===
# Original corpus size: 57638
# Small corpus size: 5000
# Relevant documents: 1486
# BM25 hard negatives: 2108
# Random documents: 1406
# Selected queries: 428
# Filtered qrels: 1486
#
# === Sample Selected Queries ===
# Query 1 (ID: 4641): Where should I park my rainy-day / emergency fund?...
# Query 2 (ID: 5503): Tax considerations for selling a property below appraised value to family?...
# Query 3 (ID: 7803): Can the Delta be used to calculate the option premium given a certain target?...

# %% [markdown]
# ### QRELS CSV to TREC

# %%
QRELS_CSV = "/home/guest/r12922050/GitHub/d2qplus/data/fiqa-bm25-5000/test.tsv"
OUTPUT_PATH = "/home/guest/r12922050/GitHub/d2qplus/data/fiqa-bm25-5000/qrels/test.trec"
import pandas as pd
import os

# if output directory does not exist, create it
if not os.path.exists(os.path.dirname(OUTPUT_PATH)):
    os.makedirs(os.path.dirname(OUTPUT_PATH))
qrels_df = pd.read_csv(QRELS_CSV, sep='\t')

# transform to trec format
qrels_df['Q0'] = '0'  # Add a dummy Q0 column
qrels_df = qrels_df[['qid', 'Q0', 'docno', 'label']]

# save to .trec
qrels_df.to_csv(OUTPUT_PATH, sep=' ', index=False, header=False)
