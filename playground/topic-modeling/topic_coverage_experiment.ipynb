# %% [markdown]
# # Topic Coverage Experiment
# In this notebook, I want to see whether my Topic Coverage query generation method translates to higher retrieval recall

# %%
import pandas as pd
qrels = pd.read_csv("/home/guest/r12922050/GitHub/d2qplus/data/nfcorpus/qrels/test.tsv", sep="\t")
# only keep rows with score > 0
qrels = qrels[qrels['score'] > 0]
qrels

# %%
doc_to_queries = (
    qrels.groupby("corpus-id")["query-id"]
         .apply(list)                     # list of queries per doc
         .to_dict()
)
eligible_docs = set(doc_to_queries)       # docs that have ≥1 relevant query
print(f"{len(eligible_docs):,} documents have at least one relevant query")
# Out:
# 3,128 documents have at least one relevant query

# %%
#!/usr/bin/env python
# sample_docs_no_pathlib.py
import json
import random
import pickle
import pandas as pd

# ---------- file names ----------
CORPUS_PATH   = "/home/guest/r12922050/GitHub/d2qplus/data/nfcorpus/corpus.jsonl"
QRELS_PATH    = "/home/guest/r12922050/GitHub/d2qplus/data/nfcorpus/qrels/test.tsv"          # change if comma-separated
QUERIES_PATH = "/home/guest/r12922050/GitHub/d2qplus/data/nfcorpus/queries.jsonl"
OUT_DOCS      = "./sampled_docs.jsonl"

# ---------- parameters ----------
SAMPLE_SIZE   = 1000
RANDOM_SEED   = 42                   # reproducible sampling

# ---------- 1. load qrels ----------
qrels = pd.read_csv(QRELS_PATH, sep="\t")

qrels["score"] = qrels["score"].astype(int)   # <- cast to int
qrels = qrels.query("score > 0")             # keep only relevant pairs

doc_to_queries_full = (
    qrels.groupby("corpus-id")["query-id"]
         .apply(list)
         .to_dict()
)

eligible_docs = set(doc_to_queries_full)
print(f"{len(eligible_docs):,} documents with ≥1 relevant query")

# ---------- 2. stream-read the corpus & keep eligible ----------
docs = []
with open(CORPUS_PATH, "r", encoding="utf-8") as f:
    for line in f:
        obj = json.loads(line)
        if obj["_id"] in eligible_docs:
            docs.append(obj)

print(f"Loaded {len(docs):,} eligible documents")

# random sample documents
random.seed(RANDOM_SEED)
sampled_docs = random.sample(docs, SAMPLE_SIZE)

# construct qid -> query_text mapping
with open(QUERIES_PATH, "r", encoding="utf-8") as f:
    queries = [json.loads(line) for line in f]
query_to_text = {q["_id"]: q["text"] for q in queries}

out = []
for doc in sampled_docs:
    json_obj = {
        "doc_id": doc["_id"],
        "title": doc["title"],
        "text": doc["text"],
        "queries": [query_to_text[qid] for qid in doc_to_queries_full[doc["_id"]]]
    }
    out.append(json_obj)
with open(OUT_DOCS, "w", encoding="utf-8") as f:
    for obj in out:
        f.write(json.dumps(obj, ensure_ascii=False) + "\n")
print(f"Saved {len(out):,} sampled documents to {OUT_DOCS}")
# Out:
# 3,128 documents with ≥1 relevant query
# Loaded 3,128 eligible documents
# Saved 1,000 sampled documents to ./sampled_docs.jsonl

# %%
docs[0]
# Out:
# {'_id': 'MED-10',
#  'title': 'Statin Use and Breast Cancer Survival: A Nationwide Cohort Study from Finland',
#  'text': 'Recent studies have suggested that statins, an established drug group in the prevention of cardiovascular mortality, could delay or prevent breast cancer recurrence but the effect on disease-specific mortality remains unclear. We evaluated risk of breast cancer death among statin users in a population-based cohort of breast cancer patients. The study cohort included all newly diagnosed breast cancer patients in Finland during 1995–2003 (31,236 cases), identified from the Finnish Cancer Registry. Information on statin use before and after the diagnosis was obtained from a national prescription database. We used the Cox proportional hazards regression method to estimate mortality among statin users with statin use as time-dependent variable. A total of 4,151 participants had used statins. During the median follow-up of 3.25 years after the diagnosis (range 0.08–9.0 years) 6,011 participants died, of which 3,619 (60.2%) was due to breast cancer. After adjustment for age, tumor characteristics, and treatment selection, both post-diagnostic and pre-diagnostic statin use were associated with lowered risk of breast cancer death (HR 0.46, 95% CI 0.38–0.55 and HR 0.54, 95% CI 0.44–0.67, respectively). The risk decrease by post-diagnostic statin use was likely affected by healthy adherer bias; that is, the greater likelihood of dying cancer patients to discontinue statin use as the association was not clearly dose-dependent and observed already at low-dose/short-term use. The dose- and time-dependence of the survival benefit among pre-diagnostic statin users suggests a possible causal effect that should be evaluated further in a clinical trial testing statins’ effect on survival in breast cancer patients.',
#  'metadata': {'url': 'http://www.ncbi.nlm.nih.gov/pubmed/25329299'}}

# %% [markdown]
# ## RQ: Do the BERTopic topics I extracted line up with the real (test-set) queries that were judged relevant for each document?

# %%
import pandas as pd
topic_model = pd.read_pickle("/home/guest/r12922050/GitHub/d2qplus/topics/nfcorpus/topic_model_sentence_enhanced.pickle")
topic_model
# Out:
#       Topic  Count                                       Name  \
# 0        -1  10153                     -1_diet_were_fat_these
# 1         0    280                 0_no_any_there_differences
# 2         1    250  1_antioxidant_antioxidants_capacity_assay
# 3         2    207          2_cholesterol_lipoprotein_hdl_ldl
# 4         3    151             3_ncds_communicable_ncd_public
# ...     ...    ...                                        ...
# 1283   1282      5                         1282_spl_c22_5n_ps
# 1284   1283      5      1283_plentiful_ironically_easy_access
# 1285   1284      5          1284_offensive_guard_rear_essence
# 1286   1285      5                     1285_ra_offal_877_1968
# 1287   1286      5                 1286_deaths_1348_1469_3694
#
#                                          Representation  \
# 0     [diet, were, fat, these, and, was, for, the, a...
# 1     [no, any, there, differences, observed, signif...
# 2     [antioxidant, antioxidants, capacity, assay, r...
# 3     [cholesterol, lipoprotein, hdl, ldl, density, ...
# 4     [ncds, communicable, ncd, public, world, polic...
# ...                                                 ...
# 1283  [spl, c22, 5n, ps, pe, omnivores, pc, sphingo,...
# 1284  [plentiful, ironically, easy, access, produces...
# 1285  [offensive, guard, rear, essence, strategy, de...
# 1286  [ra, offal, 877, 1968, correlations, 1978, lin...
# 1287  [deaths, 1348, 1469, 3694, datalink, 1171, 881...
#
#                                     Representative_Docs  \
# 0     [For the 0, 300, and 600 mg/day SDG groups, re...
# 1     [There were no significant changes in body wei...
# 2     [DESIGN: The ferric-reducing ability of plasma...
# 3     [Before the intervention and at 4 and 8 weeks ...
# 4     [Effective approaches for large-scale NCD prev...
# ...                                                 ...
# 1283  [The concentrations of the fatty acids 20:3n-6...
# 1284  [To assess the direct effect of postprandial t...
# 1285  [In essence, this is an offensive strategy., T...
# 1286  [It is hypothesized that meat and offal may be...
# 1287  [Results: From 1987 to 2008 there were 385 bre...
#
#                                          Enhanced_Topic
# 0     Effects of SDG on Prostate Symptoms and Mortality
# 1       No significant changes observed in study groups
# 2              Antioxidant capacity and activity assays
# 3              Lipid profile changes after intervention
# 4     Non-communicable disease prevention and contro...
# ...                                                 ...
# 1283  Effects of dietary fat intake on n-3 and n-6 f...
# 1284        Effects of high-fat diet on atherosclerosis
# 1285                        Military Defensive Strategy
# 1286  Association between meat consumption and rheum...
# 1287    Breast cancer mortality and recurrence analysis
#
# [1288 rows x 6 columns]

# %%
topic_model_info = {}
for idx, row in topic_model.iterrows():
    topic_model_info[row['Topic']] = {
        'Representation': row['Representation'], # list of words
        'Representative_Docs': row['Representative_Docs'], # list of sentences
        'Enhanced_Topic': row['Enhanced_Topic'],
    }

# %%
from sentence_transformers import SentenceTransformer
model_name = "sentence-transformers/all-mpnet-base-v2"
embedder = SentenceTransformer(model_name, device="cuda:2")
def embed(texts):            # helper that always returns L2-normalised vectors
    return embedder.encode(texts, convert_to_numpy=True, normalize_embeddings=True)

# embed for each topic
for topic, info in topic_model_info.items():
    rep = " ".join(info['Representation'])
    info['Representation_Embed'] = embed([rep])[0]
    info['Enhanced_Topic_Embed'] = embed([info['Enhanced_Topic']])[0]

    info['Rep_Enhanced_Embed'] = embed([rep+" "+info['Enhanced_Topic']])[0]

# %%
with open("/home/guest/r12922050/GitHub/d2qplus/playground/topic-modeling/sampled_docs.jsonl", "r") as f:
    sampled_docs = [json.loads(line) for line in f]
sampled_docs[0]
# Out:
# {'doc_id': 'MED-4635',
#  'title': 'Globalization, diet, and health: an example from Tonga.',
#  'text': "The increased flow of goods, people, and ideas associated with globalization have contributed to an increase in noncommunicable diseases in much of the world. One response has been to encourage lifestyle changes with educational programmes, thus controlling the lifestyle-related disease. Key assumptions with this approach are that people's food preferences are linked to their consumption patterns, and that consumption patterns can be transformed through educational initiatives. To investigate these assumptions, and policies that derive from it, we undertook a broad-based survey of food-related issues in the Kingdom of Tonga using a questionnaire. Data on the relationships between food preferences, perception of nutritional value, and frequency of consumption were gathered for both traditional and imported foods. The results show that the consumption of health-compromising imported foods was unrelated either to food preferences or to perceptions of nutritional value, and suggests that diet-related diseases may not be amenable to interventions based on education campaigns. Given recent initiatives towards trade liberalization and the creation of the World Trade Organization, tariffs or import bans may not serve as alternative measures to control consumption. This presents significant challenges to health policy-makers serving economically marginal populations and suggests that some population health concerns cannot be adequately addressed without awareness of the effects of global trade.",
#  'queries': ['Stool Size and Breast Cancer Risk',
#   'Japan',
#   'taro',
#   'Kiwifruit for Irritable Bowel Syndrome']}

# %%
# calculate average cosine similarity of queries to topic representation
with open("/home/guest/r12922050/GitHub/d2qplus/topics/nfcorpus/enhanced_rep_sentence.jsonl", "r") as f:
    doc_topic_info = [json.loads(line) for line in f]
doc_topic_info_dict = {doc["doc_id"]: doc['topics'] for doc in doc_topic_info}
doc_topic_info_dict['MED-10']
# Out:
# [{'topic_id': 526, 'weight': 0.428571},
#  {'topic_id': 96, 'weight': 0.142857},
#  {'topic_id': 1021, 'weight': 0.428571}]

# %%
import numpy as np
avg_cosine_sim = {} # doc_id -> avg cosine similarity
for doc in sampled_docs:
    doc_id = doc['doc_id']
    doc_text = doc['text']
    doc_title = doc['title']
    queries = doc['queries'] # list of queries
    topic_ids = [t['topic_id'] for t in doc_topic_info_dict[doc_id]]
    cosine_sims = []
    for topic_id in topic_ids:
        topic_info = topic_model_info[topic_id]
        rep_embed = topic_info['Representation_Embed']
        enhanced_embed = topic_info['Enhanced_Topic_Embed']
        rep_enhanced_embed = topic_info['Rep_Enhanced_Embed']
        for query in queries:
            query_embed = embed([query])[0]
            cosine_sim_rep = (query_embed @ rep_embed) / (np.linalg.norm(query_embed) * np.linalg.norm(rep_embed))
            cosine_sim_enhanced = (query_embed @ enhanced_embed) / (np.linalg.norm(query_embed) * np.linalg.norm(enhanced_embed))
            cosine_sim_rep_enhanced = (query_embed @ rep_enhanced_embed) / (np.linalg.norm(query_embed) * np.linalg.norm(rep_enhanced_embed))
            cosine_sims.append((cosine_sim_rep, cosine_sim_enhanced, cosine_sim_rep_enhanced))
    avg_cosine_sim[doc_id] = {
        'avg_cosine_sim_rep': np.mean([sim[0] for sim in cosine_sims]),
        'avg_cosine_sim_enhanced': np.mean([sim[1] for sim in cosine_sims]),
        'avg_cosine_sim_rep_enhanced': np.mean([sim[2] for sim in cosine_sims]),
    }
avg_cosine_sim
# Out:
# /home/guest/r12922050/miniconda3/envs/bertopic/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/guest/r12922050/miniconda3/envs/bertopic/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# {'MED-4635': {'avg_cosine_sim_rep': 0.07250403,
#   'avg_cosine_sim_enhanced': 0.06542132,
#   'avg_cosine_sim_rep_enhanced': 0.06145745},
#  'MED-1578': {'avg_cosine_sim_rep': 0.17333111,
#   'avg_cosine_sim_enhanced': 0.17362395,
#   'avg_cosine_sim_rep_enhanced': 0.16370457},
#  'MED-1150': {'avg_cosine_sim_rep': 0.15503637,
#   'avg_cosine_sim_enhanced': 0.100239694,
#   'avg_cosine_sim_rep_enhanced': 0.14868991},
#  'MED-5152': {'avg_cosine_sim_rep': 0.15824738,
#   'avg_cosine_sim_enhanced': 0.16387501,
#   'avg_cosine_sim_rep_enhanced': 0.15147369},
#  'MED-2421': {'avg_cosine_sim_rep': 0.11859123,
#   'avg_cosine_sim_enhanced': 0.09196148,
#   'avg_cosine_sim_rep_enhanced': 0.10999618},
#  'MED-2260': {'avg_cosine_sim_rep': 0.18008839,
#   'avg_cosine_sim_enhanced': 0.13388796,
#   'avg_cosine_sim_rep_enhanced': 0.14655413},
#  'MED-2152': {'avg_cosine_sim_rep': 0.19772732,
#   'avg_cosine_sim_enhanced': 0.13955253,
#   'avg_cosine_sim_rep_enhanced': 0.15693872},
#  'MED-1723': {'avg_cosine_sim_rep': 0.100573815,
#   'avg_cosine_sim_enhanced': 0.11350498,
#   'avg_cosine_sim_rep_enhanced': 0.10824684},
#  'MED-5124': {'avg_cosine_sim_rep': 0.15631458,
#   'avg_cosine_sim_enhanced': 0.22749402,
#   'avg_cosine_sim_rep_enhanced': 0.1914229},
#  'MED-1533': {'avg_cosine_sim_rep': 0.21423158,
#   'avg_cosine_sim_enhanced': 0.097217485,
#   'avg_cosine_sim_rep_enhanced': 0.1358329},
#  'MED-4822': {'avg_cosine_sim_rep': 0.15007639,
#   'avg_cosine_sim_enhanced': 0.15566784,
#   'avg_cosine_sim_rep_enhanced': 0.14824244},
#  'MED-5148': {'avg_cosine_sim_rep': 0.18066198,
#   'avg_cosine_sim_enhanced': 0.20257328,
#   'avg_cosine_sim_rep_enhanced': 0.17833708},
#  'MED-4104': {'avg_cosine_sim_rep': 0.071545154,
#   'avg_cosine_sim_enhanced': 0.129553,
#   'avg_cosine_sim_rep_enhanced': 0.08878201},
#  'MED-1465': {'avg_cosine_sim_rep': 0.11474515,
#   'avg_cosine_sim_enhanced': 0.17315072,
#   'avg_cosine_sim_rep_enhanced': 0.15723608},
#  'MED-4363': {'avg_cosine_sim_rep': 0.2307417,
#   'avg_cosine_sim_enhanced': 0.20639938,
#   'avg_cosine_sim_rep_enhanced': 0.19161762},
#  'MED-3445': {'avg_cosine_sim_rep': 0.07180871,
#   'avg_cosine_sim_enhanced': 0.08408569,
#   'avg_cosine_sim_rep_enhanced': 0.07164998},
#  'MED-1184': {'avg_cosine_sim_rep': 0.118801735,
#   'avg_cosine_sim_enhanced': 0.029727647,
#   'avg_cosine_sim_rep_enhanced': 0.06382715},
#  'MED-1175': {'avg_cosine_sim_rep': 0.10042419,
#   'avg_cosine_sim_enhanced': 0.08429908,
#   'avg_cosine_sim_rep_enhanced': 0.08343538},
#  'MED-1497': {'avg_cosine_sim_rep': 0.1376621,
#   'avg_cosine_sim_enhanced': 0.18778713,
#   'avg_cosine_sim_rep_enhanced': 0.16168647},
#  'MED-2129': {'avg_cosine_sim_rep': 0.086657725,
#   'avg_cosine_sim_enhanced': 0.06632656,
#   'avg_cosine_sim_rep_enhanced': 0.058150753},
#  'MED-2195': {'avg_cosine_sim_rep': 0.13968946,
#   'avg_cosine_sim_enhanced': 0.08775573,
#   'avg_cosine_sim_rep_enhanced': 0.13805462},
#  'MED-3863': {'avg_cosine_sim_rep': 0.08953547,
#   'avg_cosine_sim_enhanced': 0.09884441,
#   'avg_cosine_sim_rep_enhanced': 0.08782623},
#  'MED-4419': {'avg_cosine_sim_rep': -0.07313235,
#   'avg_cosine_sim_enhanced': -0.02890074,
#   'avg_cosine_sim_rep_enhanced': -0.053940333},
#  'MED-1158': {'avg_cosine_sim_rep': 0.19370922,
#   'avg_cosine_sim_enhanced': 0.07344723,
#   'avg_cosine_sim_rep_enhanced': 0.12658879},
#  'MED-4183': {'avg_cosine_sim_rep': 0.082579084,
#   'avg_cosine_sim_enhanced': 0.09456553,
#   'avg_cosine_sim_rep_enhanced': 0.09079697},
#  'MED-2040': {'avg_cosine_sim_rep': 0.13792327,
#   'avg_cosine_sim_enhanced': 0.10425791,
#   'avg_cosine_sim_rep_enhanced': 0.11072866},
#  'MED-5027': {'avg_cosine_sim_rep': 0.047101237,
#   'avg_cosine_sim_enhanced': 0.014475838,
#   'avg_cosine_sim_rep_enhanced': 0.016239516},
#  'MED-4690': {'avg_cosine_sim_rep': 0.066751845,
#   'avg_cosine_sim_enhanced': 0.011565005,
#   'avg_cosine_sim_rep_enhanced': -0.008635318},
#  'MED-4953': {'avg_cosine_sim_rep': 0.12782979,
#   'avg_cosine_sim_enhanced': 0.073136024,
#   'avg_cosine_sim_rep_enhanced': 0.08701999},
#  'MED-4103': {'avg_cosine_sim_rep': 0.105804294,
#   'avg_cosine_sim_enhanced': 0.1116444,
#   'avg_cosine_sim_rep_enhanced': 0.10342236},
#  'MED-3435': {'avg_cosine_sim_rep': 0.05152651,
#   'avg_cosine_sim_enhanced': 0.061027773,
#   'avg_cosine_sim_rep_enhanced': 0.037108198},
#  'MED-2138': {'avg_cosine_sim_rep': 0.13328074,
#   'avg_cosine_sim_enhanced': 0.12474612,
#   'avg_cosine_sim_rep_enhanced': 0.11828414},
#  'MED-3588': {'avg_cosine_sim_rep': 0.20462416,
#   'avg_cosine_sim_enhanced': 0.22418143,
#   'avg_cosine_sim_rep_enhanced': 0.1933891},
#  'MED-4357': {'avg_cosine_sim_rep': 0.1676246,
#   'avg_cosine_sim_enhanced': 0.10169691,
#   'avg_cosine_sim_rep_enhanced': 0.16064334},
#  'MED-2436': {'avg_cosine_sim_rep': 0.14007297,
#   'avg_cosine_sim_enhanced': 0.114988215,
#   'avg_cosine_sim_rep_enhanced': 0.122635566},
#  'MED-735': {'avg_cosine_sim_rep': 0.054176677,
#   'avg_cosine_sim_enhanced': 0.046500534,
#   'avg_cosine_sim_rep_enhanced': 0.06945973},
#  'MED-1818': {'avg_cosine_sim_rep': 0.22295983,
#   'avg_cosine_sim_enhanced': 0.17584851,
#   'avg_cosine_sim_rep_enhanced': 0.18259256},
#  'MED-4939': {'avg_cosine_sim_rep': 0.08244729,
#   'avg_cosine_sim_enhanced': 0.11918443,
#   'avg_cosine_sim_rep_enhanced': 0.100797996},
#  'MED-3448': {'avg_cosine_sim_rep': 0.0973021,
#   'avg_cosine_sim_enhanced': 0.10991275,
#   'avg_cosine_sim_rep_enhanced': 0.10145489},
#  'MED-2824': {'avg_cosine_sim_rep': 0.080872186,
#   'avg_cosine_sim_enhanced': 0.090284675,
#   'avg_cosine_sim_rep_enhanced': 0.090742655},
#  'MED-2435': {'avg_cosine_sim_rep': 0.045163415,
#   'avg_cosine_sim_enhanced': 0.10910954,
#   'avg_cosine_sim_rep_enhanced': 0.07526279},
#  'MED-1797': {'avg_cosine_sim_rep': 0.11184909,
#   'avg_cosine_sim_enhanced': 0.07312745,
#   'avg_cosine_sim_rep_enhanced': 0.0831023},
#  'MED-2111': {'avg_cosine_sim_rep': 0.07997542,
#   'avg_cosine_sim_enhanced': 0.051236562,
#   'avg_cosine_sim_rep_enhanced': 0.03836888},
#  'MED-2809': {'avg_cosine_sim_rep': 0.07302656,
#   'avg_cosine_sim_enhanced': 0.12182907,
#   'avg_cosine_sim_rep_enhanced': 0.11353832},
#  'MED-1532': {'avg_cosine_sim_rep': 0.12047662,
#   'avg_cosine_sim_enhanced': 0.12361925,
#   'avg_cosine_sim_rep_enhanced': 0.11200898},
#  'MED-1493': {'avg_cosine_sim_rep': 0.009748784,
#   'avg_cosine_sim_enhanced': -0.020071056,
#   'avg_cosine_sim_rep_enhanced': -0.017193066},
#  'MED-3144': {'avg_cosine_sim_rep': 0.02495134,
#   'avg_cosine_sim_enhanced': 0.032308776,
#   'avg_cosine_sim_rep_enhanced': 0.012601992},
#  'MED-1510': {'avg_cosine_sim_rep': -0.038399365,
#   'avg_cosine_sim_enhanced': 0.050026268,
#   'avg_cosine_sim_rep_enhanced': -0.04151661},
#  'MED-2986': {'avg_cosine_sim_rep': 0.039535448,
#   'avg_cosine_sim_enhanced': 0.0727716,
#   'avg_cosine_sim_rep_enhanced': 0.035893597},
#  'MED-2852': {'avg_cosine_sim_rep': 0.022650205,
#   'avg_cosine_sim_enhanced': -0.010670757,
#   'avg_cosine_sim_rep_enhanced': 0.016730756},
#  'MED-4427': {'avg_cosine_sim_rep': nan,
#   'avg_cosine_sim_enhanced': nan,
#   'avg_cosine_sim_rep_enhanced': nan},
#  'MED-2365': {'avg_cosine_sim_rep': 0.07024904,
#   'avg_cosine_sim_enhanced': 0.044806793,
#   'avg_cosine_sim_rep_enhanced': 0.028813958},
#  'MED-1241': {'avg_cosine_sim_rep': 0.14586085,
#   'avg_cosine_sim_enhanced': 0.07055739,
#   'avg_cosine_sim_rep_enhanced': 0.09386354},
#  'MED-5094': {'avg_cosine_sim_rep': nan,
#   'avg_cosine_sim_enhanced': nan,
#   'avg_cosine_sim_rep_enhanced': nan},
#  'MED-3638': {'avg_cosine_sim_rep': 0.13103421,
#   'avg_cosine_sim_enhanced': 0.15107784,
#   'avg_cosine_sim_rep_enhanced': 0.14809456},
#  'MED-4035': {'avg_cosine_sim_rep': 0.09610497,
#   'avg_cosine_sim_enhanced': 0.08915927,
#   'avg_cosine_sim_rep_enhanced': 0.07408615},
#  'MED-1641': {'avg_cosine_sim_rep': 0.2129693,
#   'avg_cosine_sim_enhanced': 0.20617199,
#   'avg_cosine_sim_rep_enhanced': 0.20162465},
#  'MED-3138': {'avg_cosine_sim_rep': 0.037893437,
#   'avg_cosine_sim_enhanced': -0.002353826,
#   'avg_cosine_sim_rep_enhanced': 0.024348708},
#  'MED-1428': {'avg_cosine_sim_rep': -0.016936885,
#   'avg_cosine_sim_enhanced': 0.05338594,
#   'avg_cosine_sim_rep_enhanced': -0.0030728048},
#  'MED-4139': {'avg_cosine_sim_rep': 0.14165625,
#   'avg_cosine_sim_enhanced': 0.106851,
#   'avg_cosine_sim_rep_enhanced': 0.13496168},
#  'MED-2526': {'avg_cosine_sim_rep': 0.12773478,
#   'avg_cosine_sim_enhanced': 0.13553306,
#   'avg_cosine_sim_rep_enhanced': 0.1240951},
#  'MED-4574': {'avg_cosine_sim_rep': 0.157722,
#   'avg_cosine_sim_enhanced': 0.14730224,
#   'avg_cosine_sim_rep_enhanced': 0.15187916},
#  'MED-4516': {'avg_cosine_sim_rep': 0.09969555,
#   'avg_cosine_sim_enhanced': 0.086967945,
#   'avg_cosine_sim_rep_enhanced': 0.08661415},
#  'MED-3000': {'avg_cosine_sim_rep': 0.054478683,
#   'avg_cosine_sim_enhanced': 0.069864176,
#   'avg_cosine_sim_rep_enhanced': 0.05427706},
#  'MED-4292': {'avg_cosine_sim_rep': 0.054271255,
#   'avg_cosine_sim_enhanced': 0.08362746,
#   'avg_cosine_sim_rep_enhanced': 0.030346803},
#  'MED-2008': {'avg_cosine_sim_rep': 0.15463832,
#   'avg_cosine_sim_enhanced': 0.058208328,
#   'avg_cosine_sim_rep_enhanced': 0.10999982},
#  'MED-4967': {'avg_cosine_sim_rep': 0.33913612,
#   'avg_cosine_sim_enhanced': 0.2387384,
#   'avg_cosine_sim_rep_enhanced': 0.24909985},
#  'MED-1380': {'avg_cosine_sim_rep': 0.11088977,
#   'avg_cosine_sim_enhanced': 0.10989982,
#   'avg_cosine_sim_rep_enhanced': 0.103257835},
#  'MED-1252': {'avg_cosine_sim_rep': 0.10415059,
#   'avg_cosine_sim_enhanced': 0.037646066,
#   'avg_cosine_sim_rep_enhanced': 0.088436894},
#  'MED-4751': {'avg_cosine_sim_rep': 0.07699471,
#   'avg_cosine_sim_enhanced': 0.09727954,
#   'avg_cosine_sim_rep_enhanced': 0.07123699},
#  'MED-2171': {'avg_cosine_sim_rep': 0.06351395,
#   'avg_cosine_sim_enhanced': 0.04299657,
#   'avg_cosine_sim_rep_enhanced': 0.043040477},
#  'MED-2509': {'avg_cosine_sim_rep': 0.13005362,
#   'avg_cosine_sim_enhanced': 0.087403774,
#   'avg_cosine_sim_rep_enhanced': 0.11052022},
#  'MED-1432': {'avg_cosine_sim_rep': 0.14209548,
#   'avg_cosine_sim_enhanced': 0.13531981,
#   'avg_cosine_sim_rep_enhanced': 0.12308845},
#  'MED-2200': {'avg_cosine_sim_rep': 0.19251814,
#   'avg_cosine_sim_enhanced': 0.15242161,
#   'avg_cosine_sim_rep_enhanced': 0.16441914},
#  'MED-1527': {'avg_cosine_sim_rep': 0.060322333,
#   'avg_cosine_sim_enhanced': 0.078394145,
#   'avg_cosine_sim_rep_enhanced': 0.055283733},
#  'MED-5266': {'avg_cosine_sim_rep': 0.17564066,
#   'avg_cosine_sim_enhanced': 0.17250617,
#   'avg_cosine_sim_rep_enhanced': 0.1741508},
#  'MED-5272': {'avg_cosine_sim_rep': 0.09718703,
#   'avg_cosine_sim_enhanced': 0.19949421,
#   'avg_cosine_sim_rep_enhanced': 0.13949068},
#  'MED-3609': {'avg_cosine_sim_rep': 0.13331746,
#   'avg_cosine_sim_enhanced': 0.075334325,
#   'avg_cosine_sim_rep_enhanced': 0.10830164},
#  'MED-4617': {'avg_cosine_sim_rep': 0.15042137,
#   'avg_cosine_sim_enhanced': 0.1187013,
#   'avg_cosine_sim_rep_enhanced': 0.12556185},
#  'MED-3028': {'avg_cosine_sim_rep': 0.14843325,
#   'avg_cosine_sim_enhanced': 0.15323044,
#   'avg_cosine_sim_rep_enhanced': 0.14930151},
#  'MED-1836': {'avg_cosine_sim_rep': 0.037524566,
#   'avg_cosine_sim_enhanced': 0.13449845,
#   'avg_cosine_sim_rep_enhanced': 0.09307143},
#  'MED-3085': {'avg_cosine_sim_rep': 0.023524953,
#   'avg_cosine_sim_enhanced': 0.078718595,
#   'avg_cosine_sim_rep_enhanced': 0.050388437},
#  'MED-2969': {'avg_cosine_sim_rep': 0.10508124,
#   'avg_cosine_sim_enhanced': 0.06735666,
#   'avg_cosine_sim_rep_enhanced': 0.07758196},
#  'MED-2087': {'avg_cosine_sim_rep': 0.1696083,
#   'avg_cosine_sim_enhanced': 0.13552202,
#   'avg_cosine_sim_rep_enhanced': 0.14611503},
#  'MED-4796': {'avg_cosine_sim_rep': 0.19164705,
#   'avg_cosine_sim_enhanced': 0.120538004,
#   'avg_cosine_sim_rep_enhanced': 0.15216765},
#  'MED-2378': {'avg_cosine_sim_rep': 0.20936717,
#   'avg_cosine_sim_enhanced': 0.1738647,
#   'avg_cosine_sim_rep_enhanced': 0.20348783},
#  'MED-4955': {'avg_cosine_sim_rep': 0.02406027,
#   'avg_cosine_sim_enhanced': 0.08108154,
#   'avg_cosine_sim_rep_enhanced': 0.051386792},
#  'MED-4853': {'avg_cosine_sim_rep': 0.09293647,
#   'avg_cosine_sim_enhanced': 0.08304882,
#   'avg_cosine_sim_rep_enhanced': 0.09043842},
#  'MED-4677': {'avg_cosine_sim_rep': 0.15653232,
#   'avg_cosine_sim_enhanced': 0.14243104,
#   'avg_cosine_sim_rep_enhanced': 0.1363495},
#  'MED-1393': {'avg_cosine_sim_rep': 0.112584494,
#   'avg_cosine_sim_enhanced': 0.08572841,
#   'avg_cosine_sim_rep_enhanced': 0.07972855},
#  'MED-4469': {'avg_cosine_sim_rep': 0.120568305,
#   'avg_cosine_sim_enhanced': 0.11311459,
#   'avg_cosine_sim_rep_enhanced': 0.102548},
#  'MED-4613': {'avg_cosine_sim_rep': 0.10028,
#   'avg_cosine_sim_enhanced': 0.110366784,
#   'avg_cosine_sim_rep_enhanced': 0.08381707},
#  'MED-1874': {'avg_cosine_sim_rep': 0.07489974,
#   'avg_cosine_sim_enhanced': 0.07643794,
#   'avg_cosine_sim_rep_enhanced': 0.057018127},
#  'MED-4026': {'avg_cosine_sim_rep': 0.22863019,
#   'avg_cosine_sim_enhanced': 0.1986351,
#   'avg_cosine_sim_rep_enhanced': 0.21443674},
#  'MED-5092': {'avg_cosine_sim_rep': 0.16915236,
#   'avg_cosine_sim_enhanced': 0.17051803,
#   'avg_cosine_sim_rep_enhanced': 0.18655735},
#  'MED-2259': {'avg_cosine_sim_rep': 0.0716606,
#   'avg_cosine_sim_enhanced': 0.08175984,
#   'avg_cosine_sim_rep_enhanced': 0.06351173},
#  'MED-1839': {'avg_cosine_sim_rep': 0.115919605,
#   'avg_cosine_sim_enhanced': 0.14532027,
#   'avg_cosine_sim_rep_enhanced': 0.11517148},
#  'MED-3657': {'avg_cosine_sim_rep': 0.15872288,
#   'avg_cosine_sim_enhanced': 0.12674469,
#   'avg_cosine_sim_rep_enhanced': 0.12578578},
#  'MED-3142': {'avg_cosine_sim_rep': 0.14700152,
#   'avg_cosine_sim_enhanced': 0.0499945,
#   'avg_cosine_sim_rep_enhanced': 0.052502334},
#  'MED-2394': {'avg_cosine_sim_rep': 0.072430685,
#   'avg_cosine_sim_enhanced': 0.122459084,
#   'avg_cosine_sim_rep_enhanced': 0.1080569},
#  'MED-4638': {'avg_cosine_sim_rep': 0.111592524,
#   'avg_cosine_sim_enhanced': 0.11007673,
#   'avg_cosine_sim_rep_enhanced': 0.09015992},
#  'MED-4876': {'avg_cosine_sim_rep': 0.092060044,
#   'avg_cosine_sim_enhanced': 0.08497502,
#   'avg_cosine_sim_rep_enhanced': 0.06945812},
#  'MED-4164': {'avg_cosine_sim_rep': 0.24166381,
#   'avg_cosine_sim_enhanced': 0.14356318,
#   'avg_cosine_sim_rep_enhanced': 0.15347728},
#  'MED-2135': {'avg_cosine_sim_rep': 0.10588498,
#   'avg_cosine_sim_enhanced': 0.12546843,
#   'avg_cosine_sim_rep_enhanced': 0.11116436},
#  'MED-4858': {'avg_cosine_sim_rep': 0.09484374,
#   'avg_cosine_sim_enhanced': 0.08986345,
#   'avg_cosine_sim_rep_enhanced': 0.11223988},
#  'MED-2746': {'avg_cosine_sim_rep': 0.03663355,
#   'avg_cosine_sim_enhanced': 0.21085908,
#   'avg_cosine_sim_rep_enhanced': 0.1044494},
#  'MED-1314': {'avg_cosine_sim_rep': 0.2228868,
#   'avg_cosine_sim_enhanced': 0.1608409,
#   'avg_cosine_sim_rep_enhanced': 0.17186141},
#  'MED-2176': {'avg_cosine_sim_rep': 0.15085937,
#   'avg_cosine_sim_enhanced': 0.08102198,
#   'avg_cosine_sim_rep_enhanced': 0.10537735},
#  'MED-1185': {'avg_cosine_sim_rep': 0.123809405,
#   'avg_cosine_sim_enhanced': 0.0526181,
#   'avg_cosine_sim_rep_enhanced': 0.081854075},
#  'MED-2698': {'avg_cosine_sim_rep': 0.059261814,
#   'avg_cosine_sim_enhanced': 0.070241116,
#   'avg_cosine_sim_rep_enhanced': 0.06680337},
#  'MED-3283': {'avg_cosine_sim_rep': 0.07718059,
#   'avg_cosine_sim_enhanced': 0.11919279,
#   'avg_cosine_sim_rep_enhanced': 0.0738964},
#  'MED-2381': {'avg_cosine_sim_rep': 0.117648736,
#   'avg_cosine_sim_enhanced': 0.16919018,
#   'avg_cosine_sim_rep_enhanced': 0.14441225},
#  'MED-1359': {'avg_cosine_sim_rep': 0.049884927,
#   'avg_cosine_sim_enhanced': 0.014159491,
#   'avg_cosine_sim_rep_enhanced': 0.01796228},
#  'MED-2093': {'avg_cosine_sim_rep': 0.02475702,
#   'avg_cosine_sim_enhanced': 0.023915112,
#   'avg_cosine_sim_rep_enhanced': 0.005951929},
#  'MED-4224': {'avg_cosine_sim_rep': 0.12615989,
#   'avg_cosine_sim_enhanced': 0.13328925,
#   'avg_cosine_sim_rep_enhanced': 0.13121974},
#  'MED-5036': {'avg_cosine_sim_rep': 0.06478345,
#   'avg_cosine_sim_enhanced': 0.13172324,
#   'avg_cosine_sim_rep_enhanced': 0.07224399},
#  'MED-2694': {'avg_cosine_sim_rep': nan,
#   'avg_cosine_sim_enhanced': nan,
#   'avg_cosine_sim_rep_enhanced': nan},
#  'MED-2099': {'avg_cosine_sim_rep': 0.109569095,
#   'avg_cosine_sim_enhanced': 0.07207846,
#   'avg_cosine_sim_rep_enhanced': 0.08935142},
#  'MED-4721': {'avg_cosine_sim_rep': -0.0014353916,
#   'avg_cosine_sim_enhanced': 0.051232178,
#   'avg_cosine_sim_rep_enhanced': -0.007579252},
#  'MED-3830': {'avg_cosine_sim_rep': 0.08341971,
#   'avg_cosine_sim_enhanced': 0.1412451,
#   'avg_cosine_sim_rep_enhanced': 0.12522611},
#  'MED-3245': {'avg_cosine_sim_rep': 0.15822998,
#   'avg_cosine_sim_enhanced': 0.13329448,
#   'avg_cosine_sim_rep_enhanced': 0.13939035},
#  'MED-4651': {'avg_cosine_sim_rep': -0.0038400132,
#   'avg_cosine_sim_enhanced': 0.03258076,
#   'avg_cosine_sim_rep_enhanced': 0.010097143},
#  'MED-3636': {'avg_cosine_sim_rep': 0.09922495,
#   'avg_cosine_sim_enhanced': 0.07872024,
#   'avg_cosine_sim_rep_enhanced': 0.08707121},
#  'MED-1740': {'avg_cosine_sim_rep': 0.13125822,
#   'avg_cosine_sim_enhanced': 0.123302445,
#   'avg_cosine_sim_rep_enhanced': 0.111346364},
#  'MED-2366': {'avg_cosine_sim_rep': 0.10367516,
#   'avg_cosine_sim_enhanced': 0.09151925,
#   'avg_cosine_sim_rep_enhanced': 0.08996716},
#  'MED-5363': {'avg_cosine_sim_rep': 0.09500023,
#   'avg_cosine_sim_enhanced': 0.09683603,
#   'avg_cosine_sim_rep_enhanced': 0.10589841},
#  'MED-2267': {'avg_cosine_sim_rep': 0.112575695,
#   'avg_cosine_sim_enhanced': 0.11102706,
#   'avg_cosine_sim_rep_enhanced': 0.12526648},
#  'MED-4184': {'avg_cosine_sim_rep': 0.0554954,
#   'avg_cosine_sim_enhanced': 0.040422186,
#   'avg_cosine_sim_rep_enhanced': 0.0334563},
#  'MED-4057': {'avg_cosine_sim_rep': 0.11241889,
#   'avg_cosine_sim_enhanced': 0.13365096,
#   'avg_cosine_sim_rep_enhanced': 0.10870315},
#  'MED-2357': {'avg_cosine_sim_rep': 0.08233218,
#   'avg_cosine_sim_enhanced': 0.05613581,
#   'avg_cosine_sim_rep_enhanced': 0.08834271},
#  'MED-4330': {'avg_cosine_sim_rep': 0.09125699,
#   'avg_cosine_sim_enhanced': 0.08911859,
#   'avg_cosine_sim_rep_enhanced': 0.07658116},
#  'MED-3475': {'avg_cosine_sim_rep': 0.031688318,
#   'avg_cosine_sim_enhanced': -0.005984523,
#   'avg_cosine_sim_rep_enhanced': 0.008622635},
#  'MED-4325': {'avg_cosine_sim_rep': 0.16453116,
#   'avg_cosine_sim_enhanced': 0.14549784,
#   'avg_cosine_sim_rep_enhanced': 0.1696316},
#  'MED-3275': {'avg_cosine_sim_rep': 0.0477845,
#   'avg_cosine_sim_enhanced': 0.13613045,
#   'avg_cosine_sim_rep_enhanced': 0.048889972},
#  'MED-3001': {'avg_cosine_sim_rep': 0.07627043,
#   'avg_cosine_sim_enhanced': 0.05385283,
#   'avg_cosine_sim_rep_enhanced': 0.04674176},
#  'MED-2134': {'avg_cosine_sim_rep': 0.09548339,
#   'avg_cosine_sim_enhanced': 0.07179999,
#   'avg_cosine_sim_rep_enhanced': 0.061699226},
#  'MED-1718': {'avg_cosine_sim_rep': 0.05474694,
#   'avg_cosine_sim_enhanced': 0.05224992,
#   'avg_cosine_sim_rep_enhanced': 0.040389508},
#  'MED-3888': {'avg_cosine_sim_rep': 0.09467933,
#   'avg_cosine_sim_enhanced': 0.051142953,
#   'avg_cosine_sim_rep_enhanced': 0.08368193},
#  'MED-3795': {'avg_cosine_sim_rep': 0.12618084,
#   'avg_cosine_sim_enhanced': 0.084237695,
#   'avg_cosine_sim_rep_enhanced': 0.08364167},
#  'MED-1486': {'avg_cosine_sim_rep': 0.068523616,
#   'avg_cosine_sim_enhanced': 0.043570112,
#   'avg_cosine_sim_rep_enhanced': 0.044908088},
#  'MED-1258': {'avg_cosine_sim_rep': 0.16250004,
#   'avg_cosine_sim_enhanced': 0.120797604,
#   'avg_cosine_sim_rep_enhanced': 0.10308253},
#  'MED-1571': {'avg_cosine_sim_rep': 0.07221579,
#   'avg_cosine_sim_enhanced': 0.10703323,
#   'avg_cosine_sim_rep_enhanced': 0.10117436},
#  'MED-1787': {'avg_cosine_sim_rep': 0.11467135,
#   'avg_cosine_sim_enhanced': 0.046497338,
#   'avg_cosine_sim_rep_enhanced': 0.06703989},
#  'MED-4565': {'avg_cosine_sim_rep': 0.17767128,
#   'avg_cosine_sim_enhanced': 0.13051504,
#   'avg_cosine_sim_rep_enhanced': 0.123088844},
#  'MED-1820': {'avg_cosine_sim_rep': 0.17129517,
#   'avg_cosine_sim_enhanced': 0.14582588,
#   'avg_cosine_sim_rep_enhanced': 0.14999121},
#  'MED-4841': {'avg_cosine_sim_rep': 0.16584933,
#   'avg_cosine_sim_enhanced': 0.15137778,
#   'avg_cosine_sim_rep_enhanced': 0.17857175},
#  'MED-3446': {'avg_cosine_sim_rep': 0.06419545,
#   'avg_cosine_sim_enhanced': 0.08861238,
#   'avg_cosine_sim_rep_enhanced': 0.07537377},
#  'MED-4391': {'avg_cosine_sim_rep': 0.15970246,
#   'avg_cosine_sim_enhanced': 0.13346998,
#   'avg_cosine_sim_rep_enhanced': 0.13805935},
#  'MED-1348': {'avg_cosine_sim_rep': 0.0866331,
#   'avg_cosine_sim_enhanced': 0.06557673,
#   'avg_cosine_sim_rep_enhanced': 0.06838757},
#  'MED-3175': {'avg_cosine_sim_rep': 0.14870225,
#   'avg_cosine_sim_enhanced': 0.071872614,
#   'avg_cosine_sim_rep_enhanced': 0.099446096},
#  'MED-3158': {'avg_cosine_sim_rep': nan,
#   'avg_cosine_sim_enhanced': nan,
#   'avg_cosine_sim_rep_enhanced': nan},
#  'MED-4389': {'avg_cosine_sim_rep': 0.097495176,
#   'avg_cosine_sim_enhanced': 0.14664547,
#   'avg_cosine_sim_rep_enhanced': 0.112551294},
#  'MED-3681': {'avg_cosine_sim_rep': 0.20478597,
#   'avg_cosine_sim_enhanced': 0.2321165,
#   'avg_cosine_sim_rep_enhanced': 0.23937006},
#  'MED-3985': {'avg_cosine_sim_rep': 0.16777445,
#   'avg_cosine_sim_enhanced': 0.17297228,
#   'avg_cosine_sim_rep_enhanced': 0.17779212},
#  'MED-2292': {'avg_cosine_sim_rep': 0.079160124,
#   'avg_cosine_sim_enhanced': 0.06954773,
#   'avg_cosine_sim_rep_enhanced': 0.057881393},
#  'MED-4144': {'avg_cosine_sim_rep': 0.09937815,
#   'avg_cosine_sim_enhanced': 0.065708324,
#   'avg_cosine_sim_rep_enhanced': 0.06938711},
#  'MED-986': {'avg_cosine_sim_rep': 0.18241784,
#   'avg_cosine_sim_enhanced': 0.16901812,
#   'avg_cosine_sim_rep_enhanced': 0.15168317},
#  'MED-4840': {'avg_cosine_sim_rep': 0.104207166,
#   'avg_cosine_sim_enhanced': 0.12047446,
#   'avg_cosine_sim_rep_enhanced': 0.106297195},
#  'MED-5053': {'avg_cosine_sim_rep': 0.076383054,
#   'avg_cosine_sim_enhanced': 0.07095999,
#   'avg_cosine_sim_rep_enhanced': 0.06128673},
#  'MED-1595': {'avg_cosine_sim_rep': 0.19646442,
#   'avg_cosine_sim_enhanced': 0.16460527,
#   'avg_cosine_sim_rep_enhanced': 0.16877694},
#  'MED-4846': {'avg_cosine_sim_rep': 0.17750508,
#   'avg_cosine_sim_enhanced': 0.12905206,
#   'avg_cosine_sim_rep_enhanced': 0.167242},
#  'MED-4038': {'avg_cosine_sim_rep': 0.15154272,
#   'avg_cosine_sim_enhanced': 0.092993006,
#   'avg_cosine_sim_rep_enhanced': 0.12469621},
#  'MED-2376': {'avg_cosine_sim_rep': 0.115461916,
#   'avg_cosine_sim_enhanced': 0.13746788,
#   'avg_cosine_sim_rep_enhanced': 0.13660227},
#  'MED-4642': {'avg_cosine_sim_rep': 0.1313867,
#   'avg_cosine_sim_enhanced': 0.15904605,
#   'avg_cosine_sim_rep_enhanced': 0.15113713},
#  'MED-5273': {'avg_cosine_sim_rep': 0.17614885,
#   'avg_cosine_sim_enhanced': 0.1946009,
#   'avg_cosine_sim_rep_enhanced': 0.18355644},
#  'MED-952': {'avg_cosine_sim_rep': 0.052730747,
#   'avg_cosine_sim_enhanced': 0.07578999,
#   'avg_cosine_sim_rep_enhanced': 0.0532063},
#  'MED-2528': {'avg_cosine_sim_rep': 0.07411686,
#   'avg_cosine_sim_enhanced': 0.12599044,
#   'avg_cosine_sim_rep_enhanced': 0.094297394},
#  'MED-3501': {'avg_cosine_sim_rep': 0.15829471,
#   'avg_cosine_sim_enhanced': 0.07541946,
#   'avg_cosine_sim_rep_enhanced': 0.12039958},
#  'MED-1810': {'avg_cosine_sim_rep': 0.18390715,
#   'avg_cosine_sim_enhanced': 0.1317206,
#   'avg_cosine_sim_rep_enhanced': 0.12539406},
#  'MED-3610': {'avg_cosine_sim_rep': 0.20158163,
#   'avg_cosine_sim_enhanced': 0.1114074,
#   'avg_cosine_sim_rep_enhanced': 0.17711231},
#  'MED-717': {'avg_cosine_sim_rep': 0.058963228,
#   'avg_cosine_sim_enhanced': -0.0031622767,
#   'avg_cosine_sim_rep_enhanced': 0.038374398},
#  'MED-5047': {'avg_cosine_sim_rep': 0.09698178,
#   'avg_cosine_sim_enhanced': 0.12195916,
#   'avg_cosine_sim_rep_enhanced': 0.114334404},
#  'MED-2360': {'avg_cosine_sim_rep': 0.103443205,
#   'avg_cosine_sim_enhanced': 0.021661159,
#   'avg_cosine_sim_rep_enhanced': 0.02601499},
#  'MED-3841': {'avg_cosine_sim_rep': 0.1139082,
#   'avg_cosine_sim_enhanced': 0.15747419,
#   'avg_cosine_sim_rep_enhanced': 0.14741316},
#  'MED-1933': {'avg_cosine_sim_rep': 0.07136911,
#   'avg_cosine_sim_enhanced': 0.14509042,
#   'avg_cosine_sim_rep_enhanced': 0.12535107},
#  'MED-3877': {'avg_cosine_sim_rep': 0.06140961,
#   'avg_cosine_sim_enhanced': 0.077346236,
#   'avg_cosine_sim_rep_enhanced': 0.08540622},
#  'MED-1554': {'avg_cosine_sim_rep': 0.097494446,
#   'avg_cosine_sim_enhanced': 0.102231584,
#   'avg_cosine_sim_rep_enhanced': 0.09381271},
#  'MED-4551': {'avg_cosine_sim_rep': 0.11541388,
#   'avg_cosine_sim_enhanced': 0.109484546,
#   'avg_cosine_sim_rep_enhanced': 0.107236005},
#  'MED-2584': {'avg_cosine_sim_rep': 0.062733784,
#   'avg_cosine_sim_enhanced': 0.0614684,
#   'avg_cosine_sim_rep_enhanced': 0.043341476},
#  'MED-4633': {'avg_cosine_sim_rep': 0.19259483,
#   'avg_cosine_sim_enhanced': 0.1826922,
#   'avg_cosine_sim_rep_enhanced': 0.1829459},
#  'MED-5073': {'avg_cosine_sim_rep': 0.08096393,
#   'avg_cosine_sim_enhanced': 0.061927807,
#   'avg_cosine_sim_rep_enhanced': 0.07149799},
#  'MED-4468': {'avg_cosine_sim_rep': 0.14836983,
#   'avg_cosine_sim_enhanced': 0.15075836,
#   'avg_cosine_sim_rep_enhanced': 0.142125},
#  'MED-5330': {'avg_cosine_sim_rep': 0.0674975,
#   'avg_cosine_sim_enhanced': 0.09034707,
#   'avg_cosine_sim_rep_enhanced': 0.081361905},
#  'MED-5091': {'avg_cosine_sim_rep': 0.13526212,
#   'avg_cosine_sim_enhanced': 0.13668378,
#   'avg_cosine_sim_rep_enhanced': 0.1424831},
#  'MED-3102': {'avg_cosine_sim_rep': 0.053586423,
#   'avg_cosine_sim_enhanced': 0.07475661,
#   'avg_cosine_sim_rep_enhanced': 0.06448211},
#  'MED-1830': {'avg_cosine_sim_rep': 0.06367617,
#   'avg_cosine_sim_enhanced': 0.12590005,
#   'avg_cosine_sim_rep_enhanced': 0.08381099},
#  'MED-4059': {'avg_cosine_sim_rep': 0.13328865,
#   'avg_cosine_sim_enhanced': 0.118957244,
#   'avg_cosine_sim_rep_enhanced': 0.12400899},
#  'MED-3990': {'avg_cosine_sim_rep': 0.16761956,
#   'avg_cosine_sim_enhanced': 0.17233847,
#   'avg_cosine_sim_rep_enhanced': 0.17694184},
#  'MED-118': {'avg_cosine_sim_rep': 0.18317671,
#   'avg_cosine_sim_enhanced': 0.15048914,
#   'avg_cosine_sim_rep_enhanced': 0.1439391},
#  'MED-4405': {'avg_cosine_sim_rep': 0.07688531,
#   'avg_cosine_sim_enhanced': 0.050147213,
#   'avg_cosine_sim_rep_enhanced': 0.057463307},
#  'MED-2745': {'avg_cosine_sim_rep': 0.15234153,
#   'avg_cosine_sim_enhanced': 0.10359558,
#   'avg_cosine_sim_rep_enhanced': 0.1294106},
#  'MED-3774': {'avg_cosine_sim_rep': 0.0096039055,
#   'avg_cosine_sim_enhanced': 0.027881399,
#   'avg_cosine_sim_rep_enhanced': 0.0062937923},
#  'MED-1124': {'avg_cosine_sim_rep': 0.046771497,
#   'avg_cosine_sim_enhanced': 0.11188972,
#   'avg_cosine_sim_rep_enhanced': 0.078335725},
#  'MED-1580': {'avg_cosine_sim_rep': 0.121314436,
#   'avg_cosine_sim_enhanced': 0.16420351,
#   'avg_cosine_sim_rep_enhanced': 0.15692712},
#  'MED-3020': {'avg_cosine_sim_rep': 0.071603715,
#   'avg_cosine_sim_enhanced': 0.046515606,
#   'avg_cosine_sim_rep_enhanced': 0.054739974},
#  'MED-2651': {'avg_cosine_sim_rep': 0.2041461,
#   'avg_cosine_sim_enhanced': 0.17555861,
#   'avg_cosine_sim_rep_enhanced': 0.16797891},
#  'MED-2227': {'avg_cosine_sim_rep': 0.16017647,
#   'avg_cosine_sim_enhanced': 0.16202983,
#   'avg_cosine_sim_rep_enhanced': 0.1435077},
#  'MED-1322': {'avg_cosine_sim_rep': 0.042197503,
#   'avg_cosine_sim_enhanced': 0.006481265,
#   'avg_cosine_sim_rep_enhanced': 0.02120044},
#  'MED-2243': {'avg_cosine_sim_rep': 0.10204551,
#   'avg_cosine_sim_enhanced': 0.09504732,
#   'avg_cosine_sim_rep_enhanced': 0.09394863},
#  'MED-5121': {'avg_cosine_sim_rep': 0.08990884,
#   'avg_cosine_sim_enhanced': 0.19794641,
#   'avg_cosine_sim_rep_enhanced': 0.15575863},
#  'MED-5195': {'avg_cosine_sim_rep': 0.15567622,
#   'avg_cosine_sim_enhanced': 0.13632146,
#   'avg_cosine_sim_rep_enhanced': 0.12291632},
#  'MED-1458': {'avg_cosine_sim_rep': 0.13486265,
#   'avg_cosine_sim_enhanced': 0.071999535,
#   'avg_cosine_sim_rep_enhanced': 0.0944493},
#  'MED-3763': {'avg_cosine_sim_rep': 0.06407289,
#   'avg_cosine_sim_enhanced': 0.12779213,
#   'avg_cosine_sim_rep_enhanced': 0.08774899},
#  'MED-1378': {'avg_cosine_sim_rep': 0.099476494,
#   'avg_cosine_sim_enhanced': 0.04901364,
#   'avg_cosine_sim_rep_enhanced': 0.088343},
#  'MED-4013': {'avg_cosine_sim_rep': 0.014736087,
#   'avg_cosine_sim_enhanced': 0.008834781,
#   'avg_cosine_sim_rep_enhanced': 0.0076048416},
#  'MED-1646': {'avg_cosine_sim_rep': 0.15214129,
#   'avg_cosine_sim_enhanced': 0.15184824,
#   'avg_cosine_sim_rep_enhanced': 0.13235566},
#  'MED-1672': {'avg_cosine_sim_rep': 0.21521658,
#   'avg_cosine_sim_enhanced': 0.14337851,
#   'avg_cosine_sim_rep_enhanced': 0.17277123},
#  'MED-4744': {'avg_cosine_sim_rep': 0.14907537,
#   'avg_cosine_sim_enhanced': 0.15057926,
#   'avg_cosine_sim_rep_enhanced': 0.16973996},
#  'MED-3711': {'avg_cosine_sim_rep': 0.02868722,
#   'avg_cosine_sim_enhanced': 0.026297245,
#   'avg_cosine_sim_rep_enhanced': 0.02222805},
#  'MED-4129': {'avg_cosine_sim_rep': 0.14927898,
#   'avg_cosine_sim_enhanced': 0.11812516,
#   'avg_cosine_sim_rep_enhanced': 0.14023916},
#  'MED-1846': {'avg_cosine_sim_rep': 0.12779081,
#   'avg_cosine_sim_enhanced': 0.11783156,
#   'avg_cosine_sim_rep_enhanced': 0.1180565},
#  'MED-2367': {'avg_cosine_sim_rep': 0.10286347,
#   'avg_cosine_sim_enhanced': 0.030915668,
#   'avg_cosine_sim_rep_enhanced': 0.039498568},
#  'MED-3979': {'avg_cosine_sim_rep': 0.118618034,
#   'avg_cosine_sim_enhanced': 0.19582379,
#   'avg_cosine_sim_rep_enhanced': 0.15034932},
#  'MED-4450': {'avg_cosine_sim_rep': 0.13789493,
#   'avg_cosine_sim_enhanced': 0.12333192,
#   'avg_cosine_sim_rep_enhanced': 0.14890885},
#  'MED-3450': {'avg_cosine_sim_rep': 0.12248439,
#   'avg_cosine_sim_enhanced': 0.11535512,
#   'avg_cosine_sim_rep_enhanced': 0.09506717},
#  'MED-2096': {'avg_cosine_sim_rep': 0.096377954,
#   'avg_cosine_sim_enhanced': 0.055883333,
#   'avg_cosine_sim_rep_enhanced': 0.04876811},
#  'MED-4058': {'avg_cosine_sim_rep': 0.11561758,
#   'avg_cosine_sim_enhanced': 0.096639976,
#   'avg_cosine_sim_rep_enhanced': 0.09745221},
#  'MED-4883': {'avg_cosine_sim_rep': 0.1111098,
#   'avg_cosine_sim_enhanced': 0.025828712,
#   'avg_cosine_sim_rep_enhanced': 0.08649869},
#  'MED-2049': {'avg_cosine_sim_rep': 0.2374187,
#   'avg_cosine_sim_enhanced': 0.1781112,
#   'avg_cosine_sim_rep_enhanced': 0.1806183},
#  'MED-2669': {'avg_cosine_sim_rep': 0.080044776,
#   'avg_cosine_sim_enhanced': 0.06494104,
#   'avg_cosine_sim_rep_enhanced': 0.079866536},
#  'MED-3274': {'avg_cosine_sim_rep': 0.18855321,
#   'avg_cosine_sim_enhanced': 0.13101721,
#   'avg_cosine_sim_rep_enhanced': 0.11728974},
#  'MED-4802': {'avg_cosine_sim_rep': 0.13200112,
#   'avg_cosine_sim_enhanced': 0.11050538,
#   'avg_cosine_sim_rep_enhanced': 0.11319283},
#  'MED-5328': {'avg_cosine_sim_rep': 0.11147329,
#   'avg_cosine_sim_enhanced': 0.15392011,
#   'avg_cosine_sim_rep_enhanced': 0.12038894},
#  'MED-3099': {'avg_cosine_sim_rep': 0.09828429,
#   'avg_cosine_sim_enhanced': 0.13399185,
#   'avg_cosine_sim_rep_enhanced': 0.1081116},
#  'MED-3525': {'avg_cosine_sim_rep': 0.14663023,
#   'avg_cosine_sim_enhanced': 0.0660851,
#   'avg_cosine_sim_rep_enhanced': 0.12964882},
#  'MED-3935': {'avg_cosine_sim_rep': 0.08465655,
#   'avg_cosine_sim_enhanced': 0.096135095,
#   'avg_cosine_sim_rep_enhanced': 0.081802405},
#  'MED-3599': {'avg_cosine_sim_rep': 0.08650331,
#   'avg_cosine_sim_enhanced': 0.10157406,
#   'avg_cosine_sim_rep_enhanced': 0.0948862},
#  'MED-1622': {'avg_cosine_sim_rep': 0.12322618,
#   'avg_cosine_sim_enhanced': 0.14589939,
#   'avg_cosine_sim_rep_enhanced': 0.14464356},
#  'MED-2273': {'avg_cosine_sim_rep': 0.06161551,
#   'avg_cosine_sim_enhanced': 0.013676218,
#   'avg_cosine_sim_rep_enhanced': 0.0474882},
#  'MED-2158': {'avg_cosine_sim_rep': 0.104428336,
#   'avg_cosine_sim_enhanced': 0.13437934,
#   'avg_cosine_sim_rep_enhanced': 0.10841202},
#  'MED-1350': {'avg_cosine_sim_rep': 0.016206019,
#   'avg_cosine_sim_enhanced': 0.039159298,
#   'avg_cosine_sim_rep_enhanced': 0.02241059},
#  'MED-2815': {'avg_cosine_sim_rep': 0.10263193,
#   'avg_cosine_sim_enhanced': 0.08944248,
#   'avg_cosine_sim_rep_enhanced': 0.10689305},
#  'MED-1131': {'avg_cosine_sim_rep': 0.084327154,
#   'avg_cosine_sim_enhanced': 0.040413857,
#   'avg_cosine_sim_rep_enhanced': 0.082572326},
#  'MED-4353': {'avg_cosine_sim_rep': 0.12732333,
#   'avg_cosine_sim_enhanced': 0.11030199,
#   'avg_cosine_sim_rep_enhanced': 0.09598861},
#  'MED-4146': {'avg_cosine_sim_rep': 0.08353241,
#   'avg_cosine_sim_enhanced': 0.059095357,
#   'avg_cosine_sim_rep_enhanced': 0.067317136},
#  'MED-2180': {'avg_cosine_sim_rep': 0.088394724,
#   'avg_cosine_sim_enhanced': 0.1320787,
#   'avg_cosine_sim_rep_enhanced': 0.0878713},
#  'MED-4354': {'avg_cosine_sim_rep': 0.07016942,
#   'avg_cosine_sim_enhanced': 0.009408821,
#   'avg_cosine_sim_rep_enhanced': 0.055475608},
#  'MED-5324': {'avg_cosine_sim_rep': 0.11300661,
#   'avg_cosine_sim_enhanced': 0.14036706,
#   'avg_cosine_sim_rep_enhanced': 0.12525381},
#  'MED-745': {'avg_cosine_sim_rep': 0.055159755,
#   'avg_cosine_sim_enhanced': 0.24236858,
#   'avg_cosine_sim_rep_enhanced': 0.20944767},
#  'MED-1389': {'avg_cosine_sim_rep': 0.066784404,
#   'avg_cosine_sim_enhanced': 0.05101856,
#   'avg_cosine_sim_rep_enhanced': 0.03499516},
#  'MED-4591': {'avg_cosine_sim_rep': 0.2594247,
#   'avg_cosine_sim_enhanced': 0.20495938,
#   'avg_cosine_sim_rep_enhanced': 0.21318634},
#  'MED-1327': {'avg_cosine_sim_rep': 0.028843988,
#   'avg_cosine_sim_enhanced': -0.001681293,
#   'avg_cosine_sim_rep_enhanced': 0.0020368933},
#  'MED-2175': {'avg_cosine_sim_rep': 0.12109772,
#   'avg_cosine_sim_enhanced': 0.079006754,
#   'avg_cosine_sim_rep_enhanced': 0.095811374},
#  'MED-1366': {'avg_cosine_sim_rep': 0.105922006,
#   'avg_cosine_sim_enhanced': 0.14986466,
#   'avg_cosine_sim_rep_enhanced': 0.11057272},
#  'MED-1181': {'avg_cosine_sim_rep': 0.103348374,
#   'avg_cosine_sim_enhanced': 0.10074973,
#   'avg_cosine_sim_rep_enhanced': 0.087029874},
#  'MED-2775': {'avg_cosine_sim_rep': 0.045287356,
#   'avg_cosine_sim_enhanced': 0.075659856,
#   'avg_cosine_sim_rep_enhanced': 0.046372917},
#  'MED-4972': {'avg_cosine_sim_rep': 0.12365782,
#   'avg_cosine_sim_enhanced': 0.18070026,
#   'avg_cosine_sim_rep_enhanced': 0.17406778},
#  'MED-3920': {'avg_cosine_sim_rep': 0.10148864,
#   'avg_cosine_sim_enhanced': 0.06373779,
#   'avg_cosine_sim_rep_enhanced': 0.08430192},
#  'MED-2221': {'avg_cosine_sim_rep': 0.10891791,
#   'avg_cosine_sim_enhanced': 0.10337247,
#   'avg_cosine_sim_rep_enhanced': 0.0965204},
#  'MED-2437': {'avg_cosine_sim_rep': 0.0934337,
#   'avg_cosine_sim_enhanced': 0.10882189,
#   'avg_cosine_sim_rep_enhanced': 0.09344485},
#  'MED-4790': {'avg_cosine_sim_rep': 0.10173363,
#   'avg_cosine_sim_enhanced': 0.09796439,
#   'avg_cosine_sim_rep_enhanced': 0.08762145},
#  'MED-3761': {'avg_cosine_sim_rep': nan,
#   'avg_cosine_sim_enhanced': nan,
#   'avg_cosine_sim_rep_enhanced': nan},
#  'MED-2107': {'avg_cosine_sim_rep': 0.16716914,
#   'avg_cosine_sim_enhanced': 0.082935356,
#   'avg_cosine_sim_rep_enhanced': 0.13919777},
#  'MED-5000': {'avg_cosine_sim_rep': 0.20259356,
#   'avg_cosine_sim_enhanced': 0.21216214,
#   'avg_cosine_sim_rep_enhanced': 0.22040173},
#  'MED-1689': {'avg_cosine_sim_rep': 0.053706825,
#   'avg_cosine_sim_enhanced': 0.021932479,
#   'avg_cosine_sim_rep_enhanced': 0.018759962},
#  'MED-4245': {'avg_cosine_sim_rep': 0.07393916,
#   'avg_cosine_sim_enhanced': 0.10669311,
#   'avg_cosine_sim_rep_enhanced': 0.1050083},
#  'MED-4288': {'avg_cosine_sim_rep': 0.04875918,
#   'avg_cosine_sim_enhanced': 0.08055588,
#   'avg_cosine_sim_rep_enhanced': 0.05096065},
#  'MED-3701': {'avg_cosine_sim_rep': 0.113687634,
#   'avg_cosine_sim_enhanced': 0.12212845,
#   'avg_cosine_sim_rep_enhanced': 0.12216304},
#  'MED-2252': {'avg_cosine_sim_rep': 0.06524996,
#   'avg_cosine_sim_enhanced': 0.08223396,
#   'avg_cosine_sim_rep_enhanced': 0.06158017},
#  'MED-3702': {'avg_cosine_sim_rep': 0.24190795,
#   'avg_cosine_sim_enhanced': 0.24832208,
#   'avg_cosine_sim_rep_enhanced': 0.23974967},
#  'MED-3350': {'avg_cosine_sim_rep': 0.0042789704,
#   'avg_cosine_sim_enhanced': 0.03347848,
#   'avg_cosine_sim_rep_enhanced': 0.013561542},
#  'MED-2000': {'avg_cosine_sim_rep': 0.1562085,
#   'avg_cosine_sim_enhanced': 0.20880075,
#   'avg_cosine_sim_rep_enhanced': 0.17544954},
#  'MED-1500': {'avg_cosine_sim_rep': 0.078000836,
#   'avg_cosine_sim_enhanced': 0.09343927,
#   'avg_cosine_sim_rep_enhanced': 0.078035526},
#  'MED-1511': {'avg_cosine_sim_rep': -0.034684874,
#   'avg_cosine_sim_enhanced': -0.03740783,
#   'avg_cosine_sim_rep_enhanced': -0.04243597},
#  'MED-4741': {'avg_cosine_sim_rep': 0.1018582,
#   'avg_cosine_sim_enhanced': 0.20293455,
#   'avg_cosine_sim_rep_enhanced': 0.1778723},
#  'MED-3486': {'avg_cosine_sim_rep': 0.08307092,
#   'avg_cosine_sim_enhanced': 0.10564969,
#   'avg_cosine_sim_rep_enhanced': 0.036702108},
#  'MED-2951': {'avg_cosine_sim_rep': 0.06997284,
#   'avg_cosine_sim_enhanced': 0.083350636,
#   'avg_cosine_sim_rep_enhanced': 0.05864793},
#  'MED-3451': {'avg_cosine_sim_rep': 0.12481194,
#   'avg_cosine_sim_enhanced': 0.10463296,
#   'avg_cosine_sim_rep_enhanced': 0.10324171},
#  'MED-3376': {'avg_cosine_sim_rep': 0.11628492,
#   'avg_cosine_sim_enhanced': 0.081185535,
#   'avg_cosine_sim_rep_enhanced': 0.09196576},
#  'MED-3676': {'avg_cosine_sim_rep': 0.11542491,
#   'avg_cosine_sim_enhanced': 0.14093147,
#   'avg_cosine_sim_rep_enhanced': 0.15338057},
#  'MED-1304': {'avg_cosine_sim_rep': 0.13053238,
#   'avg_cosine_sim_enhanced': 0.13387436,
#   'avg_cosine_sim_rep_enhanced': 0.10130331},
#  'MED-4809': {'avg_cosine_sim_rep': 0.054322045,
#   'avg_cosine_sim_enhanced': -0.021248218,
#   'avg_cosine_sim_rep_enhanced': -0.010906288},
#  'MED-4710': {'avg_cosine_sim_rep': 0.085707165,
#   'avg_cosine_sim_enhanced': 0.04978629,
#   'avg_cosine_sim_rep_enhanced': 0.036591824},
#  'MED-4667': {'avg_cosine_sim_rep': 0.07016091,
#   'avg_cosine_sim_enhanced': 0.056399744,
#   'avg_cosine_sim_rep_enhanced': 0.03503371},
#  'MED-1517': {'avg_cosine_sim_rep': 0.016413806,
#   'avg_cosine_sim_enhanced': -0.015784593,
#   'avg_cosine_sim_rep_enhanced': -0.02357353},
#  'MED-1334': {'avg_cosine_sim_rep': 0.06290672,
#   'avg_cosine_sim_enhanced': 0.07303628,
#   'avg_cosine_sim_rep_enhanced': 0.05870409},
#  'MED-3305': {'avg_cosine_sim_rep': 0.17587675,
#   'avg_cosine_sim_enhanced': 0.18165149,
#   'avg_cosine_sim_rep_enhanced': 0.16429375},
#  'MED-2820': {'avg_cosine_sim_rep': 0.14276572,
#   'avg_cosine_sim_enhanced': 0.07588516,
#   'avg_cosine_sim_rep_enhanced': 0.092148095},
#  'MED-1569': {'avg_cosine_sim_rep': 0.13891016,
#   'avg_cosine_sim_enhanced': 0.050346,
#   'avg_cosine_sim_rep_enhanced': 0.07905764},
#  'MED-2278': {'avg_cosine_sim_rep': 0.120206214,
#   'avg_cosine_sim_enhanced': 0.14182483,
#   'avg_cosine_sim_rep_enhanced': 0.12312488},
#  'MED-2005': {'avg_cosine_sim_rep': 0.14314464,
#   'avg_cosine_sim_enhanced': 0.1294993,
#   'avg_cosine_sim_rep_enhanced': 0.16396968},
#  'MED-4947': {'avg_cosine_sim_rep': 0.13490757,
#   'avg_cosine_sim_enhanced': 0.10542017,
#   'avg_cosine_sim_rep_enhanced': 0.11230973},
#  'MED-5204': {'avg_cosine_sim_rep': 0.08170263,
#   'avg_cosine_sim_enhanced': 0.077134125,
#   'avg_cosine_sim_rep_enhanced': 0.06771028},
#  'MED-3586': {'avg_cosine_sim_rep': 0.1141598,
#   'avg_cosine_sim_enhanced': 0.16187494,
#   'avg_cosine_sim_rep_enhanced': 0.14891224},
#  'MED-1726': {'avg_cosine_sim_rep': 0.13735683,
#   'avg_cosine_sim_enhanced': 0.114898324,
#   'avg_cosine_sim_rep_enhanced': 0.121004365},
#  'MED-5341': {'avg_cosine_sim_rep': 0.08461388,
#   'avg_cosine_sim_enhanced': 0.07090357,
#   'avg_cosine_sim_rep_enhanced': 0.07488535},
#  'MED-1958': {'avg_cosine_sim_rep': 0.20384263,
#   'avg_cosine_sim_enhanced': 0.111483134,
#   'avg_cosine_sim_rep_enhanced': 0.14571962},
#  'MED-4959': {'avg_cosine_sim_rep': 0.09582583,
#   'avg_cosine_sim_enhanced': 0.07629904,
#   'avg_cosine_sim_rep_enhanced': 0.07919455},
#  'MED-3658': {'avg_cosine_sim_rep': 0.14597039,
#   'avg_cosine_sim_enhanced': 0.12524226,
#   'avg_cosine_sim_rep_enhanced': 0.14845991},
#  'MED-2284': {'avg_cosine_sim_rep': 0.07726285,
#   'avg_cosine_sim_enhanced': 0.101278275,
#   'avg_cosine_sim_rep_enhanced': 0.06677438},
#  'MED-1410': {'avg_cosine_sim_rep': 0.07451749,
#   'avg_cosine_sim_enhanced': 0.056013703,
#   'avg_cosine_sim_rep_enhanced': 0.059469752},
#  'MED-3547': {'avg_cosine_sim_rep': 0.10459328,
#   'avg_cosine_sim_enhanced': 0.12898348,
#   'avg_cosine_sim_rep_enhanced': 0.08171998},
#  'MED-4132': {'avg_cosine_sim_rep': 0.015400351,
#   'avg_cosine_sim_enhanced': -0.013522771,
#   'avg_cosine_sim_rep_enhanced': -0.00396818},
#  'MED-1515': {'avg_cosine_sim_rep': -0.016298395,
#   'avg_cosine_sim_enhanced': -0.026120948,
#   'avg_cosine_sim_rep_enhanced': -0.041886862},
#  'MED-1279': {'avg_cosine_sim_rep': 0.007260211,
#   'avg_cosine_sim_enhanced': 0.08375733,
#   'avg_cosine_sim_rep_enhanced': 0.018143693},
#  'MED-4705': {'avg_cosine_sim_rep': 0.12582062,
#   'avg_cosine_sim_enhanced': 0.08557819,
#   'avg_cosine_sim_rep_enhanced': 0.08036026},
#  'MED-4071': {'avg_cosine_sim_rep': 0.113384984,
#   'avg_cosine_sim_enhanced': 0.1340599,
#   'avg_cosine_sim_rep_enhanced': 0.11601987},
#  'MED-1103': {'avg_cosine_sim_rep': 0.084246345,
#   'avg_cosine_sim_enhanced': 0.049375918,
#   'avg_cosine_sim_rep_enhanced': 0.06491176},
#  'MED-1496': {'avg_cosine_sim_rep': 0.11526704,
#   'avg_cosine_sim_enhanced': 0.10192329,
#   'avg_cosine_sim_rep_enhanced': 0.08990108},
#  'MED-2215': {'avg_cosine_sim_rep': 0.1352851,
#   'avg_cosine_sim_enhanced': 0.15593317,
#   'avg_cosine_sim_rep_enhanced': 0.13735512},
#  'MED-1851': {'avg_cosine_sim_rep': 0.08110484,
#   'avg_cosine_sim_enhanced': 0.12004468,
#   'avg_cosine_sim_rep_enhanced': 0.11118274},
#  'MED-3320': {'avg_cosine_sim_rep': 0.046410337,
#   'avg_cosine_sim_enhanced': 0.058983766,
#   'avg_cosine_sim_rep_enhanced': 0.050171368},
#  'MED-3762': {'avg_cosine_sim_rep': 0.12197824,
#   'avg_cosine_sim_enhanced': 0.13041858,
#   'avg_cosine_sim_rep_enhanced': 0.12460082},
#  'MED-3744': {'avg_cosine_sim_rep': 0.16489331,
#   'avg_cosine_sim_enhanced': 0.15402994,
#   'avg_cosine_sim_rep_enhanced': 0.13893148},
#  'MED-2105': {'avg_cosine_sim_rep': 0.11751848,
#   'avg_cosine_sim_enhanced': 0.1258807,
#   'avg_cosine_sim_rep_enhanced': 0.10667336},
#  'MED-3282': {'avg_cosine_sim_rep': 0.08097584,
#   'avg_cosine_sim_enhanced': 0.11170735,
#   'avg_cosine_sim_rep_enhanced': 0.08607392},
#  'MED-1326': {'avg_cosine_sim_rep': 0.05990133,
#   'avg_cosine_sim_enhanced': 0.038793445,
#   'avg_cosine_sim_rep_enhanced': 0.054984465},
#  'MED-1844': {'avg_cosine_sim_rep': 0.012833243,
#   'avg_cosine_sim_enhanced': -0.011160882,
#   'avg_cosine_sim_rep_enhanced': -0.007915657},
#  'MED-3140': {'avg_cosine_sim_rep': 0.09405777,
#   'avg_cosine_sim_enhanced': 0.05005586,
#   'avg_cosine_sim_rep_enhanced': 0.04470598},
#  'MED-398': {'avg_cosine_sim_rep': 0.062305193,
#   'avg_cosine_sim_enhanced': 0.056751087,
#   'avg_cosine_sim_rep_enhanced': 0.069523826},
#  'MED-3215': {'avg_cosine_sim_rep': 0.12249932,
#   'avg_cosine_sim_enhanced': 0.15797728,
#   'avg_cosine_sim_rep_enhanced': 0.12604806},
#  'MED-2368': {'avg_cosine_sim_rep': 0.07981227,
#   'avg_cosine_sim_enhanced': 0.030576706,
#   'avg_cosine_sim_rep_enhanced': 0.06412974},
#  'MED-3620': {'avg_cosine_sim_rep': 0.06820959,
#   'avg_cosine_sim_enhanced': 0.061882816,
#   'avg_cosine_sim_rep_enhanced': 0.05931169},
#  'MED-2488': {'avg_cosine_sim_rep': 0.13383627,
#   'avg_cosine_sim_enhanced': 0.12839597,
#   'avg_cosine_sim_rep_enhanced': 0.1545332},
#  'MED-3449': {'avg_cosine_sim_rep': 0.12286367,
#   'avg_cosine_sim_enhanced': 0.11989177,
#   'avg_cosine_sim_rep_enhanced': 0.11688989},
#  'MED-4159': {'avg_cosine_sim_rep': 0.1634446,
#   'avg_cosine_sim_enhanced': 0.09425388,
#   'avg_cosine_sim_rep_enhanced': 0.13051942},
#  'MED-4755': {'avg_cosine_sim_rep': 0.07208701,
#   'avg_cosine_sim_enhanced': 0.06381626,
#   'avg_cosine_sim_rep_enhanced': 0.05916469},
#  'MED-3766': {'avg_cosine_sim_rep': 0.10396701,
#   'avg_cosine_sim_enhanced': 0.113076545,
#   'avg_cosine_sim_rep_enhanced': 0.10246832},
#  'MED-1795': {'avg_cosine_sim_rep': 0.11733525,
#   'avg_cosine_sim_enhanced': 0.11423145,
#   'avg_cosine_sim_rep_enhanced': 0.11513003},
#  'MED-1998': {'avg_cosine_sim_rep': 0.1056688,
#   'avg_cosine_sim_enhanced': 0.09903733,
#   'avg_cosine_sim_rep_enhanced': 0.10073865},
#  'MED-2577': {'avg_cosine_sim_rep': 0.09818178,
#   'avg_cosine_sim_enhanced': 0.07644827,
#   'avg_cosine_sim_rep_enhanced': 0.07358235},
#  'MED-2124': {'avg_cosine_sim_rep': 0.006773254,
#   'avg_cosine_sim_enhanced': 0.033128653,
#   'avg_cosine_sim_rep_enhanced': 0.011239373},
#  'MED-1324': {'avg_cosine_sim_rep': 0.18246609,
#   'avg_cosine_sim_enhanced': 0.09807237,
#   'avg_cosine_sim_rep_enhanced': 0.1414714},
#  'MED-4303': {'avg_cosine_sim_rep': 0.16384238,
#   'avg_cosine_sim_enhanced': 0.1312291,
#   'avg_cosine_sim_rep_enhanced': 0.16369252},
#  'MED-4087': {'avg_cosine_sim_rep': 0.0352693,
#   'avg_cosine_sim_enhanced': 0.01117048,
#   'avg_cosine_sim_rep_enhanced': 0.020232853},
#  'MED-1335': {'avg_cosine_sim_rep': 0.07416793,
#   'avg_cosine_sim_enhanced': 0.057721034,
#   'avg_cosine_sim_rep_enhanced': 0.059602734},
#  'MED-2677': {'avg_cosine_sim_rep': 0.0759898,
#   'avg_cosine_sim_enhanced': 0.10131238,
#   'avg_cosine_sim_rep_enhanced': 0.08449002},
#  'MED-1319': {'avg_cosine_sim_rep': 0.079181395,
#   'avg_cosine_sim_enhanced': 0.07144455,
#   'avg_cosine_sim_rep_enhanced': 0.0710951},
#  'MED-1277': {'avg_cosine_sim_rep': 0.03804047,
#   'avg_cosine_sim_enhanced': 0.038010355,
#   'avg_cosine_sim_rep_enhanced': 0.007813611},
#  'MED-4328': {'avg_cosine_sim_rep': 0.09945152,
#   'avg_cosine_sim_enhanced': 0.076095425,
#   'avg_cosine_sim_rep_enhanced': 0.1015369},
#  'MED-3717': {'avg_cosine_sim_rep': 0.10643624,
#   'avg_cosine_sim_enhanced': 0.013453233,
#   'avg_cosine_sim_rep_enhanced': 0.08601024},
#  'MED-3850': {'avg_cosine_sim_rep': nan,
#   'avg_cosine_sim_enhanced': nan,
#   'avg_cosine_sim_rep_enhanced': nan},
#  'MED-4001': {'avg_cosine_sim_rep': 0.104063176,
#   'avg_cosine_sim_enhanced': 0.0761636,
#   'avg_cosine_sim_rep_enhanced': 0.075091},
#  'MED-1806': {'avg_cosine_sim_rep': 0.15292117,
#   'avg_cosine_sim_enhanced': 0.084892005,
#   'avg_cosine_sim_rep_enhanced': 0.08978459},
#  'MED-1317': {'avg_cosine_sim_rep': 0.11425641,
#   'avg_cosine_sim_enhanced': 0.02255223,
#   'avg_cosine_sim_rep_enhanced': 0.043666285},
#  'MED-3878': {'avg_cosine_sim_rep': 0.062094957,
#   'avg_cosine_sim_enhanced': 0.074772865,
#   'avg_cosine_sim_rep_enhanced': 0.08076725},
#  'MED-1434': {'avg_cosine_sim_rep': 0.14209548,
#   'avg_cosine_sim_enhanced': 0.13531981,
#   'avg_cosine_sim_rep_enhanced': 0.12308845},
#  'MED-1979': {'avg_cosine_sim_rep': 0.093992636,
#   'avg_cosine_sim_enhanced': 0.13158739,
#   'avg_cosine_sim_rep_enhanced': 0.075100735},
#  'MED-1375': {'avg_cosine_sim_rep': 0.11314548,
#   'avg_cosine_sim_enhanced': 0.11640905,
#   'avg_cosine_sim_rep_enhanced': 0.0989822},
#  'MED-4384': {'avg_cosine_sim_rep': 0.12589608,
#   'avg_cosine_sim_enhanced': 0.1219481,
#   'avg_cosine_sim_rep_enhanced': 0.11402763},
#  'MED-1373': {'avg_cosine_sim_rep': 0.1541226,
#   'avg_cosine_sim_enhanced': 0.09490861,
#   'avg_cosine_sim_rep_enhanced': 0.1165583},
#  'MED-4816': {'avg_cosine_sim_rep': 0.34532562,
#   'avg_cosine_sim_enhanced': 0.29915667,
#   'avg_cosine_sim_rep_enhanced': 0.2965542},
#  'MED-2210': {'avg_cosine_sim_rep': 0.06318607,
#   'avg_cosine_sim_enhanced': 0.21291053,
#   'avg_cosine_sim_rep_enhanced': 0.15615214},
#  'MED-3309': {'avg_cosine_sim_rep': 0.049619652,
#   'avg_cosine_sim_enhanced': 0.0792004,
#   'avg_cosine_sim_rep_enhanced': 0.061978888},
#  'MED-1618': {'avg_cosine_sim_rep': 0.04565045,
#   'avg_cosine_sim_enhanced': 0.063822605,
#   'avg_cosine_sim_rep_enhanced': 0.049806703},
#  'MED-4235': {'avg_cosine_sim_rep': 0.11548697,
#   'avg_cosine_sim_enhanced': 0.09840145,
#   'avg_cosine_sim_rep_enhanced': 0.08763889},
#  'MED-2265': {'avg_cosine_sim_rep': 0.21691003,
#   'avg_cosine_sim_enhanced': 0.156886,
#   'avg_cosine_sim_rep_enhanced': 0.15700266},
#  'MED-4302': {'avg_cosine_sim_rep': 0.20751125,
#   'avg_cosine_sim_enhanced': 0.14996335,
#   'avg_cosine_sim_rep_enhanced': 0.1471451},
#  'MED-4382': {'avg_cosine_sim_rep': 0.095784836,
#   'avg_cosine_sim_enhanced': 0.03862973,
#   'avg_cosine_sim_rep_enhanced': 0.059519023},
#  'MED-1221': {'avg_cosine_sim_rep': 0.06899239,
#   'avg_cosine_sim_enhanced': 0.04513769,
#   'avg_cosine_sim_rep_enhanced': 0.04035048},
#  'MED-4520': {'avg_cosine_sim_rep': 0.08690263,
#   'avg_cosine_sim_enhanced': 0.09873535,
#   'avg_cosine_sim_rep_enhanced': 0.107154414},
#  'MED-1441': {'avg_cosine_sim_rep': 0.1551601,
#   'avg_cosine_sim_enhanced': 0.18010056,
#   'avg_cosine_sim_rep_enhanced': 0.1590833},
# ...
#  'MED-1804': {'avg_cosine_sim_rep': 0.23202565,
#   'avg_cosine_sim_enhanced': 0.108147115,
#   'avg_cosine_sim_rep_enhanced': 0.118864514},
#  'MED-2237': {'avg_cosine_sim_rep': 0.09634334,
#   'avg_cosine_sim_enhanced': 0.14099102,
#   'avg_cosine_sim_rep_enhanced': 0.11276737},
#  'MED-1888': {'avg_cosine_sim_rep': -0.018417614,
#   'avg_cosine_sim_enhanced': 0.07537305,
#   'avg_cosine_sim_rep_enhanced': 0.0109791765},
#  'MED-1409': {'avg_cosine_sim_rep': 0.117932804,
#   'avg_cosine_sim_enhanced': 0.118317954,
#   'avg_cosine_sim_rep_enhanced': 0.11308596},
#  'MED-1802': {'avg_cosine_sim_rep': 0.10761901,
#   'avg_cosine_sim_enhanced': 0.113022685,
#   'avg_cosine_sim_rep_enhanced': 0.086760916},
#  'MED-666': {'avg_cosine_sim_rep': 0.0822422,
#   'avg_cosine_sim_enhanced': 0.0981975,
#   'avg_cosine_sim_rep_enhanced': 0.06827431},
#  'MED-3356': {'avg_cosine_sim_rep': 0.14138585,
#   'avg_cosine_sim_enhanced': 0.117933705,
#   'avg_cosine_sim_rep_enhanced': 0.12717934},
#  'MED-4134': {'avg_cosine_sim_rep': 0.13924104,
#   'avg_cosine_sim_enhanced': 0.108863875,
#   'avg_cosine_sim_rep_enhanced': 0.13809392},
#  'MED-3689': {'avg_cosine_sim_rep': 0.12187898,
#   'avg_cosine_sim_enhanced': 0.13900451,
#   'avg_cosine_sim_rep_enhanced': 0.118210755},
#  'MED-2518': {'avg_cosine_sim_rep': 0.08769191,
#   'avg_cosine_sim_enhanced': 0.09155789,
#   'avg_cosine_sim_rep_enhanced': 0.081339814},
#  'MED-1187': {'avg_cosine_sim_rep': 0.11760504,
#   'avg_cosine_sim_enhanced': 0.056780767,
#   'avg_cosine_sim_rep_enhanced': 0.06434255},
#  'MED-2188': {'avg_cosine_sim_rep': 0.18131818,
#   'avg_cosine_sim_enhanced': 0.20931357,
#   'avg_cosine_sim_rep_enhanced': 0.17568226},
#  'MED-2502': {'avg_cosine_sim_rep': 0.17165354,
#   'avg_cosine_sim_enhanced': 0.1394889,
#   'avg_cosine_sim_rep_enhanced': 0.1531154},
#  'MED-2468': {'avg_cosine_sim_rep': 0.1517788,
#   'avg_cosine_sim_enhanced': 0.15908068,
#   'avg_cosine_sim_rep_enhanced': 0.12960279},
#  'MED-3615': {'avg_cosine_sim_rep': 0.092155226,
#   'avg_cosine_sim_enhanced': 0.04921113,
#   'avg_cosine_sim_rep_enhanced': 0.06044561},
#  'MED-1390': {'avg_cosine_sim_rep': 0.053218976,
#   'avg_cosine_sim_enhanced': 0.023696242,
#   'avg_cosine_sim_rep_enhanced': 0.027341604},
#  'MED-2203': {'avg_cosine_sim_rep': 0.13825609,
#   'avg_cosine_sim_enhanced': 0.2100383,
#   'avg_cosine_sim_rep_enhanced': 0.17118305},
#  'MED-4125': {'avg_cosine_sim_rep': 0.16899867,
#   'avg_cosine_sim_enhanced': 0.1341727,
#   'avg_cosine_sim_rep_enhanced': 0.16092087},
#  'MED-2036': {'avg_cosine_sim_rep': 0.09550101,
#   'avg_cosine_sim_enhanced': 0.05612114,
#   'avg_cosine_sim_rep_enhanced': 0.06900116},
#  'MED-4525': {'avg_cosine_sim_rep': 0.18818735,
#   'avg_cosine_sim_enhanced': 0.10884442,
#   'avg_cosine_sim_rep_enhanced': 0.1470529},
#  'MED-1596': {'avg_cosine_sim_rep': 0.22528176,
#   'avg_cosine_sim_enhanced': 0.15517683,
#   'avg_cosine_sim_rep_enhanced': 0.18657},
#  'MED-4550': {'avg_cosine_sim_rep': 0.22714552,
#   'avg_cosine_sim_enhanced': 0.2718689,
#   'avg_cosine_sim_rep_enhanced': 0.27173582},
#  'MED-4731': {'avg_cosine_sim_rep': 0.15501437,
#   'avg_cosine_sim_enhanced': 0.16580006,
#   'avg_cosine_sim_rep_enhanced': 0.15266524},
#  'MED-2370': {'avg_cosine_sim_rep': 0.120342314,
#   'avg_cosine_sim_enhanced': 0.17011198,
#   'avg_cosine_sim_rep_enhanced': 0.12493333},
#  'MED-1737': {'avg_cosine_sim_rep': 0.13317983,
#   'avg_cosine_sim_enhanced': 0.112163134,
#   'avg_cosine_sim_rep_enhanced': 0.10326988},
#  'MED-5153': {'avg_cosine_sim_rep': 0.100329906,
#   'avg_cosine_sim_enhanced': 0.13106142,
#   'avg_cosine_sim_rep_enhanced': 0.11046702},
#  'MED-1330': {'avg_cosine_sim_rep': 0.05583977,
#   'avg_cosine_sim_enhanced': 0.02335363,
#   'avg_cosine_sim_rep_enhanced': 0.038544215},
#  'MED-1849': {'avg_cosine_sim_rep': 0.14622495,
#   'avg_cosine_sim_enhanced': 0.13711312,
#   'avg_cosine_sim_rep_enhanced': 0.13934773},
#  'MED-5329': {'avg_cosine_sim_rep': 0.13239737,
#   'avg_cosine_sim_enhanced': 0.17322557,
#   'avg_cosine_sim_rep_enhanced': 0.14519534},
#  'MED-2505': {'avg_cosine_sim_rep': 0.15540235,
#   'avg_cosine_sim_enhanced': 0.09087664,
#   'avg_cosine_sim_rep_enhanced': 0.092782535},
#  'MED-3530': {'avg_cosine_sim_rep': 0.0833241,
#   'avg_cosine_sim_enhanced': 0.086881705,
#   'avg_cosine_sim_rep_enhanced': 0.070073456},
#  'MED-1639': {'avg_cosine_sim_rep': 0.097428136,
#   'avg_cosine_sim_enhanced': 0.14176287,
#   'avg_cosine_sim_rep_enhanced': 0.11325802},
#  'MED-3683': {'avg_cosine_sim_rep': 0.17868488,
#   'avg_cosine_sim_enhanced': 0.18164934,
#   'avg_cosine_sim_rep_enhanced': 0.20340604},
#  'MED-2608': {'avg_cosine_sim_rep': nan,
#   'avg_cosine_sim_enhanced': nan,
#   'avg_cosine_sim_rep_enhanced': nan},
#  'MED-4606': {'avg_cosine_sim_rep': 0.21185732,
#   'avg_cosine_sim_enhanced': 0.19462354,
#   'avg_cosine_sim_rep_enhanced': 0.22556289},
#  'MED-4766': {'avg_cosine_sim_rep': 0.17931898,
#   'avg_cosine_sim_enhanced': 0.14427839,
#   'avg_cosine_sim_rep_enhanced': 0.15973933},
#  'MED-3840': {'avg_cosine_sim_rep': 0.06809376,
#   'avg_cosine_sim_enhanced': 0.14502853,
#   'avg_cosine_sim_rep_enhanced': 0.10272529},
#  'MED-3796': {'avg_cosine_sim_rep': 0.12113608,
#   'avg_cosine_sim_enhanced': 0.10239694,
#   'avg_cosine_sim_rep_enhanced': 0.10548671},
#  'MED-3524': {'avg_cosine_sim_rep': 0.13201387,
#   'avg_cosine_sim_enhanced': 0.075730205,
#   'avg_cosine_sim_rep_enhanced': 0.07839035},
#  'MED-1435': {'avg_cosine_sim_rep': 0.06289096,
#   'avg_cosine_sim_enhanced': 0.09039735,
#   'avg_cosine_sim_rep_enhanced': 0.09896076},
#  'MED-4713': {'avg_cosine_sim_rep': 0.15738285,
#   'avg_cosine_sim_enhanced': 0.099738516,
#   'avg_cosine_sim_rep_enhanced': 0.14163508},
#  'MED-3490': {'avg_cosine_sim_rep': 0.0937965,
#   'avg_cosine_sim_enhanced': 0.13310745,
#   'avg_cosine_sim_rep_enhanced': 0.077299535},
#  'MED-4298': {'avg_cosine_sim_rep': 0.123563826,
#   'avg_cosine_sim_enhanced': 0.083934076,
#   'avg_cosine_sim_rep_enhanced': 0.07884031},
#  'MED-2287': {'avg_cosine_sim_rep': 0.15288801,
#   'avg_cosine_sim_enhanced': 0.050643653,
#   'avg_cosine_sim_rep_enhanced': 0.121044904},
#  'MED-4347': {'avg_cosine_sim_rep': 0.055495605,
#   'avg_cosine_sim_enhanced': 0.060532264,
#   'avg_cosine_sim_rep_enhanced': 0.049488496},
#  'MED-1488': {'avg_cosine_sim_rep': 0.096713535,
#   'avg_cosine_sim_enhanced': 0.082590185,
#   'avg_cosine_sim_rep_enhanced': 0.07332432},
#  'MED-5184': {'avg_cosine_sim_rep': 0.10104175,
#   'avg_cosine_sim_enhanced': 0.2544134,
#   'avg_cosine_sim_rep_enhanced': 0.19943675},
#  'MED-1129': {'avg_cosine_sim_rep': 0.110266335,
#   'avg_cosine_sim_enhanced': 0.1320825,
#   'avg_cosine_sim_rep_enhanced': 0.10860977},
#  'MED-2389': {'avg_cosine_sim_rep': 0.16335545,
#   'avg_cosine_sim_enhanced': 0.18650533,
#   'avg_cosine_sim_rep_enhanced': 0.18580511},
#  'MED-4372': {'avg_cosine_sim_rep': 0.18686089,
#   'avg_cosine_sim_enhanced': 0.12517197,
#   'avg_cosine_sim_rep_enhanced': 0.1664},
#  'MED-1917': {'avg_cosine_sim_rep': 0.123573445,
#   'avg_cosine_sim_enhanced': 0.05193428,
#   'avg_cosine_sim_rep_enhanced': 0.08351907},
#  'MED-4680': {'avg_cosine_sim_rep': 0.14833885,
#   'avg_cosine_sim_enhanced': 0.1414906,
#   'avg_cosine_sim_rep_enhanced': 0.14186883},
#  'MED-3941': {'avg_cosine_sim_rep': 0.07167519,
#   'avg_cosine_sim_enhanced': 0.09407837,
#   'avg_cosine_sim_rep_enhanced': 0.09934139},
#  'MED-4573': {'avg_cosine_sim_rep': 0.12366237,
#   'avg_cosine_sim_enhanced': 0.037824806,
#   'avg_cosine_sim_rep_enhanced': 0.09374211},
#  'MED-4383': {'avg_cosine_sim_rep': 0.0731941,
#   'avg_cosine_sim_enhanced': 0.16224182,
#   'avg_cosine_sim_rep_enhanced': 0.13047461},
#  'MED-1950': {'avg_cosine_sim_rep': 0.18028332,
#   'avg_cosine_sim_enhanced': 0.060992032,
#   'avg_cosine_sim_rep_enhanced': 0.11377553},
#  'MED-5333': {'avg_cosine_sim_rep': 0.16199136,
#   'avg_cosine_sim_enhanced': 0.16603707,
#   'avg_cosine_sim_rep_enhanced': 0.16560279},
#  'MED-4147': {'avg_cosine_sim_rep': 0.10310523,
#   'avg_cosine_sim_enhanced': 0.040963806,
#   'avg_cosine_sim_rep_enhanced': 0.042474486},
#  'MED-1487': {'avg_cosine_sim_rep': 0.10118603,
#   'avg_cosine_sim_enhanced': 0.07940858,
#   'avg_cosine_sim_rep_enhanced': 0.07238928},
#  'MED-3690': {'avg_cosine_sim_rep': 0.13527068,
#   'avg_cosine_sim_enhanced': 0.092529416,
#   'avg_cosine_sim_rep_enhanced': 0.11531552},
#  'MED-2900': {'avg_cosine_sim_rep': 0.12971184,
#   'avg_cosine_sim_enhanced': 0.08873792,
#   'avg_cosine_sim_rep_enhanced': 0.09120892},
#  'MED-5177': {'avg_cosine_sim_rep': 0.09764286,
#   'avg_cosine_sim_enhanced': 0.12318729,
#   'avg_cosine_sim_rep_enhanced': 0.11458698},
#  'MED-2792': {'avg_cosine_sim_rep': 0.2468977,
#   'avg_cosine_sim_enhanced': 0.06534018,
#   'avg_cosine_sim_rep_enhanced': 0.11688986},
#  'MED-2722': {'avg_cosine_sim_rep': 0.063496076,
#   'avg_cosine_sim_enhanced': 0.063232854,
#   'avg_cosine_sim_rep_enhanced': 0.059346154},
#  'MED-1545': {'avg_cosine_sim_rep': 0.13776992,
#   'avg_cosine_sim_enhanced': 0.09366447,
#   'avg_cosine_sim_rep_enhanced': 0.114911236},
#  'MED-1827': {'avg_cosine_sim_rep': 0.103586644,
#   'avg_cosine_sim_enhanced': 0.11151942,
#   'avg_cosine_sim_rep_enhanced': 0.12322252},
#  'MED-2772': {'avg_cosine_sim_rep': 0.11100278,
#   'avg_cosine_sim_enhanced': 0.10199017,
#   'avg_cosine_sim_rep_enhanced': 0.10963025},
#  'MED-4691': {'avg_cosine_sim_rep': 0.04666066,
#   'avg_cosine_sim_enhanced': 0.0379049,
#   'avg_cosine_sim_rep_enhanced': 0.032127593},
#  'MED-3807': {'avg_cosine_sim_rep': 0.16711287,
#   'avg_cosine_sim_enhanced': 0.1099688,
#   'avg_cosine_sim_rep_enhanced': 0.13229369},
#  'MED-5344': {'avg_cosine_sim_rep': 0.050071456,
#   'avg_cosine_sim_enhanced': 0.03274229,
#   'avg_cosine_sim_rep_enhanced': 0.03399762},
#  'MED-3280': {'avg_cosine_sim_rep': 0.096913755,
#   'avg_cosine_sim_enhanced': 0.1577535,
#   'avg_cosine_sim_rep_enhanced': 0.114097595},
#  'MED-1208': {'avg_cosine_sim_rep': 0.13569015,
#   'avg_cosine_sim_enhanced': 0.108153336,
#   'avg_cosine_sim_rep_enhanced': 0.09567887},
#  'MED-5081': {'avg_cosine_sim_rep': 0.09934783,
#   'avg_cosine_sim_enhanced': 0.112231255,
#   'avg_cosine_sim_rep_enhanced': 0.093748026},
#  'MED-1470': {'avg_cosine_sim_rep': 0.15184066,
#   'avg_cosine_sim_enhanced': 0.1626535,
#   'avg_cosine_sim_rep_enhanced': 0.16668916},
#  'MED-5118': {'avg_cosine_sim_rep': 0.16418846,
#   'avg_cosine_sim_enhanced': 0.28976905,
#   'avg_cosine_sim_rep_enhanced': 0.24088828},
#  'MED-4381': {'avg_cosine_sim_rep': 0.097529925,
#   'avg_cosine_sim_enhanced': 0.04295253,
#   'avg_cosine_sim_rep_enhanced': 0.063241825},
#  'MED-2742': {'avg_cosine_sim_rep': 0.12568888,
#   'avg_cosine_sim_enhanced': 0.067535736,
#   'avg_cosine_sim_rep_enhanced': 0.09462403},
#  'MED-1600': {'avg_cosine_sim_rep': 0.18439597,
#   'avg_cosine_sim_enhanced': 0.22267409,
#   'avg_cosine_sim_rep_enhanced': 0.21041185},
#  'MED-3311': {'avg_cosine_sim_rep': 0.12161688,
#   'avg_cosine_sim_enhanced': 0.13105418,
#   'avg_cosine_sim_rep_enhanced': 0.11668625},
#  'MED-3922': {'avg_cosine_sim_rep': 0.11441477,
#   'avg_cosine_sim_enhanced': 0.08409614,
#   'avg_cosine_sim_rep_enhanced': 0.079203874},
#  'MED-306': {'avg_cosine_sim_rep': 0.057692807,
#   'avg_cosine_sim_enhanced': 0.06391052,
#   'avg_cosine_sim_rep_enhanced': 0.060289312},
#  'MED-3656': {'avg_cosine_sim_rep': 0.05242527,
#   'avg_cosine_sim_enhanced': 0.044447437,
#   'avg_cosine_sim_rep_enhanced': 0.03355868},
#  'MED-3385': {'avg_cosine_sim_rep': 0.23149623,
#   'avg_cosine_sim_enhanced': 0.23842199,
#   'avg_cosine_sim_rep_enhanced': 0.24659497},
#  'MED-1305': {'avg_cosine_sim_rep': 0.09050228,
#   'avg_cosine_sim_enhanced': 0.070639715,
#   'avg_cosine_sim_rep_enhanced': 0.06259589},
#  'MED-1987': {'avg_cosine_sim_rep': 0.05783184,
#   'avg_cosine_sim_enhanced': 0.035459578,
#   'avg_cosine_sim_rep_enhanced': 0.050738633},
#  'MED-3939': {'avg_cosine_sim_rep': 0.20192303,
#   'avg_cosine_sim_enhanced': 0.17102584,
#   'avg_cosine_sim_rep_enhanced': 0.2079684},
#  'MED-5190': {'avg_cosine_sim_rep': 0.12874936,
#   'avg_cosine_sim_enhanced': 0.13575962,
#   'avg_cosine_sim_rep_enhanced': 0.112497956},
#  'MED-3820': {'avg_cosine_sim_rep': 0.058040965,
#   'avg_cosine_sim_enhanced': 0.091059454,
#   'avg_cosine_sim_rep_enhanced': 0.061827052},
#  'MED-3542': {'avg_cosine_sim_rep': 0.09270293,
#   'avg_cosine_sim_enhanced': 0.111475565,
#   'avg_cosine_sim_rep_enhanced': 0.06411307},
#  'MED-1283': {'avg_cosine_sim_rep': 0.08970743,
#   'avg_cosine_sim_enhanced': 0.08847502,
#   'avg_cosine_sim_rep_enhanced': 0.07041293},
#  'MED-4760': {'avg_cosine_sim_rep': 0.0036355872,
#   'avg_cosine_sim_enhanced': 0.062423356,
#   'avg_cosine_sim_rep_enhanced': 0.06532305},
#  'MED-5157': {'avg_cosine_sim_rep': 0.17354695,
#   'avg_cosine_sim_enhanced': 0.17229924,
#   'avg_cosine_sim_rep_enhanced': 0.14660825},
#  'MED-4813': {'avg_cosine_sim_rep': 0.23490387,
#   'avg_cosine_sim_enhanced': 0.21439993,
#   'avg_cosine_sim_rep_enhanced': 0.20122375},
#  'MED-2501': {'avg_cosine_sim_rep': 0.1054222,
#   'avg_cosine_sim_enhanced': 0.0916162,
#   'avg_cosine_sim_rep_enhanced': 0.079900116},
#  'MED-4786': {'avg_cosine_sim_rep': 0.102087095,
#   'avg_cosine_sim_enhanced': 0.23676759,
#   'avg_cosine_sim_rep_enhanced': 0.16252264},
#  'MED-3758': {'avg_cosine_sim_rep': 0.015827347,
#   'avg_cosine_sim_enhanced': 0.100643046,
#   'avg_cosine_sim_rep_enhanced': 0.03998828},
#  'MED-4515': {'avg_cosine_sim_rep': 0.06574196,
#   'avg_cosine_sim_enhanced': 0.07812536,
#   'avg_cosine_sim_rep_enhanced': 0.068715855},
#  'MED-4417': {'avg_cosine_sim_rep': 0.07923338,
#   'avg_cosine_sim_enhanced': 0.088079065,
#   'avg_cosine_sim_rep_enhanced': 0.090198874},
#  'MED-5026': {'avg_cosine_sim_rep': 0.038118772,
#   'avg_cosine_sim_enhanced': 0.030762091,
#   'avg_cosine_sim_rep_enhanced': 0.008941916},
#  'MED-1811': {'avg_cosine_sim_rep': 0.21921298,
#   'avg_cosine_sim_enhanced': 0.21490768,
#   'avg_cosine_sim_rep_enhanced': 0.22280619},
#  'MED-2664': {'avg_cosine_sim_rep': 0.07066153,
#   'avg_cosine_sim_enhanced': 0.098175265,
#   'avg_cosine_sim_rep_enhanced': 0.07295789},
#  'MED-1098': {'avg_cosine_sim_rep': 0.15398763,
#   'avg_cosine_sim_enhanced': 0.11210761,
#   'avg_cosine_sim_rep_enhanced': 0.13896461},
#  'MED-3354': {'avg_cosine_sim_rep': 0.04393775,
#   'avg_cosine_sim_enhanced': 0.06516794,
#   'avg_cosine_sim_rep_enhanced': 0.0678066},
#  'MED-4234': {'avg_cosine_sim_rep': 0.050809443,
#   'avg_cosine_sim_enhanced': 0.04781781,
#   'avg_cosine_sim_rep_enhanced': 0.038744405},
#  'MED-4091': {'avg_cosine_sim_rep': 0.12250657,
#   'avg_cosine_sim_enhanced': 0.13139562,
#   'avg_cosine_sim_rep_enhanced': 0.11468274},
#  'MED-1587': {'avg_cosine_sim_rep': 0.07219252,
#   'avg_cosine_sim_enhanced': 0.07972303,
#   'avg_cosine_sim_rep_enhanced': 0.090942994},
#  'MED-3654': {'avg_cosine_sim_rep': 0.16958708,
#   'avg_cosine_sim_enhanced': 0.17628856,
#   'avg_cosine_sim_rep_enhanced': 0.170886},
#  'MED-1607': {'avg_cosine_sim_rep': 0.18365887,
#   'avg_cosine_sim_enhanced': 0.2129663,
#   'avg_cosine_sim_rep_enhanced': 0.18709959},
#  'MED-1791': {'avg_cosine_sim_rep': 0.037965275,
#   'avg_cosine_sim_enhanced': 0.08608384,
#   'avg_cosine_sim_rep_enhanced': 0.04619567},
#  'MED-3976': {'avg_cosine_sim_rep': 0.034480445,
#   'avg_cosine_sim_enhanced': 0.10432007,
#   'avg_cosine_sim_rep_enhanced': 0.05103883},
#  'MED-2521': {'avg_cosine_sim_rep': 0.08173922,
#   'avg_cosine_sim_enhanced': 0.097545765,
#   'avg_cosine_sim_rep_enhanced': 0.06767719},
#  'MED-3885': {'avg_cosine_sim_rep': 0.036599476,
#   'avg_cosine_sim_enhanced': 0.047609694,
#   'avg_cosine_sim_rep_enhanced': 0.02268638},
#  'MED-2412': {'avg_cosine_sim_rep': 0.12351084,
#   'avg_cosine_sim_enhanced': 0.122980595,
#   'avg_cosine_sim_rep_enhanced': 0.12371543},
#  'MED-3399': {'avg_cosine_sim_rep': 0.012318309,
#   'avg_cosine_sim_enhanced': 0.04313577,
#   'avg_cosine_sim_rep_enhanced': -0.012536644},
#  'MED-3749': {'avg_cosine_sim_rep': 0.111342214,
#   'avg_cosine_sim_enhanced': 0.17118457,
#   'avg_cosine_sim_rep_enhanced': 0.1583298},
#  'MED-3699': {'avg_cosine_sim_rep': 0.10218886,
#   'avg_cosine_sim_enhanced': 0.12356383,
#   'avg_cosine_sim_rep_enhanced': 0.11012405},
#  'MED-4290': {'avg_cosine_sim_rep': 0.09438776,
#   'avg_cosine_sim_enhanced': 0.08855806,
#   'avg_cosine_sim_rep_enhanced': 0.07944186},
#  'MED-3627': {'avg_cosine_sim_rep': 0.07068177,
#   'avg_cosine_sim_enhanced': 0.055599127,
#   'avg_cosine_sim_rep_enhanced': 0.06166199}}

# %%
results = {
    "avg_cosine_sim_rep":
        np.nanmean([v['avg_cosine_sim_rep']            for v in avg_cosine_sim.values()]),
    "avg_cosine_sim_enhanced":
        np.nanmean([v['avg_cosine_sim_enhanced']       for v in avg_cosine_sim.values()]),
    "avg_cosine_sim_rep_enhanced":
        np.nanmean([v['avg_cosine_sim_rep_enhanced']   for v in avg_cosine_sim.values()]),
}
results
# Out:
# {'avg_cosine_sim_rep': 0.1112142515903303,
#  'avg_cosine_sim_enhanced': 0.10548924442992584,
#  'avg_cosine_sim_rep_enhanced': 0.10203854355672345}

# %%
import numpy as np
avg_cosine_sim = {} # doc_id -> avg cosine similarity
for doc in sampled_docs:
    doc_id = doc['doc_id']
    doc_text = doc['text']
    doc_title = doc['title']
    doc_text_embed = embed([doc_text])[0]
    doc_title_embed = embed([doc_title])[0]
    queries = doc['queries'] # list of queries
    topic_ids = [t['topic_id'] for t in doc_topic_info_dict[doc_id]]
    cosine_sims = []
    for query in queries:
        query_embed = embed([query])[0]
        cos_sim_text_title = float(np.dot(doc_text_embed, doc_title_embed))
        cos_sim_query_text = float(np.dot(query_embed, doc_text_embed))
        cos_sim_query_title = float(np.dot(query_embed, doc_title_embed))
        cosine_sims.append((cos_sim_text_title, cos_sim_query_text, cos_sim_query_title))
    avg_cosine_sim[doc_id] = {
        'avg_cos_sim_text_title': np.nanmean([sim[0] for sim in cosine_sims]),
        'avg_cos_sim_query_text': np.nanmean([sim[1] for sim in cosine_sims]),
        'avg_cos_sim_query_title': np.nanmean([sim[2] for sim in cosine_sims]),
    }
avg_cosine_sim
# Out:
# {'MED-4635': {'avg_cos_sim_text_title': 0.8181056976318359,
#   'avg_cos_sim_query_text': 0.13240932952612638,
#   'avg_cos_sim_query_title': 0.16894018603488803},
#  'MED-1578': {'avg_cos_sim_text_title': 0.8104920387268066,
#   'avg_cos_sim_query_text': 0.2982138991355896,
#   'avg_cos_sim_query_title': 0.30337146297097206},
#  'MED-1150': {'avg_cos_sim_text_title': 0.8568789958953857,
#   'avg_cos_sim_query_text': 0.2798227866490682,
#   'avg_cos_sim_query_title': 0.24127397686243057},
#  'MED-5152': {'avg_cos_sim_text_title': 0.8424941897392273,
#   'avg_cos_sim_query_text': 0.23720304667949677,
#   'avg_cos_sim_query_title': 0.2830433249473572},
#  'MED-2421': {'avg_cos_sim_text_title': 0.8563762903213501,
#   'avg_cos_sim_query_text': 0.23848023265600204,
#   'avg_cos_sim_query_title': 0.10720447823405266},
#  'MED-2260': {'avg_cos_sim_text_title': 0.9218974113464355,
#   'avg_cos_sim_query_text': 0.12088546560456355,
#   'avg_cos_sim_query_title': 0.09137757929662864},
#  'MED-2152': {'avg_cos_sim_text_title': 0.7775894999504089,
#   'avg_cos_sim_query_text': 0.25509518533945086,
#   'avg_cos_sim_query_title': 0.3034038066864014},
#  'MED-1723': {'avg_cos_sim_text_title': 0.8336130380630493,
#   'avg_cos_sim_query_text': 0.3095260187983513,
#   'avg_cos_sim_query_title': 0.2733502462506294},
#  'MED-5124': {'avg_cos_sim_text_title': 0.884179949760437,
#   'avg_cos_sim_query_text': 0.38247382640838623,
#   'avg_cos_sim_query_title': 0.32359907031059265},
#  'MED-1533': {'avg_cos_sim_text_title': 0.8152437210083008,
#   'avg_cos_sim_query_text': 0.3223646730184555,
#   'avg_cos_sim_query_title': 0.2949737086892128},
#  'MED-4822': {'avg_cos_sim_text_title': 0.9437596201896667,
#   'avg_cos_sim_query_text': 0.2121913805603981,
#   'avg_cos_sim_query_title': 0.1824820637702942},
#  'MED-5148': {'avg_cos_sim_text_title': 0.8467046022415161,
#   'avg_cos_sim_query_text': 0.28378790616989136,
#   'avg_cos_sim_query_title': 0.2751449942588806},
#  'MED-4104': {'avg_cos_sim_text_title': 0.9297317266464233,
#   'avg_cos_sim_query_text': 0.2281098092595736,
#   'avg_cos_sim_query_title': 0.20087146138151488},
#  'MED-1465': {'avg_cos_sim_text_title': 0.6989497542381287,
#   'avg_cos_sim_query_text': 0.29266995191574097,
#   'avg_cos_sim_query_title': 0.23889997601509094},
#  'MED-4363': {'avg_cos_sim_text_title': 0.8781795501708984,
#   'avg_cos_sim_query_text': 0.29147685567537945,
#   'avg_cos_sim_query_title': 0.2689675986766815},
#  'MED-3445': {'avg_cos_sim_text_title': 0.6648303866386414,
#   'avg_cos_sim_query_text': 0.26538507640361786,
#   'avg_cos_sim_query_title': 0.19885174930095673},
#  'MED-1184': {'avg_cos_sim_text_title': 0.8812305331230164,
#   'avg_cos_sim_query_text': 0.2090156152844429,
#   'avg_cos_sim_query_title': 0.24508873373270035},
#  'MED-1175': {'avg_cos_sim_text_title': 0.8983570337295532,
#   'avg_cos_sim_query_text': 0.2224482912570238,
#   'avg_cos_sim_query_title': 0.2225304190069437},
#  'MED-1497': {'avg_cos_sim_text_title': 0.7276540994644165,
#   'avg_cos_sim_query_text': 0.054060282185673714,
#   'avg_cos_sim_query_title': 0.07171144057065248},
#  'MED-2129': {'avg_cos_sim_text_title': 0.47351300716400146,
#   'avg_cos_sim_query_text': 0.13365234496692815,
#   'avg_cos_sim_query_title': 0.07807046532010038},
#  'MED-2195': {'avg_cos_sim_text_title': 0.9213032722473145,
#   'avg_cos_sim_query_text': 0.19477546215057373,
#   'avg_cos_sim_query_title': 0.1799574668208758},
#  'MED-3863': {'avg_cos_sim_text_title': 0.8379313945770264,
#   'avg_cos_sim_query_text': 0.054263281635940075,
#   'avg_cos_sim_query_title': 0.03815382160246372},
#  'MED-4419': {'avg_cos_sim_text_title': 0.8112335205078125,
#   'avg_cos_sim_query_text': 0.10813915729522705,
#   'avg_cos_sim_query_title': 0.042181044816970825},
#  'MED-1158': {'avg_cos_sim_text_title': 0.8056125640869141,
#   'avg_cos_sim_query_text': 0.3383137807250023,
#   'avg_cos_sim_query_title': 0.35324355959892273},
#  'MED-4183': {'avg_cos_sim_text_title': 0.7980927228927612,
#   'avg_cos_sim_query_text': 0.12935957964509726,
#   'avg_cos_sim_query_title': 0.15833731244007745},
#  'MED-2040': {'avg_cos_sim_text_title': 0.8786380290985107,
#   'avg_cos_sim_query_text': 0.10078323384126027,
#   'avg_cos_sim_query_title': 0.10353018033007781},
#  'MED-5027': {'avg_cos_sim_text_title': 0.8638335466384888,
#   'avg_cos_sim_query_text': 0.15988218784332275,
#   'avg_cos_sim_query_title': 0.1427266001701355},
#  'MED-4690': {'avg_cos_sim_text_title': 0.7541712522506714,
#   'avg_cos_sim_query_text': -0.005604403093457222,
#   'avg_cos_sim_query_title': 0.0043460167944431305},
#  'MED-4953': {'avg_cos_sim_text_title': 0.8175204992294312,
#   'avg_cos_sim_query_text': 0.16818296164274216,
#   'avg_cos_sim_query_title': 0.15008683130145073},
#  'MED-4103': {'avg_cos_sim_text_title': 0.8771606087684631,
#   'avg_cos_sim_query_text': 0.21495041251182556,
#   'avg_cos_sim_query_title': 0.1626508707801501},
#  'MED-3435': {'avg_cos_sim_text_title': 0.8977378010749817,
#   'avg_cos_sim_query_text': 0.04198906167099873,
#   'avg_cos_sim_query_title': 0.04728083653996388},
#  'MED-2138': {'avg_cos_sim_text_title': 0.7652237415313721,
#   'avg_cos_sim_query_text': 0.21526860569914183,
#   'avg_cos_sim_query_title': 0.2793423514813185},
#  'MED-3588': {'avg_cos_sim_text_title': 0.9056259393692017,
#   'avg_cos_sim_query_text': 0.18559805527329445,
#   'avg_cos_sim_query_title': 0.15948098637163638},
#  'MED-4357': {'avg_cos_sim_text_title': 0.8581221103668213,
#   'avg_cos_sim_query_text': 0.2753707369168599,
#   'avg_cos_sim_query_title': 0.35537275671958923},
#  'MED-2436': {'avg_cos_sim_text_title': 0.8448299169540405,
#   'avg_cos_sim_query_text': 0.5079026222229004,
#   'avg_cos_sim_query_title': 0.44592589139938354},
#  'MED-735': {'avg_cos_sim_text_title': 0.8773736953735352,
#   'avg_cos_sim_query_text': 0.049696918576955795,
#   'avg_cos_sim_query_title': 0.05812389403581619},
#  'MED-1818': {'avg_cos_sim_text_title': 0.8476452827453613,
#   'avg_cos_sim_query_text': 0.3656286597251892,
#   'avg_cos_sim_query_title': 0.3018491864204407},
#  'MED-4939': {'avg_cos_sim_text_title': 0.7521579265594482,
#   'avg_cos_sim_query_text': 0.2560137021355331,
#   'avg_cos_sim_query_title': 0.20241555199027061},
#  'MED-3448': {'avg_cos_sim_text_title': 0.9055201411247253,
#   'avg_cos_sim_query_text': 0.27841340750455856,
#   'avg_cos_sim_query_title': 0.2161194235086441},
#  'MED-2824': {'avg_cos_sim_text_title': 0.8234890699386597,
#   'avg_cos_sim_query_text': 0.161065012216568,
#   'avg_cos_sim_query_title': 0.1322133963306745},
#  'MED-2435': {'avg_cos_sim_text_title': 0.7544638514518738,
#   'avg_cos_sim_query_text': 0.42286133766174316,
#   'avg_cos_sim_query_title': 0.5915881395339966},
#  'MED-1797': {'avg_cos_sim_text_title': 0.7781872749328613,
#   'avg_cos_sim_query_text': 0.13065986335277557,
#   'avg_cos_sim_query_title': 0.12926088832318783},
#  'MED-2111': {'avg_cos_sim_text_title': 0.31629088521003723,
#   'avg_cos_sim_query_text': 0.15783737390302122,
#   'avg_cos_sim_query_title': 0.1660555936396122},
#  'MED-2809': {'avg_cos_sim_text_title': 0.8002465963363647,
#   'avg_cos_sim_query_text': 0.2005625069141388,
#   'avg_cos_sim_query_title': 0.16932457046849386},
#  'MED-1532': {'avg_cos_sim_text_title': 0.8712010979652405,
#   'avg_cos_sim_query_text': 0.23239595496228763,
#   'avg_cos_sim_query_title': 0.19082893351359026},
#  'MED-1493': {'avg_cos_sim_text_title': 0.7842326164245605,
#   'avg_cos_sim_query_text': 0.2294202744960785,
#   'avg_cos_sim_query_title': 0.27564670642217},
#  'MED-3144': {'avg_cos_sim_text_title': 0.8975501656532288,
#   'avg_cos_sim_query_text': 0.11879338324069977,
#   'avg_cos_sim_query_title': 0.07567719742655754},
#  'MED-1510': {'avg_cos_sim_text_title': 0.8256449103355408,
#   'avg_cos_sim_query_text': 0.01772182062268257,
#   'avg_cos_sim_query_title': 0.029365364462137222},
#  'MED-2986': {'avg_cos_sim_text_title': 0.8246370553970337,
#   'avg_cos_sim_query_text': 0.16132733412086964,
#   'avg_cos_sim_query_title': 0.09156519779935479},
#  'MED-2852': {'avg_cos_sim_text_title': 0.8823691606521606,
#   'avg_cos_sim_query_text': 0.24084603786468506,
#   'avg_cos_sim_query_title': 0.32482093572616577},
#  'MED-4427': {'avg_cos_sim_text_title': 0.9128062725067139,
#   'avg_cos_sim_query_text': 0.35251450538635254,
#   'avg_cos_sim_query_title': 0.34214645624160767},
#  'MED-2365': {'avg_cos_sim_text_title': 0.8999987244606018,
#   'avg_cos_sim_query_text': 0.2194877877831459,
#   'avg_cos_sim_query_title': 0.21905749291181564},
#  'MED-1241': {'avg_cos_sim_text_title': 0.9412330389022827,
#   'avg_cos_sim_query_text': 0.2706475257873535,
#   'avg_cos_sim_query_title': 0.2668482760588328},
#  'MED-5094': {'avg_cos_sim_text_title': 0.7486234903335571,
#   'avg_cos_sim_query_text': 0.20380382736523947,
#   'avg_cos_sim_query_title': 0.1442350670695305},
#  'MED-3638': {'avg_cos_sim_text_title': 0.873673677444458,
#   'avg_cos_sim_query_text': -0.005315106362104416,
#   'avg_cos_sim_query_title': -0.008336788043379784},
#  'MED-4035': {'avg_cos_sim_text_title': 0.8486546874046326,
#   'avg_cos_sim_query_text': 0.054724935442209244,
#   'avg_cos_sim_query_title': 0.03617168217897415},
#  'MED-1641': {'avg_cos_sim_text_title': 0.8826852440834045,
#   'avg_cos_sim_query_text': 0.2790752521583012,
#   'avg_cos_sim_query_title': 0.2555761837533542},
#  'MED-3138': {'avg_cos_sim_text_title': 0.8539077639579773,
#   'avg_cos_sim_query_text': 0.25032990479043554,
#   'avg_cos_sim_query_title': 0.22414698132446834},
#  'MED-1428': {'avg_cos_sim_text_title': 0.7523769736289978,
#   'avg_cos_sim_query_text': 0.07170325517654419,
#   'avg_cos_sim_query_title': 0.03355807065963745},
#  'MED-4139': {'avg_cos_sim_text_title': 0.8346666097640991,
#   'avg_cos_sim_query_text': 0.20172677785158158,
#   'avg_cos_sim_query_title': 0.1296166729182005},
#  'MED-2526': {'avg_cos_sim_text_title': 0.7735071778297424,
#   'avg_cos_sim_query_text': 0.23261875872101104,
#   'avg_cos_sim_query_title': 0.2405978228364672},
#  'MED-4574': {'avg_cos_sim_text_title': 0.8927717804908752,
#   'avg_cos_sim_query_text': 0.2539432682096958,
#   'avg_cos_sim_query_title': 0.24445232190191746},
#  'MED-4516': {'avg_cos_sim_text_title': 0.8728736639022827,
#   'avg_cos_sim_query_text': 0.4556184858083725,
#   'avg_cos_sim_query_title': 0.4892403185367584},
#  'MED-3000': {'avg_cos_sim_text_title': 0.8078758716583252,
#   'avg_cos_sim_query_text': 0.18187319673597813,
#   'avg_cos_sim_query_title': 0.13521508197300136},
#  'MED-4292': {'avg_cos_sim_text_title': 0.6853219270706177,
#   'avg_cos_sim_query_text': 0.43029069900512695,
#   'avg_cos_sim_query_title': 0.4962494373321533},
#  'MED-2008': {'avg_cos_sim_text_title': 0.8930994272232056,
#   'avg_cos_sim_query_text': 0.24762957990169526,
#   'avg_cos_sim_query_title': 0.1605125367641449},
#  'MED-4967': {'avg_cos_sim_text_title': 0.8558537364006042,
#   'avg_cos_sim_query_text': 0.3301825672388077,
#   'avg_cos_sim_query_title': 0.22707690298557281},
#  'MED-1380': {'avg_cos_sim_text_title': 0.7405859231948853,
#   'avg_cos_sim_query_text': 0.1800296093736376,
#   'avg_cos_sim_query_title': 0.17870161150182998},
#  'MED-1252': {'avg_cos_sim_text_title': 0.8718044757843018,
#   'avg_cos_sim_query_text': 0.2922017052769661,
#   'avg_cos_sim_query_title': 0.2347716987133026},
#  'MED-4751': {'avg_cos_sim_text_title': 0.7641161680221558,
#   'avg_cos_sim_query_text': 0.28222348416845006,
#   'avg_cos_sim_query_title': 0.21747874918704233},
#  'MED-2171': {'avg_cos_sim_text_title': 0.8192181587219238,
#   'avg_cos_sim_query_text': 0.18224516580812633,
#   'avg_cos_sim_query_title': 0.1487853042781353},
#  'MED-2509': {'avg_cos_sim_text_title': 0.772951602935791,
#   'avg_cos_sim_query_text': 0.22293603140860796,
#   'avg_cos_sim_query_title': 0.20359914051368833},
#  'MED-1432': {'avg_cos_sim_text_title': 0.8844965696334839,
#   'avg_cos_sim_query_text': 0.2468198835849762,
#   'avg_cos_sim_query_title': 0.2929481789469719},
#  'MED-2200': {'avg_cos_sim_text_title': 0.8298026919364929,
#   'avg_cos_sim_query_text': 0.24529946595430374,
#   'avg_cos_sim_query_title': 0.21080805733799934},
#  'MED-1527': {'avg_cos_sim_text_title': 0.8899455070495605,
#   'avg_cos_sim_query_text': 0.20221283818994248,
#   'avg_cos_sim_query_title': 0.17056789661624602},
#  'MED-5266': {'avg_cos_sim_text_title': 0.875282883644104,
#   'avg_cos_sim_query_text': 0.5271242260932922,
#   'avg_cos_sim_query_title': 0.5301451086997986},
#  'MED-5272': {'avg_cos_sim_text_title': 0.8256193399429321,
#   'avg_cos_sim_query_text': 0.6173044443130493,
#   'avg_cos_sim_query_title': 0.755049467086792},
#  'MED-3609': {'avg_cos_sim_text_title': 0.9360191822052002,
#   'avg_cos_sim_query_text': 0.1665896438062191,
#   'avg_cos_sim_query_title': 0.19737909734249115},
#  'MED-4617': {'avg_cos_sim_text_title': 0.8409509658813477,
#   'avg_cos_sim_query_text': 0.12129014320671558,
#   'avg_cos_sim_query_title': 0.13675771839916706},
#  'MED-3028': {'avg_cos_sim_text_title': 0.9102795720100403,
#   'avg_cos_sim_query_text': 0.30694369904019614,
#   'avg_cos_sim_query_title': 0.3091066533868963},
#  'MED-1836': {'avg_cos_sim_text_title': 0.8902742266654968,
#   'avg_cos_sim_query_text': 0.16338324546813965,
#   'avg_cos_sim_query_title': 0.09382187575101852},
#  'MED-3085': {'avg_cos_sim_text_title': 0.8960078954696655,
#   'avg_cos_sim_query_text': 0.25605951520529663,
#   'avg_cos_sim_query_title': 0.26699990372766147},
#  'MED-2969': {'avg_cos_sim_text_title': 0.7228233218193054,
#   'avg_cos_sim_query_text': 0.14593947445973754,
#   'avg_cos_sim_query_title': 0.13190065720118582},
#  'MED-2087': {'avg_cos_sim_text_title': 0.6119201183319092,
#   'avg_cos_sim_query_text': 0.32841511567433673,
#   'avg_cos_sim_query_title': 0.22721629838148752},
#  'MED-4796': {'avg_cos_sim_text_title': 0.8415920734405518,
#   'avg_cos_sim_query_text': 0.062822625041008,
#   'avg_cos_sim_query_title': 0.08813747204840183},
#  'MED-2378': {'avg_cos_sim_text_title': 0.7803542613983154,
#   'avg_cos_sim_query_text': 0.352063849568367,
#   'avg_cos_sim_query_title': 0.4002340982357661},
#  'MED-4955': {'avg_cos_sim_text_title': 0.7605354189872742,
#   'avg_cos_sim_query_text': 0.3012533187866211,
#   'avg_cos_sim_query_title': 0.23214847346146902},
#  'MED-4853': {'avg_cos_sim_text_title': 0.9115996360778809,
#   'avg_cos_sim_query_text': 0.2755936582883199,
#   'avg_cos_sim_query_title': 0.2574366753300031},
#  'MED-4677': {'avg_cos_sim_text_title': 0.6331027746200562,
#   'avg_cos_sim_query_text': 0.46305781602859497,
#   'avg_cos_sim_query_title': 0.644179493188858},
#  'MED-1393': {'avg_cos_sim_text_title': 0.8392273187637329,
#   'avg_cos_sim_query_text': 0.15824402421712874,
#   'avg_cos_sim_query_title': 0.1166545843705535},
#  'MED-4469': {'avg_cos_sim_text_title': 0.8234797716140747,
#   'avg_cos_sim_query_text': 0.25071045756340027,
#   'avg_cos_sim_query_title': 0.22556709249814352},
#  'MED-4613': {'avg_cos_sim_text_title': 0.8363912105560303,
#   'avg_cos_sim_query_text': 0.2104273483157158,
#   'avg_cos_sim_query_title': 0.19687737971544267},
#  'MED-1874': {'avg_cos_sim_text_title': 0.8177275657653809,
#   'avg_cos_sim_query_text': 0.22277584671974182,
#   'avg_cos_sim_query_title': 0.2199784517288208},
#  'MED-4026': {'avg_cos_sim_text_title': 0.5013086795806885,
#   'avg_cos_sim_query_text': 0.22328799962997437,
#   'avg_cos_sim_query_title': 0.35536351799964905},
#  'MED-5092': {'avg_cos_sim_text_title': 0.8064013123512268,
#   'avg_cos_sim_query_text': 0.21242110803723335,
#   'avg_cos_sim_query_title': 0.1757169310003519},
#  'MED-2259': {'avg_cos_sim_text_title': 0.8422421813011169,
#   'avg_cos_sim_query_text': 0.11056128423660994,
#   'avg_cos_sim_query_title': 0.0685068176438411},
#  'MED-1839': {'avg_cos_sim_text_title': 0.8828496932983398,
#   'avg_cos_sim_query_text': 0.25007718801498413,
#   'avg_cos_sim_query_title': 0.2219235748052597},
#  'MED-3657': {'avg_cos_sim_text_title': 0.8481925129890442,
#   'avg_cos_sim_query_text': 0.10710085493822892,
#   'avg_cos_sim_query_title': 0.10351669819404681},
#  'MED-3142': {'avg_cos_sim_text_title': 0.8880321383476257,
#   'avg_cos_sim_query_text': 0.12579767095545927,
#   'avg_cos_sim_query_title': 0.11867772415280342},
#  'MED-2394': {'avg_cos_sim_text_title': 0.8391362428665161,
#   'avg_cos_sim_query_text': 0.34084950387477875,
#   'avg_cos_sim_query_title': 0.3274012068286538},
#  'MED-4638': {'avg_cos_sim_text_title': 0.9209381341934204,
#   'avg_cos_sim_query_text': 0.4296372855703036,
#   'avg_cos_sim_query_title': 0.3954513693849246},
#  'MED-4876': {'avg_cos_sim_text_title': 0.6986773014068604,
#   'avg_cos_sim_query_text': 0.19839804619550705,
#   'avg_cos_sim_query_title': 0.19494685530662537},
#  'MED-4164': {'avg_cos_sim_text_title': 0.8150814771652222,
#   'avg_cos_sim_query_text': 0.2287372350692749,
#   'avg_cos_sim_query_title': 0.30027973651885986},
#  'MED-2135': {'avg_cos_sim_text_title': 0.7617043852806091,
#   'avg_cos_sim_query_text': 0.21342551273604235,
#   'avg_cos_sim_query_title': 0.1418496553475658},
#  'MED-4858': {'avg_cos_sim_text_title': 0.8750354051589966,
#   'avg_cos_sim_query_text': 0.18553012609481812,
#   'avg_cos_sim_query_title': 0.11528085917234421},
#  'MED-2746': {'avg_cos_sim_text_title': 0.8921300172805786,
#   'avg_cos_sim_query_text': 0.36752381175756454,
#   'avg_cos_sim_query_title': 0.3648977279663086},
#  'MED-1314': {'avg_cos_sim_text_title': 0.8465508818626404,
#   'avg_cos_sim_query_text': 0.12641042470932007,
#   'avg_cos_sim_query_title': 0.11478705704212189},
#  'MED-2176': {'avg_cos_sim_text_title': 0.7529773712158203,
#   'avg_cos_sim_query_text': 0.20876234428336224,
#   'avg_cos_sim_query_title': 0.13286448766787848},
#  'MED-1185': {'avg_cos_sim_text_title': 0.837822675704956,
#   'avg_cos_sim_query_text': 0.29284053295850754,
#   'avg_cos_sim_query_title': 0.2932947725057602},
#  'MED-2698': {'avg_cos_sim_text_title': 0.918147623538971,
#   'avg_cos_sim_query_text': 0.07181856036186218,
#   'avg_cos_sim_query_title': 0.10540448129177094},
#  'MED-3283': {'avg_cos_sim_text_title': 0.8469651937484741,
#   'avg_cos_sim_query_text': 0.16622914634644986,
#   'avg_cos_sim_query_title': 0.12792033813893794},
#  'MED-2381': {'avg_cos_sim_text_title': 0.8791183233261108,
#   'avg_cos_sim_query_text': 0.34136447310447693,
#   'avg_cos_sim_query_title': 0.35810009638468426},
#  'MED-1359': {'avg_cos_sim_text_title': 0.8355410099029541,
#   'avg_cos_sim_query_text': 0.2064274549484253,
#   'avg_cos_sim_query_title': 0.16970860958099365},
#  'MED-2093': {'avg_cos_sim_text_title': 0.8448886871337891,
#   'avg_cos_sim_query_text': -0.04414600133895874,
#   'avg_cos_sim_query_title': -0.05952490493655205},
#  'MED-4224': {'avg_cos_sim_text_title': 0.865592360496521,
#   'avg_cos_sim_query_text': 0.17426541000604628,
#   'avg_cos_sim_query_title': 0.1772891590371728},
#  'MED-5036': {'avg_cos_sim_text_title': 0.8681872487068176,
#   'avg_cos_sim_query_text': 0.3832992911338806,
#   'avg_cos_sim_query_title': 0.3647107779979706},
#  'MED-2694': {'avg_cos_sim_text_title': 0.775109052658081,
#   'avg_cos_sim_query_text': 0.015717195346951485,
#   'avg_cos_sim_query_title': 0.03455347940325737},
#  'MED-2099': {'avg_cos_sim_text_title': 0.8444299697875977,
#   'avg_cos_sim_query_text': 0.2781277770797412,
#   'avg_cos_sim_query_title': 0.2841892937819163},
#  'MED-4721': {'avg_cos_sim_text_title': 0.8632439374923706,
#   'avg_cos_sim_query_text': 0.26056140661239624,
#   'avg_cos_sim_query_title': 0.2553638219833374},
#  'MED-3830': {'avg_cos_sim_text_title': 0.8909012079238892,
#   'avg_cos_sim_query_text': 0.37575939670205116,
#   'avg_cos_sim_query_title': 0.34486082196235657},
#  'MED-3245': {'avg_cos_sim_text_title': 0.8748183250427246,
#   'avg_cos_sim_query_text': 0.2797868177294731,
#   'avg_cos_sim_query_title': 0.23170798830688},
#  'MED-4651': {'avg_cos_sim_text_title': 0.745213508605957,
#   'avg_cos_sim_query_text': 0.07792814821004868,
#   'avg_cos_sim_query_title': 0.064829520881176},
#  'MED-3636': {'avg_cos_sim_text_title': 0.6453312039375305,
#   'avg_cos_sim_query_text': 0.19093712088134554,
#   'avg_cos_sim_query_title': 0.17249095253646374},
#  'MED-1740': {'avg_cos_sim_text_title': 0.8388504981994629,
#   'avg_cos_sim_query_text': 0.43987393379211426,
#   'avg_cos_sim_query_title': 0.43827784061431885},
#  'MED-2366': {'avg_cos_sim_text_title': 0.8208714127540588,
#   'avg_cos_sim_query_text': 0.07666300516575575,
#   'avg_cos_sim_query_title': 0.09369639423675835},
#  'MED-5363': {'avg_cos_sim_text_title': 0.9016910195350647,
#   'avg_cos_sim_query_text': 0.17284349708019622,
#   'avg_cos_sim_query_title': 0.15730508609807917},
#  'MED-2267': {'avg_cos_sim_text_title': 0.8380812406539917,
#   'avg_cos_sim_query_text': 0.12538382411003113,
#   'avg_cos_sim_query_title': 0.13995465636253357},
#  'MED-4184': {'avg_cos_sim_text_title': 0.8528206944465637,
#   'avg_cos_sim_query_text': 0.13635276102771363,
#   'avg_cos_sim_query_title': 0.12691086220244566},
#  'MED-4057': {'avg_cos_sim_text_title': 0.8092406392097473,
#   'avg_cos_sim_query_text': 0.4792401045560837,
#   'avg_cos_sim_query_title': 0.40116018056869507},
#  'MED-2357': {'avg_cos_sim_text_title': 0.67577064037323,
#   'avg_cos_sim_query_text': 0.11430222913622856,
#   'avg_cos_sim_query_title': 0.0894311424344778},
#  'MED-4330': {'avg_cos_sim_text_title': 0.8398411273956299,
#   'avg_cos_sim_query_text': 0.3392757922410965,
#   'avg_cos_sim_query_title': 0.37419167160987854},
#  'MED-3475': {'avg_cos_sim_text_title': 0.8573876023292542,
#   'avg_cos_sim_query_text': 0.19114025682210922,
#   'avg_cos_sim_query_title': 0.1818089410662651},
#  'MED-4325': {'avg_cos_sim_text_title': 0.8899505138397217,
#   'avg_cos_sim_query_text': 0.6485971659421921,
#   'avg_cos_sim_query_title': 0.6635338068008423},
#  'MED-3275': {'avg_cos_sim_text_title': 0.9276374578475952,
#   'avg_cos_sim_query_text': 0.1127737401984632,
#   'avg_cos_sim_query_title': 0.08520539961755276},
#  'MED-3001': {'avg_cos_sim_text_title': 0.7367391586303711,
#   'avg_cos_sim_query_text': 0.13138960860669613,
#   'avg_cos_sim_query_title': 0.12834497960284352},
#  'MED-2134': {'avg_cos_sim_text_title': 0.5909686088562012,
#   'avg_cos_sim_query_text': 0.13683106129368147,
#   'avg_cos_sim_query_title': 0.12089499707023303},
#  'MED-1718': {'avg_cos_sim_text_title': 0.7982998490333557,
#   'avg_cos_sim_query_text': 0.18880126625299454,
#   'avg_cos_sim_query_title': 0.23544280976057053},
#  'MED-3888': {'avg_cos_sim_text_title': 0.7974410057067871,
#   'avg_cos_sim_query_text': 0.24296342022717,
#   'avg_cos_sim_query_title': 0.151930239982903},
#  'MED-3795': {'avg_cos_sim_text_title': 0.8051558136940002,
#   'avg_cos_sim_query_text': 0.10944921523332596,
#   'avg_cos_sim_query_title': 0.08895152993500233},
#  'MED-1486': {'avg_cos_sim_text_title': 0.6771118640899658,
#   'avg_cos_sim_query_text': 0.13972362652420997,
#   'avg_cos_sim_query_title': 0.15379495024681092},
#  'MED-1258': {'avg_cos_sim_text_title': 0.770067572593689,
#   'avg_cos_sim_query_text': 0.29019394516944885,
#   'avg_cos_sim_query_title': 0.24277044832706451},
#  'MED-1571': {'avg_cos_sim_text_title': 0.8245394229888916,
#   'avg_cos_sim_query_text': 0.2912836819887161,
#   'avg_cos_sim_query_title': 0.1636771261692047},
#  'MED-1787': {'avg_cos_sim_text_title': 0.8637192845344543,
#   'avg_cos_sim_query_text': 0.14437022060155869,
#   'avg_cos_sim_query_title': 0.1682586446404457},
#  'MED-4565': {'avg_cos_sim_text_title': 0.7287279963493347,
#   'avg_cos_sim_query_text': 0.24461329728364944,
#   'avg_cos_sim_query_title': 0.18253304064273834},
#  'MED-1820': {'avg_cos_sim_text_title': 0.8709887266159058,
#   'avg_cos_sim_query_text': 0.11345843970775604,
#   'avg_cos_sim_query_title': 0.06453153491020203},
#  'MED-4841': {'avg_cos_sim_text_title': 0.896957516670227,
#   'avg_cos_sim_query_text': 0.3445022056500117,
#   'avg_cos_sim_query_title': 0.3910767237345378},
#  'MED-3446': {'avg_cos_sim_text_title': 0.8329362869262695,
#   'avg_cos_sim_query_text': 0.15884915739297867,
#   'avg_cos_sim_query_title': 0.07444825069978833},
#  'MED-4391': {'avg_cos_sim_text_title': 0.7621604800224304,
#   'avg_cos_sim_query_text': 0.14329224079847336,
#   'avg_cos_sim_query_title': 0.15231798589229584},
#  'MED-1348': {'avg_cos_sim_text_title': 0.8567445874214172,
#   'avg_cos_sim_query_text': 0.04115535505115986,
#   'avg_cos_sim_query_title': 0.038651266135275364},
#  'MED-3175': {'avg_cos_sim_text_title': 0.5718932151794434,
#   'avg_cos_sim_query_text': 0.3237111670896411,
#   'avg_cos_sim_query_title': 0.20635484997183084},
#  'MED-3158': {'avg_cos_sim_text_title': 0.8608498573303223,
#   'avg_cos_sim_query_text': 0.10429012216627598,
#   'avg_cos_sim_query_title': 0.055168675258755684},
#  'MED-4389': {'avg_cos_sim_text_title': 0.9031609296798706,
#   'avg_cos_sim_query_text': 0.31167493760585785,
#   'avg_cos_sim_query_title': 0.26979726925492287},
#  'MED-3681': {'avg_cos_sim_text_title': 0.8219888806343079,
#   'avg_cos_sim_query_text': 0.46345801651477814,
#   'avg_cos_sim_query_title': 0.440240815281868},
#  'MED-3985': {'avg_cos_sim_text_title': 0.9051601886749268,
#   'avg_cos_sim_query_text': 0.3401470333337784,
#   'avg_cos_sim_query_title': 0.3194634020328522},
#  'MED-2292': {'avg_cos_sim_text_title': 0.875151515007019,
#   'avg_cos_sim_query_text': 0.10882579162716866,
#   'avg_cos_sim_query_title': 0.14320814982056618},
#  'MED-4144': {'avg_cos_sim_text_title': 0.8403298854827881,
#   'avg_cos_sim_query_text': 0.17147735506296158,
#   'avg_cos_sim_query_title': 0.1635163351893425},
#  'MED-986': {'avg_cos_sim_text_title': 0.8404524326324463,
#   'avg_cos_sim_query_text': 0.60983806848526,
#   'avg_cos_sim_query_title': 0.4809642434120178},
#  'MED-4840': {'avg_cos_sim_text_title': 0.7870616912841797,
#   'avg_cos_sim_query_text': 0.3702259436249733,
#   'avg_cos_sim_query_title': 0.31930331885814667},
#  'MED-5053': {'avg_cos_sim_text_title': 0.9124071598052979,
#   'avg_cos_sim_query_text': 0.32098718360066414,
#   'avg_cos_sim_query_title': 0.3358095996081829},
#  'MED-1595': {'avg_cos_sim_text_title': 0.8179417252540588,
#   'avg_cos_sim_query_text': 0.32708995540936786,
#   'avg_cos_sim_query_title': 0.2316490759452184},
#  'MED-4846': {'avg_cos_sim_text_title': 0.9063687920570374,
#   'avg_cos_sim_query_text': 0.28652744460850954,
#   'avg_cos_sim_query_title': 0.24754157289862633},
#  'MED-4038': {'avg_cos_sim_text_title': 0.8592470288276672,
#   'avg_cos_sim_query_text': 0.2883366495370865,
#   'avg_cos_sim_query_title': 0.29075828939676285},
#  'MED-2376': {'avg_cos_sim_text_title': 0.7907166481018066,
#   'avg_cos_sim_query_text': 0.3189211388429006,
#   'avg_cos_sim_query_title': 0.24937208369374275},
#  'MED-4642': {'avg_cos_sim_text_title': 0.7605898380279541,
#   'avg_cos_sim_query_text': 0.3337385207414627,
#   'avg_cos_sim_query_title': 0.29440729692578316},
#  'MED-5273': {'avg_cos_sim_text_title': 0.8674247860908508,
#   'avg_cos_sim_query_text': 0.693414568901062,
#   'avg_cos_sim_query_title': 0.6644558906555176},
#  'MED-952': {'avg_cos_sim_text_title': 0.839179277420044,
#   'avg_cos_sim_query_text': 0.16555353999137878,
#   'avg_cos_sim_query_title': 0.06472945213317871},
#  'MED-2528': {'avg_cos_sim_text_title': 0.8966732025146484,
#   'avg_cos_sim_query_text': 0.21328449714928865,
#   'avg_cos_sim_query_title': 0.20010740496218204},
#  'MED-3501': {'avg_cos_sim_text_title': 0.8045963644981384,
#   'avg_cos_sim_query_text': 0.23309944570064545,
#   'avg_cos_sim_query_title': 0.22104834392666817},
#  'MED-1810': {'avg_cos_sim_text_title': 0.8432422280311584,
#   'avg_cos_sim_query_text': 0.3982923123985529,
#   'avg_cos_sim_query_title': 0.374705852009356},
#  'MED-3610': {'avg_cos_sim_text_title': 0.760308027267456,
#   'avg_cos_sim_query_text': 0.2082427591085434,
#   'avg_cos_sim_query_title': 0.1887052971869707},
#  'MED-717': {'avg_cos_sim_text_title': 0.8575243353843689,
#   'avg_cos_sim_query_text': 0.15381652116775513,
#   'avg_cos_sim_query_title': 0.12075720230738322},
#  'MED-5047': {'avg_cos_sim_text_title': 0.9106026887893677,
#   'avg_cos_sim_query_text': 0.2957513704895973,
#   'avg_cos_sim_query_title': 0.29286935925483704},
#  'MED-2360': {'avg_cos_sim_text_title': 0.8502858877182007,
#   'avg_cos_sim_query_text': 0.13268814980983734,
#   'avg_cos_sim_query_title': 0.17735957726836205},
#  'MED-3841': {'avg_cos_sim_text_title': 0.7414891719818115,
#   'avg_cos_sim_query_text': 0.26362095028162,
#   'avg_cos_sim_query_title': 0.19440409392118455},
#  'MED-1933': {'avg_cos_sim_text_title': 0.7731935977935791,
#   'avg_cos_sim_query_text': 0.07207671366631985,
#   'avg_cos_sim_query_title': 0.09975256025791168},
#  'MED-3877': {'avg_cos_sim_text_title': 0.9177082777023315,
#   'avg_cos_sim_query_text': 0.1564080659300089,
#   'avg_cos_sim_query_title': 0.1607745555229485},
#  'MED-1554': {'avg_cos_sim_text_title': 0.7433731555938721,
#   'avg_cos_sim_query_text': 0.30536990612745285,
#   'avg_cos_sim_query_title': 0.3860199252764384},
#  'MED-4551': {'avg_cos_sim_text_title': 0.8816165924072266,
#   'avg_cos_sim_query_text': 0.19484776293393224,
#   'avg_cos_sim_query_title': 0.17328789306338876},
#  'MED-2584': {'avg_cos_sim_text_title': 0.7058132886886597,
#   'avg_cos_sim_query_text': 0.23623173648957163,
#   'avg_cos_sim_query_title': 0.2015490352641791},
#  'MED-4633': {'avg_cos_sim_text_title': 0.8503861427307129,
#   'avg_cos_sim_query_text': 0.29700690507888794,
#   'avg_cos_sim_query_title': 0.19660381972789764},
#  'MED-5073': {'avg_cos_sim_text_title': 0.8927772045135498,
#   'avg_cos_sim_query_text': 0.1429060846567154,
#   'avg_cos_sim_query_title': 0.17138810455799103},
#  'MED-4468': {'avg_cos_sim_text_title': 0.8368890285491943,
#   'avg_cos_sim_query_text': 0.2811136742432912,
#   'avg_cos_sim_query_title': 0.2440218726793925},
#  'MED-5330': {'avg_cos_sim_text_title': 0.7686747312545776,
#   'avg_cos_sim_query_text': 0.15579327851134753,
#   'avg_cos_sim_query_title': 0.18074317359631614},
#  'MED-5091': {'avg_cos_sim_text_title': 0.7596101760864258,
#   'avg_cos_sim_query_text': 0.23157449811697006,
#   'avg_cos_sim_query_title': 0.2098919190466404},
#  'MED-3102': {'avg_cos_sim_text_title': 0.5720149278640747,
#   'avg_cos_sim_query_text': 0.21336804922404035,
#   'avg_cos_sim_query_title': 0.16161523812583514},
#  'MED-1830': {'avg_cos_sim_text_title': 0.8100071549415588,
#   'avg_cos_sim_query_text': 0.0226793239514033,
#   'avg_cos_sim_query_title': 0.08327758746842544},
#  'MED-4059': {'avg_cos_sim_text_title': 0.7834981083869934,
#   'avg_cos_sim_query_text': 0.3933747634291649,
#   'avg_cos_sim_query_title': 0.2323460541665554},
#  'MED-3990': {'avg_cos_sim_text_title': 0.8371768593788147,
#   'avg_cos_sim_query_text': 0.4137447476387024,
#   'avg_cos_sim_query_title': 0.3824964016675949},
#  'MED-118': {'avg_cos_sim_text_title': 0.6603812575340271,
#   'avg_cos_sim_query_text': 0.19251667697810465,
#   'avg_cos_sim_query_title': 0.2127516166203552},
#  'MED-4405': {'avg_cos_sim_text_title': 0.7967063784599304,
#   'avg_cos_sim_query_text': 0.27338847269614536,
#   'avg_cos_sim_query_title': 0.24290806179245314},
#  'MED-2745': {'avg_cos_sim_text_title': 0.9252344369888306,
#   'avg_cos_sim_query_text': 0.30111089535057545,
#   'avg_cos_sim_query_title': 0.32365741580724716},
#  'MED-3774': {'avg_cos_sim_text_title': 0.9115066528320312,
#   'avg_cos_sim_query_text': 0.18385236461957297,
#   'avg_cos_sim_query_title': 0.1848375822106997},
#  'MED-1124': {'avg_cos_sim_text_title': 0.917622983455658,
#   'avg_cos_sim_query_text': 0.43730220198631287,
#   'avg_cos_sim_query_title': 0.37374481558799744},
#  'MED-1580': {'avg_cos_sim_text_title': 0.8702476620674133,
#   'avg_cos_sim_query_text': 0.2713497653603554,
#   'avg_cos_sim_query_title': 0.2111405860632658},
#  'MED-3020': {'avg_cos_sim_text_title': 0.6495270133018494,
#   'avg_cos_sim_query_text': 0.1194000244140625,
#   'avg_cos_sim_query_title': 0.1075168140232563},
#  'MED-2651': {'avg_cos_sim_text_title': 0.6603812575340271,
#   'avg_cos_sim_query_text': 0.23877754002543433,
#   'avg_cos_sim_query_title': 0.24301491757588728},
#  'MED-2227': {'avg_cos_sim_text_title': 0.5557111501693726,
#   'avg_cos_sim_query_text': 0.3383507996797562,
#   'avg_cos_sim_query_title': 0.23186605796217918},
#  'MED-1322': {'avg_cos_sim_text_title': 0.9179014563560486,
#   'avg_cos_sim_query_text': 0.12819277743498483,
#   'avg_cos_sim_query_title': 0.11459856604536374},
#  'MED-2243': {'avg_cos_sim_text_title': 0.8859862685203552,
#   'avg_cos_sim_query_text': 0.2869345247745514,
#   'avg_cos_sim_query_title': 0.26347747445106506},
#  'MED-5121': {'avg_cos_sim_text_title': 0.8530683517456055,
#   'avg_cos_sim_query_text': 0.2907751798629761,
#   'avg_cos_sim_query_title': 0.27586595714092255},
#  'MED-5195': {'avg_cos_sim_text_title': 0.924366295337677,
#   'avg_cos_sim_query_text': 0.24269867241382598,
#   'avg_cos_sim_query_title': 0.23932252824306488},
#  'MED-1458': {'avg_cos_sim_text_title': 0.8564832210540771,
#   'avg_cos_sim_query_text': 0.20768839229519168,
#   'avg_cos_sim_query_title': 0.14424911622578898},
#  'MED-3763': {'avg_cos_sim_text_title': 0.8773297667503357,
#   'avg_cos_sim_query_text': 0.3326548054814339,
#   'avg_cos_sim_query_title': 0.41660612225532534},
#  'MED-1378': {'avg_cos_sim_text_title': 0.6582030057907104,
#   'avg_cos_sim_query_text': 0.1406922060996294,
#   'avg_cos_sim_query_title': 0.11171408649533987},
#  'MED-4013': {'avg_cos_sim_text_title': 0.8366518020629883,
#   'avg_cos_sim_query_text': -0.003859488293528557,
#   'avg_cos_sim_query_title': -0.012943250437577566},
#  'MED-1646': {'avg_cos_sim_text_title': 0.7328715324401855,
#   'avg_cos_sim_query_text': 0.24718531966209412,
#   'avg_cos_sim_query_title': 0.19121085958821432},
#  'MED-1672': {'avg_cos_sim_text_title': 0.7980132699012756,
#   'avg_cos_sim_query_text': 0.38592926412820816,
#   'avg_cos_sim_query_title': 0.3244558423757553},
#  'MED-4744': {'avg_cos_sim_text_title': 0.860882043838501,
#   'avg_cos_sim_query_text': 0.3282221853733063,
#   'avg_cos_sim_query_title': 0.25597861409187317},
#  'MED-3711': {'avg_cos_sim_text_title': 0.6222391128540039,
#   'avg_cos_sim_query_text': 0.25322916358709335,
#   'avg_cos_sim_query_title': 0.2119833379983902},
#  'MED-4129': {'avg_cos_sim_text_title': 0.8891190886497498,
#   'avg_cos_sim_query_text': 0.17360827773809434,
#   'avg_cos_sim_query_title': 0.16264708787202836},
#  'MED-1846': {'avg_cos_sim_text_title': 0.9027813076972961,
#   'avg_cos_sim_query_text': 0.278688907623291,
#   'avg_cos_sim_query_title': 0.2807350158691406},
#  'MED-2367': {'avg_cos_sim_text_title': 0.7733191251754761,
#   'avg_cos_sim_query_text': 0.1660887124016881,
#   'avg_cos_sim_query_title': 0.03101231949403882},
#  'MED-3979': {'avg_cos_sim_text_title': 0.8218809366226196,
#   'avg_cos_sim_query_text': 0.3630916178226471,
#   'avg_cos_sim_query_title': 0.3394506275653839},
#  'MED-4450': {'avg_cos_sim_text_title': 0.8398375511169434,
#   'avg_cos_sim_query_text': 0.22101695835590363,
#   'avg_cos_sim_query_title': 0.13061214343179017},
#  'MED-3450': {'avg_cos_sim_text_title': 0.8939599394798279,
#   'avg_cos_sim_query_text': 0.1134111105153958,
#   'avg_cos_sim_query_title': 0.12356012361124158},
#  'MED-2096': {'avg_cos_sim_text_title': 0.8418434858322144,
#   'avg_cos_sim_query_text': 0.060143331065773964,
#   'avg_cos_sim_query_title': 0.019592832773923874},
#  'MED-4058': {'avg_cos_sim_text_title': 0.7554721832275391,
#   'avg_cos_sim_query_text': 0.29150442183017733,
#   'avg_cos_sim_query_title': 0.22042387276887893},
#  'MED-4883': {'avg_cos_sim_text_title': 0.7385165691375732,
#   'avg_cos_sim_query_text': 0.09676461480557919,
#   'avg_cos_sim_query_title': 0.10788839496672153},
#  'MED-2049': {'avg_cos_sim_text_title': 0.8752315640449524,
#   'avg_cos_sim_query_text': 0.23985908925533295,
#   'avg_cos_sim_query_title': 0.15891937414805093},
#  'MED-2669': {'avg_cos_sim_text_title': 0.9004526138305664,
#   'avg_cos_sim_query_text': 0.3232666328549385,
#   'avg_cos_sim_query_title': 0.3100288510322571},
#  'MED-3274': {'avg_cos_sim_text_title': 0.8660542964935303,
#   'avg_cos_sim_query_text': 0.0552236438728869,
#   'avg_cos_sim_query_title': 0.04985942151397467},
#  'MED-4802': {'avg_cos_sim_text_title': 0.8267216682434082,
#   'avg_cos_sim_query_text': 0.16004658117890358,
#   'avg_cos_sim_query_title': 0.07019254192709923},
#  'MED-5328': {'avg_cos_sim_text_title': 0.8369710445404053,
#   'avg_cos_sim_query_text': 0.18281282902020832,
#   'avg_cos_sim_query_title': 0.13825429918180251},
#  'MED-3099': {'avg_cos_sim_text_title': 0.6895339488983154,
#   'avg_cos_sim_query_text': 0.2388932098235403,
#   'avg_cos_sim_query_title': 0.14101031622184174},
#  'MED-3525': {'avg_cos_sim_text_title': 0.5154270529747009,
#   'avg_cos_sim_query_text': 0.0931570182243983,
#   'avg_cos_sim_query_title': 0.05701751168817282},
#  'MED-3935': {'avg_cos_sim_text_title': 0.853015124797821,
#   'avg_cos_sim_query_text': 0.250839393053736,
#   'avg_cos_sim_query_title': 0.20098521720085824},
#  'MED-3599': {'avg_cos_sim_text_title': 0.8202931880950928,
#   'avg_cos_sim_query_text': 0.2996783033013344,
#   'avg_cos_sim_query_title': 0.30228748768568037},
#  'MED-1622': {'avg_cos_sim_text_title': 0.9042922258377075,
#   'avg_cos_sim_query_text': 0.3348742462694645,
#   'avg_cos_sim_query_title': 0.32047490030527115},
#  'MED-2273': {'avg_cos_sim_text_title': 0.8859477043151855,
#   'avg_cos_sim_query_text': 0.12540721148252487,
#   'avg_cos_sim_query_title': 0.11457588151097298},
#  'MED-2158': {'avg_cos_sim_text_title': 0.9304624199867249,
#   'avg_cos_sim_query_text': 0.4550204376379649,
#   'avg_cos_sim_query_title': 0.44881923993428546},
#  'MED-1350': {'avg_cos_sim_text_title': 0.7424377202987671,
#   'avg_cos_sim_query_text': 0.0865233801305294,
#   'avg_cos_sim_query_title': 0.05653237737715244},
#  'MED-2815': {'avg_cos_sim_text_title': 0.8067537546157837,
#   'avg_cos_sim_query_text': 0.14651019778102636,
#   'avg_cos_sim_query_title': 0.1640516184270382},
#  'MED-1131': {'avg_cos_sim_text_title': 0.8791325688362122,
#   'avg_cos_sim_query_text': 0.38065364956855774,
#   'avg_cos_sim_query_title': 0.39070940017700195},
#  'MED-4353': {'avg_cos_sim_text_title': 0.8210722804069519,
#   'avg_cos_sim_query_text': 0.22613768124332032,
#   'avg_cos_sim_query_title': 0.21009683112303415},
#  'MED-4146': {'avg_cos_sim_text_title': 0.9253433346748352,
#   'avg_cos_sim_query_text': 0.2193014919757843,
#   'avg_cos_sim_query_title': 0.19406937062740326},
#  'MED-2180': {'avg_cos_sim_text_title': 0.8331838846206665,
#   'avg_cos_sim_query_text': 0.38012110193570453,
#   'avg_cos_sim_query_title': 0.35202930370966595},
#  'MED-4354': {'avg_cos_sim_text_title': 0.8976200819015503,
#   'avg_cos_sim_query_text': 0.4622119665145874,
#   'avg_cos_sim_query_title': 0.45122887194156647},
#  'MED-5324': {'avg_cos_sim_text_title': 0.8612575531005859,
#   'avg_cos_sim_query_text': 0.18822843212235188,
#   'avg_cos_sim_query_title': 0.19173904634746058},
#  'MED-745': {'avg_cos_sim_text_title': 0.8099680542945862,
#   'avg_cos_sim_query_text': 0.16906949877738953,
#   'avg_cos_sim_query_title': 0.22648155689239502},
#  'MED-1389': {'avg_cos_sim_text_title': 0.8470355868339539,
#   'avg_cos_sim_query_text': 0.019963582511991262,
#   'avg_cos_sim_query_title': -0.014016609638929367},
#  'MED-4591': {'avg_cos_sim_text_title': 0.8886426687240601,
#   'avg_cos_sim_query_text': 0.4524076581001282,
#   'avg_cos_sim_query_title': 0.49383455514907837},
#  'MED-1327': {'avg_cos_sim_text_title': 0.8185210824012756,
#   'avg_cos_sim_query_text': 0.14155284855514766,
#   'avg_cos_sim_query_title': 0.12635936737060546},
#  'MED-2175': {'avg_cos_sim_text_title': 0.8402090072631836,
#   'avg_cos_sim_query_text': 0.1703374907374382,
#   'avg_cos_sim_query_title': 0.12245412574460109},
#  'MED-1366': {'avg_cos_sim_text_title': 0.7355086803436279,
#   'avg_cos_sim_query_text': 0.2211457940616778,
#   'avg_cos_sim_query_title': 0.18352410037602698},
#  'MED-1181': {'avg_cos_sim_text_title': 0.7856165170669556,
#   'avg_cos_sim_query_text': 0.19762237902198518,
#   'avg_cos_sim_query_title': 0.1091588514723948},
#  'MED-2775': {'avg_cos_sim_text_title': 0.8075835108757019,
#   'avg_cos_sim_query_text': 0.20901585618654886,
#   'avg_cos_sim_query_title': 0.13123229518532753},
#  'MED-4972': {'avg_cos_sim_text_title': 0.6628526449203491,
#   'avg_cos_sim_query_text': 0.4737938543160756,
#   'avg_cos_sim_query_title': 0.34043728311856586},
#  'MED-3920': {'avg_cos_sim_text_title': 0.69911789894104,
#   'avg_cos_sim_query_text': 0.2487465739250183,
#   'avg_cos_sim_query_title': 0.1801062449812889},
#  'MED-2221': {'avg_cos_sim_text_title': 0.8209410309791565,
#   'avg_cos_sim_query_text': 0.2796397738986545,
#   'avg_cos_sim_query_title': 0.2541007233990563},
#  'MED-2437': {'avg_cos_sim_text_title': 0.8535659313201904,
#   'avg_cos_sim_query_text': 0.4944290518760681,
#   'avg_cos_sim_query_title': 0.5688613057136536},
#  'MED-4790': {'avg_cos_sim_text_title': 0.879616379737854,
#   'avg_cos_sim_query_text': 0.27470139662424725,
#   'avg_cos_sim_query_title': 0.2352167492111524},
#  'MED-3761': {'avg_cos_sim_text_title': 0.7529162168502808,
#   'avg_cos_sim_query_text': 0.18373731523752213,
#   'avg_cos_sim_query_title': 0.10562063008546829},
#  'MED-2107': {'avg_cos_sim_text_title': 0.7143629789352417,
#   'avg_cos_sim_query_text': 0.2807292342185974,
#   'avg_cos_sim_query_title': 0.2411609391371409},
#  'MED-5000': {'avg_cos_sim_text_title': 0.9010469913482666,
#   'avg_cos_sim_query_text': 0.3997509479522705,
#   'avg_cos_sim_query_title': 0.4077424257993698},
#  'MED-1689': {'avg_cos_sim_text_title': 0.8408987522125244,
#   'avg_cos_sim_query_text': 0.2643985450267792,
#   'avg_cos_sim_query_title': 0.17385825514793396},
#  'MED-4245': {'avg_cos_sim_text_title': 0.8096845149993896,
#   'avg_cos_sim_query_text': 0.03551269043236971,
#   'avg_cos_sim_query_title': 0.03130005858838558},
#  'MED-4288': {'avg_cos_sim_text_title': 0.8732844591140747,
#   'avg_cos_sim_query_text': 0.34033264219760895,
#   'avg_cos_sim_query_title': 0.3758890628814697},
#  'MED-3701': {'avg_cos_sim_text_title': 0.8474776744842529,
#   'avg_cos_sim_query_text': 0.2935028914362192,
#   'avg_cos_sim_query_title': 0.2605602629482746},
#  'MED-2252': {'avg_cos_sim_text_title': 0.7902153730392456,
#   'avg_cos_sim_query_text': 0.13834765227511525,
#   'avg_cos_sim_query_title': 0.0650547534848253},
#  'MED-3702': {'avg_cos_sim_text_title': 0.7364146113395691,
#   'avg_cos_sim_query_text': 0.11547558754682541,
#   'avg_cos_sim_query_title': 0.1950925812125206},
#  'MED-3350': {'avg_cos_sim_text_title': 0.7481361031532288,
#   'avg_cos_sim_query_text': 0.1580769620835781,
#   'avg_cos_sim_query_title': 0.09497768990695477},
#  'MED-2000': {'avg_cos_sim_text_title': 0.8528826236724854,
#   'avg_cos_sim_query_text': 0.15826020389795303,
#   'avg_cos_sim_query_title': 0.15474606802066168},
#  'MED-1500': {'avg_cos_sim_text_title': 0.929389476776123,
#   'avg_cos_sim_query_text': 0.1339239925146103,
#   'avg_cos_sim_query_title': 0.13418488204479218},
#  'MED-1511': {'avg_cos_sim_text_title': 0.8430905342102051,
#   'avg_cos_sim_query_text': -0.009524061344563961,
#   'avg_cos_sim_query_title': -0.03894762694835663},
#  'MED-4741': {'avg_cos_sim_text_title': 0.9194145202636719,
#   'avg_cos_sim_query_text': 0.31843656674027443,
#   'avg_cos_sim_query_title': 0.26165876910090446},
#  'MED-3486': {'avg_cos_sim_text_title': 0.8399519920349121,
#   'avg_cos_sim_query_text': 0.1490025520324707,
#   'avg_cos_sim_query_title': 0.15292823314666748},
#  'MED-2951': {'avg_cos_sim_text_title': 0.8437854051589966,
#   'avg_cos_sim_query_text': 0.17766268054644266,
#   'avg_cos_sim_query_title': 0.16364995886882147},
#  'MED-3451': {'avg_cos_sim_text_title': 0.8779172301292419,
#   'avg_cos_sim_query_text': 0.17199121291438738,
#   'avg_cos_sim_query_title': 0.17289122318228087},
#  'MED-3376': {'avg_cos_sim_text_title': 0.7635651230812073,
#   'avg_cos_sim_query_text': 0.2287389663979411,
#   'avg_cos_sim_query_title': 0.20387054979801178},
#  'MED-3676': {'avg_cos_sim_text_title': 0.7933538556098938,
#   'avg_cos_sim_query_text': 0.3547706703344981,
#   'avg_cos_sim_query_title': 0.35573577384154004},
#  'MED-1304': {'avg_cos_sim_text_title': 0.797584056854248,
#   'avg_cos_sim_query_text': 0.3216598555445671,
#   'avg_cos_sim_query_title': 0.340411052107811},
#  'MED-4809': {'avg_cos_sim_text_title': 0.7748757600784302,
#   'avg_cos_sim_query_text': 0.1266922652721405,
#   'avg_cos_sim_query_title': 0.16262629628181458},
#  'MED-4710': {'avg_cos_sim_text_title': 0.9080910682678223,
#   'avg_cos_sim_query_text': 0.19751839091380438,
#   'avg_cos_sim_query_title': 0.17939594884713492},
#  'MED-4667': {'avg_cos_sim_text_title': 0.8926831483840942,
#   'avg_cos_sim_query_text': 0.30224818487962085,
#   'avg_cos_sim_query_title': 0.35102449854214984},
#  'MED-1517': {'avg_cos_sim_text_title': 0.7584840059280396,
#   'avg_cos_sim_query_text': 0.029962755739688873,
#   'avg_cos_sim_query_title': 0.08017513155937195},
#  'MED-1334': {'avg_cos_sim_text_title': 0.8896937370300293,
#   'avg_cos_sim_query_text': 0.09997231140732765,
#   'avg_cos_sim_query_title': 0.1251963327328364},
#  'MED-3305': {'avg_cos_sim_text_title': 0.8714510798454285,
#   'avg_cos_sim_query_text': 0.11088429888089497,
#   'avg_cos_sim_query_title': 0.09062944000793828},
#  'MED-2820': {'avg_cos_sim_text_title': 0.8192054033279419,
#   'avg_cos_sim_query_text': 0.1215115903566281,
#   'avg_cos_sim_query_title': 0.1014383075137933},
#  'MED-1569': {'avg_cos_sim_text_title': 0.8357582092285156,
#   'avg_cos_sim_query_text': 0.26481715589761734,
#   'avg_cos_sim_query_title': 0.16465227802594504},
#  'MED-2278': {'avg_cos_sim_text_title': 0.8602546453475952,
#   'avg_cos_sim_query_text': 0.12549690157175064,
#   'avg_cos_sim_query_title': 0.16961121186614037},
#  'MED-2005': {'avg_cos_sim_text_title': 0.6737344264984131,
#   'avg_cos_sim_query_text': 0.09691453197350104,
#   'avg_cos_sim_query_title': 0.04683173696200053},
#  'MED-4947': {'avg_cos_sim_text_title': 0.8753262162208557,
#   'avg_cos_sim_query_text': 0.22673994302749634,
#   'avg_cos_sim_query_title': 0.1685810089111328},
#  'MED-5204': {'avg_cos_sim_text_title': 0.8216495513916016,
#   'avg_cos_sim_query_text': 0.12203197926282883,
#   'avg_cos_sim_query_title': 0.09464509785175323},
#  'MED-3586': {'avg_cos_sim_text_title': 0.8855600357055664,
#   'avg_cos_sim_query_text': 0.24087208780375394,
#   'avg_cos_sim_query_title': 0.22402415864846922},
#  'MED-1726': {'avg_cos_sim_text_title': 0.8282231688499451,
#   'avg_cos_sim_query_text': 0.38858063519001007,
#   'avg_cos_sim_query_title': 0.41505032777786255},
#  'MED-5341': {'avg_cos_sim_text_title': 0.7647134065628052,
#   'avg_cos_sim_query_text': 0.18725649949491902,
#   'avg_cos_sim_query_title': 0.17401979074758642},
#  'MED-1958': {'avg_cos_sim_text_title': 0.8344784379005432,
#   'avg_cos_sim_query_text': 0.28911829739809036,
#   'avg_cos_sim_query_title': 0.25145298102870584},
#  'MED-4959': {'avg_cos_sim_text_title': 0.897852897644043,
#   'avg_cos_sim_query_text': 0.19800896445910135,
#   'avg_cos_sim_query_title': 0.18720793475707373},
#  'MED-3658': {'avg_cos_sim_text_title': 0.9273390769958496,
#   'avg_cos_sim_query_text': 0.30120015144348145,
#   'avg_cos_sim_query_title': 0.2972663342952728},
#  'MED-2284': {'avg_cos_sim_text_title': 0.6959167718887329,
#   'avg_cos_sim_query_text': 0.15440656741460165,
#   'avg_cos_sim_query_title': 0.10766191842655341},
#  'MED-1410': {'avg_cos_sim_text_title': 0.7219695448875427,
#   'avg_cos_sim_query_text': 0.1830126391723752,
#   'avg_cos_sim_query_title': 0.08933400083333254},
#  'MED-3547': {'avg_cos_sim_text_title': 0.9374845027923584,
#   'avg_cos_sim_query_text': 0.1609687062446028,
#   'avg_cos_sim_query_title': 0.16693444596603513},
#  'MED-4132': {'avg_cos_sim_text_title': 0.8670564889907837,
#   'avg_cos_sim_query_text': 0.23296238075603137,
#   'avg_cos_sim_query_title': 0.18372570926492865},
#  'MED-1515': {'avg_cos_sim_text_title': 0.8553521633148193,
#   'avg_cos_sim_query_text': 0.027152176946401596,
#   'avg_cos_sim_query_title': 0.05600401759147644},
#  'MED-1279': {'avg_cos_sim_text_title': 0.7057251930236816,
#   'avg_cos_sim_query_text': 0.20072048902511597,
#   'avg_cos_sim_query_title': 0.20643902197480202},
#  'MED-4705': {'avg_cos_sim_text_title': 0.6413425803184509,
#   'avg_cos_sim_query_text': 0.1492222398519516,
#   'avg_cos_sim_query_title': 0.037452288437634706},
#  'MED-4071': {'avg_cos_sim_text_title': 0.6924121379852295,
#   'avg_cos_sim_query_text': 0.259623933583498,
#   'avg_cos_sim_query_title': 0.15064658895134925},
#  'MED-1103': {'avg_cos_sim_text_title': 0.8647204637527466,
#   'avg_cos_sim_query_text': 0.0741112232208252,
#   'avg_cos_sim_query_title': 0.08035898953676224},
#  'MED-1496': {'avg_cos_sim_text_title': 0.7618653774261475,
#   'avg_cos_sim_query_text': 0.08268035820219666,
#   'avg_cos_sim_query_title': 0.04788921680301428},
#  'MED-2215': {'avg_cos_sim_text_title': 0.8445172309875488,
#   'avg_cos_sim_query_text': 0.2689051888883114,
#   'avg_cos_sim_query_title': 0.2764394252250592},
#  'MED-1851': {'avg_cos_sim_text_title': 0.8803615570068359,
#   'avg_cos_sim_query_text': 0.17937565594911575,
#   'avg_cos_sim_query_title': 0.0882488340139389},
#  'MED-3320': {'avg_cos_sim_text_title': 0.7796282172203064,
# ...
#   'avg_cos_sim_query_title': 0.040636468678712845},
#  'MED-2036': {'avg_cos_sim_text_title': 0.8536127805709839,
#   'avg_cos_sim_query_text': 0.06790488213300705,
#   'avg_cos_sim_query_title': 0.09811515361070633},
#  'MED-4525': {'avg_cos_sim_text_title': 0.8402268290519714,
#   'avg_cos_sim_query_text': 0.2849779725074768,
#   'avg_cos_sim_query_title': 0.3043801337480545},
#  'MED-1596': {'avg_cos_sim_text_title': 0.7758887410163879,
#   'avg_cos_sim_query_text': 0.2701062398652236,
#   'avg_cos_sim_query_title': 0.23682806765039763},
#  'MED-4550': {'avg_cos_sim_text_title': 0.8982467651367188,
#   'avg_cos_sim_query_text': 0.3610345125198364,
#   'avg_cos_sim_query_title': 0.3032032251358032},
#  'MED-4731': {'avg_cos_sim_text_title': 0.8775475025177002,
#   'avg_cos_sim_query_text': 0.31079234679539997,
#   'avg_cos_sim_query_title': 0.28040626148382825},
#  'MED-2370': {'avg_cos_sim_text_title': 0.8515095114707947,
#   'avg_cos_sim_query_text': 0.38119393959641457,
#   'avg_cos_sim_query_title': 0.3823615089058876},
#  'MED-1737': {'avg_cos_sim_text_title': 0.8416608572006226,
#   'avg_cos_sim_query_text': 0.4615399241447449,
#   'avg_cos_sim_query_title': 0.38670670986175537},
#  'MED-5153': {'avg_cos_sim_text_title': 0.8628582954406738,
#   'avg_cos_sim_query_text': 0.17399222403764725,
#   'avg_cos_sim_query_title': 0.22197740525007248},
#  'MED-1330': {'avg_cos_sim_text_title': 0.9148302674293518,
#   'avg_cos_sim_query_text': 0.054911937564611435,
#   'avg_cos_sim_query_title': 0.031779362509648},
#  'MED-1849': {'avg_cos_sim_text_title': 0.8589557409286499,
#   'avg_cos_sim_query_text': 0.14608410000801086,
#   'avg_cos_sim_query_title': 0.09837737306952477},
#  'MED-5329': {'avg_cos_sim_text_title': 0.8470883369445801,
#   'avg_cos_sim_query_text': 0.18271697342528828,
#   'avg_cos_sim_query_title': 0.16715793454620456},
#  'MED-2505': {'avg_cos_sim_text_title': 0.3829547166824341,
#   'avg_cos_sim_query_text': 0.13878773599863053,
#   'avg_cos_sim_query_title': 0.05100171137601137},
#  'MED-3530': {'avg_cos_sim_text_title': 0.9281423091888428,
#   'avg_cos_sim_query_text': 0.1518898162369927,
#   'avg_cos_sim_query_title': 0.15118568359563747},
#  'MED-1639': {'avg_cos_sim_text_title': 0.8038299083709717,
#   'avg_cos_sim_query_text': 0.32995652513844625,
#   'avg_cos_sim_query_title': 0.2938479578920773},
#  'MED-3683': {'avg_cos_sim_text_title': 0.7892416715621948,
#   'avg_cos_sim_query_text': 0.6324202418327332,
#   'avg_cos_sim_query_title': 0.5127285420894623},
#  'MED-2608': {'avg_cos_sim_text_title': 0.8181259632110596,
#   'avg_cos_sim_query_text': 0.2638431340456009,
#   'avg_cos_sim_query_title': 0.18763644248247147},
#  'MED-4606': {'avg_cos_sim_text_title': 0.8597316741943359,
#   'avg_cos_sim_query_text': 0.2351306974887848,
#   'avg_cos_sim_query_title': 0.30315840244293213},
#  'MED-4766': {'avg_cos_sim_text_title': 0.7880600690841675,
#   'avg_cos_sim_query_text': 0.5892963707447052,
#   'avg_cos_sim_query_title': 0.5855478197336197},
#  'MED-3840': {'avg_cos_sim_text_title': 0.8624072074890137,
#   'avg_cos_sim_query_text': 0.639837384223938,
#   'avg_cos_sim_query_title': 0.7318678498268127},
#  'MED-3796': {'avg_cos_sim_text_title': 0.8020211458206177,
#   'avg_cos_sim_query_text': 0.21262638803039277,
#   'avg_cos_sim_query_title': 0.18877865267651422},
#  'MED-3524': {'avg_cos_sim_text_title': 0.7798427939414978,
#   'avg_cos_sim_query_text': 0.211773748199145,
#   'avg_cos_sim_query_title': 0.15986795102556547},
#  'MED-1435': {'avg_cos_sim_text_title': 0.7728074789047241,
#   'avg_cos_sim_query_text': 0.032199637964367867,
#   'avg_cos_sim_query_title': 0.03805693704634905},
#  'MED-4713': {'avg_cos_sim_text_title': 0.7851774096488953,
#   'avg_cos_sim_query_text': 0.1628490388393402,
#   'avg_cos_sim_query_title': 0.17700877785682678},
#  'MED-3490': {'avg_cos_sim_text_title': 0.8657348155975342,
#   'avg_cos_sim_query_text': 0.09954427927732468,
#   'avg_cos_sim_query_title': 0.11072047054767609},
#  'MED-4298': {'avg_cos_sim_text_title': 0.8845599293708801,
#   'avg_cos_sim_query_text': 0.20429964363574982,
#   'avg_cos_sim_query_title': 0.17004737257957458},
#  'MED-2287': {'avg_cos_sim_text_title': 0.7542691230773926,
#   'avg_cos_sim_query_text': 0.06419827044010162,
#   'avg_cos_sim_query_title': 0.05319707840681076},
#  'MED-4347': {'avg_cos_sim_text_title': 0.8304769396781921,
#   'avg_cos_sim_query_text': 0.29285141328970593,
#   'avg_cos_sim_query_title': 0.2847233961025874},
#  'MED-1488': {'avg_cos_sim_text_title': 0.6783205270767212,
#   'avg_cos_sim_query_text': 0.1284436173737049,
#   'avg_cos_sim_query_title': 0.1527465209364891},
#  'MED-5184': {'avg_cos_sim_text_title': 0.948132336139679,
#   'avg_cos_sim_query_text': 0.2575849860906601,
#   'avg_cos_sim_query_title': 0.25391911417245866},
#  'MED-1129': {'avg_cos_sim_text_title': 0.7380117177963257,
#   'avg_cos_sim_query_text': -0.045977238565683365,
#   'avg_cos_sim_query_title': -0.01642199605703354},
#  'MED-2389': {'avg_cos_sim_text_title': 0.857341468334198,
#   'avg_cos_sim_query_text': 0.2687744740396738,
#   'avg_cos_sim_query_title': 0.23682777350768447},
#  'MED-4372': {'avg_cos_sim_text_title': 0.6464260816574097,
#   'avg_cos_sim_query_text': 0.33664220571517944,
#   'avg_cos_sim_query_title': 0.23853465914726257},
#  'MED-1917': {'avg_cos_sim_text_title': 0.8274611234664917,
#   'avg_cos_sim_query_text': 0.1596309207379818,
#   'avg_cos_sim_query_title': 0.1300315298140049},
#  'MED-4680': {'avg_cos_sim_text_title': 0.8300670981407166,
#   'avg_cos_sim_query_text': 0.2132855225354433,
#   'avg_cos_sim_query_title': 0.19307582266628742},
#  'MED-3941': {'avg_cos_sim_text_title': 0.8696141242980957,
#   'avg_cos_sim_query_text': 0.1312979981303215,
#   'avg_cos_sim_query_title': 0.08679316379129887},
#  'MED-4573': {'avg_cos_sim_text_title': 0.8658016324043274,
#   'avg_cos_sim_query_text': 0.49862562865018845,
#   'avg_cos_sim_query_title': 0.44537361711263657},
#  'MED-4383': {'avg_cos_sim_text_title': 0.8728753328323364,
#   'avg_cos_sim_query_text': 0.2381611168384552,
#   'avg_cos_sim_query_title': 0.21752190589904785},
#  'MED-1950': {'avg_cos_sim_text_title': 0.7648329734802246,
#   'avg_cos_sim_query_text': 0.1666656732559204,
#   'avg_cos_sim_query_title': 0.22566668689250946},
#  'MED-5333': {'avg_cos_sim_text_title': 0.7618686556816101,
#   'avg_cos_sim_query_text': 0.18673106322863273,
#   'avg_cos_sim_query_title': 0.16906052066146263},
#  'MED-4147': {'avg_cos_sim_text_title': 0.8736774325370789,
#   'avg_cos_sim_query_text': 0.1451856680214405,
#   'avg_cos_sim_query_title': 0.17055875808000565},
#  'MED-1487': {'avg_cos_sim_text_title': 0.7042722105979919,
#   'avg_cos_sim_query_text': 0.19436614960432053,
#   'avg_cos_sim_query_title': 0.14845825700710216},
#  'MED-3690': {'avg_cos_sim_text_title': 0.8600536584854126,
#   'avg_cos_sim_query_text': 0.3092546209692955,
#   'avg_cos_sim_query_title': 0.3276623636484146},
#  'MED-2900': {'avg_cos_sim_text_title': 0.9285186529159546,
#   'avg_cos_sim_query_text': 0.20898455567657948,
#   'avg_cos_sim_query_title': 0.20140115469694136},
#  'MED-5177': {'avg_cos_sim_text_title': 0.8646863698959351,
#   'avg_cos_sim_query_text': 0.28817856808503467,
#   'avg_cos_sim_query_title': 0.25633791958292323},
#  'MED-2792': {'avg_cos_sim_text_title': 0.8651865124702454,
#   'avg_cos_sim_query_text': 0.16315940767526627,
#   'avg_cos_sim_query_title': 0.1446740726629893},
#  'MED-2722': {'avg_cos_sim_text_title': 0.8768249750137329,
#   'avg_cos_sim_query_text': 0.28129699528217317,
#   'avg_cos_sim_query_title': 0.2463540703058243},
#  'MED-1545': {'avg_cos_sim_text_title': 0.8846539258956909,
#   'avg_cos_sim_query_text': 0.20892113540321589,
#   'avg_cos_sim_query_title': 0.18921346589922905},
#  'MED-1827': {'avg_cos_sim_text_title': 0.7587556838989258,
#   'avg_cos_sim_query_text': 0.17841558158397675,
#   'avg_cos_sim_query_title': 0.17585315058628717},
#  'MED-2772': {'avg_cos_sim_text_title': 0.9540047645568848,
#   'avg_cos_sim_query_text': 0.2224821123915414,
#   'avg_cos_sim_query_title': 0.19633774055788913},
#  'MED-4691': {'avg_cos_sim_text_title': 0.6109105348587036,
#   'avg_cos_sim_query_text': 0.06876172125339508,
#   'avg_cos_sim_query_title': 0.009048175066709518},
#  'MED-3807': {'avg_cos_sim_text_title': 0.8729822635650635,
#   'avg_cos_sim_query_text': 0.13606759905815125,
#   'avg_cos_sim_query_title': 0.1499980092048645},
#  'MED-5344': {'avg_cos_sim_text_title': 0.8243379592895508,
#   'avg_cos_sim_query_text': 0.21815475821495056,
#   'avg_cos_sim_query_title': 0.2264431118965149},
#  'MED-3280': {'avg_cos_sim_text_title': 0.7909798622131348,
#   'avg_cos_sim_query_text': 0.11884673023596407,
#   'avg_cos_sim_query_title': 0.10911580882966518},
#  'MED-1208': {'avg_cos_sim_text_title': 0.572603166103363,
#   'avg_cos_sim_query_text': 0.22461419304211935,
#   'avg_cos_sim_query_title': 0.20085998127857843},
#  'MED-5081': {'avg_cos_sim_text_title': 0.8634723424911499,
#   'avg_cos_sim_query_text': 0.2088940367102623,
#   'avg_cos_sim_query_title': 0.22406850010156631},
#  'MED-1470': {'avg_cos_sim_text_title': 0.816785991191864,
#   'avg_cos_sim_query_text': 0.29469922681649524,
#   'avg_cos_sim_query_title': 0.1610595261057218},
#  'MED-5118': {'avg_cos_sim_text_title': 0.906287431716919,
#   'avg_cos_sim_query_text': 0.37058407068252563,
#   'avg_cos_sim_query_title': 0.2938538193702698},
#  'MED-4381': {'avg_cos_sim_text_title': 0.655826985836029,
#   'avg_cos_sim_query_text': 0.2544201612472534,
#   'avg_cos_sim_query_title': 0.324572999562536},
#  'MED-2742': {'avg_cos_sim_text_title': 0.8357182741165161,
#   'avg_cos_sim_query_text': 0.3197037987411022,
#   'avg_cos_sim_query_title': 0.27828681096434593},
#  'MED-1600': {'avg_cos_sim_text_title': 0.6610693335533142,
#   'avg_cos_sim_query_text': 0.15004101395606995,
#   'avg_cos_sim_query_title': 0.16085852620502314},
#  'MED-3311': {'avg_cos_sim_text_title': 0.8756515979766846,
#   'avg_cos_sim_query_text': 0.27202556654810905,
#   'avg_cos_sim_query_title': 0.23886706354096532},
#  'MED-3922': {'avg_cos_sim_text_title': 0.859954833984375,
#   'avg_cos_sim_query_text': 0.18896145652979612,
#   'avg_cos_sim_query_title': 0.13229892123490572},
#  'MED-306': {'avg_cos_sim_text_title': 0.7837848663330078,
#   'avg_cos_sim_query_text': -0.021314837969839573,
#   'avg_cos_sim_query_title': -0.052543628960847855},
#  'MED-3656': {'avg_cos_sim_text_title': 0.894728422164917,
#   'avg_cos_sim_query_text': 0.026939877929786842,
#   'avg_cos_sim_query_title': 0.007355282393594583},
#  'MED-3385': {'avg_cos_sim_text_title': 0.7304871678352356,
#   'avg_cos_sim_query_text': 0.28043003380298615,
#   'avg_cos_sim_query_title': 0.22444601729512215},
#  'MED-1305': {'avg_cos_sim_text_title': 0.8831259608268738,
#   'avg_cos_sim_query_text': 0.15802259743213654,
#   'avg_cos_sim_query_title': 0.1605084165930748},
#  'MED-1987': {'avg_cos_sim_text_title': 0.8249620795249939,
#   'avg_cos_sim_query_text': 0.10714416913688182,
#   'avg_cos_sim_query_title': 0.07621045988053084},
#  'MED-3939': {'avg_cos_sim_text_title': 0.6787464022636414,
#   'avg_cos_sim_query_text': 0.08653088871921812,
#   'avg_cos_sim_query_title': 0.0652543484632458},
#  'MED-5190': {'avg_cos_sim_text_title': 0.8502972722053528,
#   'avg_cos_sim_query_text': 0.305094122265776,
#   'avg_cos_sim_query_title': 0.2672422273705403},
#  'MED-3820': {'avg_cos_sim_text_title': 0.8488348722457886,
#   'avg_cos_sim_query_text': 0.10437310642252366,
#   'avg_cos_sim_query_title': 0.06824446345369022},
#  'MED-3542': {'avg_cos_sim_text_title': 0.5564283728599548,
#   'avg_cos_sim_query_text': 0.132984958589077,
#   'avg_cos_sim_query_title': 0.1720593012869358},
#  'MED-1283': {'avg_cos_sim_text_title': 0.7943593263626099,
#   'avg_cos_sim_query_text': 0.2306578333179156,
#   'avg_cos_sim_query_title': 0.17868604759375253},
#  'MED-4760': {'avg_cos_sim_text_title': 0.8286871314048767,
#   'avg_cos_sim_query_text': 0.31391432881355286,
#   'avg_cos_sim_query_title': 0.43222445249557495},
#  'MED-5157': {'avg_cos_sim_text_title': 0.8541301488876343,
#   'avg_cos_sim_query_text': 0.40439900755882263,
#   'avg_cos_sim_query_title': 0.3907264918088913},
#  'MED-4813': {'avg_cos_sim_text_title': 0.8777689337730408,
#   'avg_cos_sim_query_text': 0.3239889244238536,
#   'avg_cos_sim_query_title': 0.3037130534648895},
#  'MED-2501': {'avg_cos_sim_text_title': 0.7553143501281738,
#   'avg_cos_sim_query_text': 0.13367028534412384,
#   'avg_cos_sim_query_title': 0.1024934456218034},
#  'MED-4786': {'avg_cos_sim_text_title': 0.9077587127685547,
#   'avg_cos_sim_query_text': 0.5465811491012573,
#   'avg_cos_sim_query_title': 0.5438661575317383},
#  'MED-3758': {'avg_cos_sim_text_title': 0.8928405046463013,
#   'avg_cos_sim_query_text': 0.3145697843283415,
#   'avg_cos_sim_query_title': 0.3093190938234329},
#  'MED-4515': {'avg_cos_sim_text_title': 0.779126763343811,
#   'avg_cos_sim_query_text': 0.32197877019643784,
#   'avg_cos_sim_query_title': 0.3544667757426699},
#  'MED-4417': {'avg_cos_sim_text_title': 0.8958710432052612,
#   'avg_cos_sim_query_text': 0.28426793217658997,
#   'avg_cos_sim_query_title': 0.2662154932816823},
#  'MED-5026': {'avg_cos_sim_text_title': 0.842658519744873,
#   'avg_cos_sim_query_text': 0.38397225737571716,
#   'avg_cos_sim_query_title': 0.314727246761322},
#  'MED-1811': {'avg_cos_sim_text_title': 0.8989433646202087,
#   'avg_cos_sim_query_text': 0.21913236379623413,
#   'avg_cos_sim_query_title': 0.18360543251037598},
#  'MED-2664': {'avg_cos_sim_text_title': 0.7829388380050659,
#   'avg_cos_sim_query_text': 0.291161784902215,
#   'avg_cos_sim_query_title': 0.31752894818782806},
#  'MED-1098': {'avg_cos_sim_text_title': 0.8019324541091919,
#   'avg_cos_sim_query_text': 0.27883270134528476,
#   'avg_cos_sim_query_title': 0.2587219588458538},
#  'MED-3354': {'avg_cos_sim_text_title': 0.8539198040962219,
#   'avg_cos_sim_query_text': 0.05481039546430111,
#   'avg_cos_sim_query_title': 0.04614608746487647},
#  'MED-4234': {'avg_cos_sim_text_title': 0.799190878868103,
#   'avg_cos_sim_query_text': 0.3179056942462921,
#   'avg_cos_sim_query_title': 0.2561851944774389},
#  'MED-4091': {'avg_cos_sim_text_title': 0.7526106834411621,
#   'avg_cos_sim_query_text': 0.20414608251303434,
#   'avg_cos_sim_query_title': 0.126541287638247},
#  'MED-1587': {'avg_cos_sim_text_title': 0.7560890316963196,
#   'avg_cos_sim_query_text': 0.24978273113568625,
#   'avg_cos_sim_query_title': 0.15592858692010245},
#  'MED-3654': {'avg_cos_sim_text_title': 0.7994118928909302,
#   'avg_cos_sim_query_text': 0.23937197029590607,
#   'avg_cos_sim_query_title': 0.24950247009595236},
#  'MED-1607': {'avg_cos_sim_text_title': 0.9194824695587158,
#   'avg_cos_sim_query_text': 0.24596897140145302,
#   'avg_cos_sim_query_title': 0.25663965567946434},
#  'MED-1791': {'avg_cos_sim_text_title': 0.8489503860473633,
#   'avg_cos_sim_query_text': 0.15840090066194534,
#   'avg_cos_sim_query_title': 0.1669764406979084},
#  'MED-3976': {'avg_cos_sim_text_title': 0.8412582874298096,
#   'avg_cos_sim_query_text': 0.29852330684661865,
#   'avg_cos_sim_query_title': 0.22905443608760834},
#  'MED-2521': {'avg_cos_sim_text_title': 0.8241708278656006,
#   'avg_cos_sim_query_text': 0.15519522177055478,
#   'avg_cos_sim_query_title': 0.16384683642536402},
#  'MED-3885': {'avg_cos_sim_text_title': 0.7384562492370605,
#   'avg_cos_sim_query_text': 0.06983805953391961,
#   'avg_cos_sim_query_title': 0.06655101770801204},
#  'MED-2412': {'avg_cos_sim_text_title': 0.860184371471405,
#   'avg_cos_sim_query_text': 0.28647175058722496,
#   'avg_cos_sim_query_title': 0.2648808724867801},
#  'MED-3399': {'avg_cos_sim_text_title': 0.8948448300361633,
#   'avg_cos_sim_query_text': 0.19136133790016174,
#   'avg_cos_sim_query_title': 0.21362356841564178},
#  'MED-3749': {'avg_cos_sim_text_title': 0.89936763048172,
#   'avg_cos_sim_query_text': 0.27286429703235626,
#   'avg_cos_sim_query_title': 0.20018740557134151},
#  'MED-3699': {'avg_cos_sim_text_title': 0.6959770321846008,
#   'avg_cos_sim_query_text': 0.2762196428245968,
#   'avg_cos_sim_query_title': 0.24325132535563576},
#  'MED-4290': {'avg_cos_sim_text_title': 0.8511934280395508,
#   'avg_cos_sim_query_text': 0.30854226648807526,
#   'avg_cos_sim_query_title': 0.34418898820877075},
#  'MED-3627': {'avg_cos_sim_text_title': 0.8648409843444824,
#   'avg_cos_sim_query_text': 0.30328308418393135,
#   'avg_cos_sim_query_title': 0.2621775859345992}}

# %%
results = {
    "avg_cosine_text_title":
        np.nanmean([v['avg_cos_sim_text_title']            for v in avg_cosine_sim.values()]),
    "avg_cos_sim_query_text":
        np.nanmean([v['avg_cos_sim_query_text']       for v in avg_cosine_sim.values()]),
    "avg_cos_sim_query_title":
        np.nanmean([v['avg_cos_sim_query_title']   for v in avg_cosine_sim.values()]),
}
results
# Out:
# {'avg_cosine_text_title': 0.8202642796039581,
#  'avg_cos_sim_query_text': 0.22855729575399447,
#  'avg_cos_sim_query_title': 0.2111831443273495}
